# %% [markdown]
# Refine the code from the exploratory Fire Emblem Heroes notebook, create a function(s) that will:
# 1. take a list of names
# 2. use those names to complete a url
# 3. scrape the url for a characters specials, weapons, assits, and passives.
# 4. create a dataframe and add a column for each name of the original table (so that the dataframes will join together with other characters) adding a column with the characters name from the list.
# 5. join the data frames together into four complete dataframes, weapons, assits, specials, and passives.

# %%
#getting all the names first
import requests
from bs4 import BeautifulSoup

names_response = requests.get('http://feheroes.gamepedia.com/Hero_List')
names_content = names_response.content
soup = BeautifulSoup(names_content, 'html.parser')
sel_a = soup.select('.wikitable')
each_char = sel_a[0].find_all('tr')


names_list = []
for char in each_char:
    a_list = char.find_all('a')
    for a in a_list:
        if len(a.text) > 0:
            #print(a.text)
            names_list.append(a.text)
#this for loop prints all of the text associated with the links
#in the table. Fortunately, all the names are links, and all of the
#other links don't return anything for the .text property
#So all of the a.text that are greater than 0 are the names.

print(names_list)
# Out:
# ['Abel', 'Alfonse', 'Alm', 'Anna', 'Arthur', 'Azama', 'Azura', 'Barst', 'Bartre', 'Beruka', 'Bruno', 'Caeda', 'Cain', 'Camilla', 'Camilla (Spring Festival)', 'Camus', 'Catria', 'Cecilia', 'Cherche', 'Chrom', 'Chrom (Spring Festival)', 'Clair', 'Clarine', 'Cordelia', 'Corrin (F)', 'Corrin (M)', 'Donnel', 'Draug', 'Effie', 'Eirika', 'Eldigan', 'Elise', 'Eliwood', 'Ephraim', 'Est', 'Fae', 'Faye', 'Felicia', 'Fir', 'Florina', 'Frederick', 'Gaius', 'Gordin', 'Gunter', 'Gwendolyn', 'Hana', 'Hawkeye', 'Hector', 'Henry', 'Hinata', 'Hinoka', 'Ike', 'Jaffar', 'Jagen', 'Jakob', 'Jeorge', 'Julia', 'Kagero', 'Karel', 'Klein', 'Lachesis', 'Laslow', 'Leo', 'Lilina', 'Linde', 'Lissa', "Lon'qu", 'Lucina', 'Lucina (Spring Festival)', 'Lucius', 'Lukas', 'Lyn', 'Maria', 'Marth', 'Matthew', 'Merric', 'Michalis', 'Minerva', 'Mist', 'Narcian', 'Navarre', 'Niles', 'Ninian', 'Nino', 'Nowi', 'Oboro', 'Odin', 'Ogma', 'Olivia', 'Olwen', 'Palla', 'Peri', 'Priscilla', 'Raigh', 'Raven', 'Rebecca', 'Reinhardt', 'Robin (F)', 'Robin (M)', 'Roy', 'Ryoma', 'Saizo', 'Sakura', 'Sanaki', 'Selena', 'Seliph', 'Serra', 'Setsuna', 'Shanna', 'Sharena', 'Sheena', 'Sophia', 'Soren', 'Stahl', 'Subaki', 'Sully', 'Takumi', 'Tharja', 'Tiki (Adult)', 'Tiki (Young)', 'Titania', 'Ursula', 'Veronica', 'Virion', 'Wrys', 'Xander', 'Xander (Spring Festival)', 'Zephiel']

# %%
#change spaces to underscores in names_list so that it works for urls

names_fixed =[]
for name in names_list:
    a = name.replace(' ','_')
    names_fixed.append(a)
print(names_fixed)
# Out:
# ['Abel', 'Alfonse', 'Alm', 'Anna', 'Arthur', 'Azama', 'Azura', 'Barst', 'Bartre', 'Beruka', 'Bruno', 'Caeda', 'Cain', 'Camilla', 'Camilla_(Spring_Festival)', 'Camus', 'Catria', 'Cecilia', 'Cherche', 'Chrom', 'Chrom_(Spring_Festival)', 'Clair', 'Clarine', 'Cordelia', 'Corrin_(F)', 'Corrin_(M)', 'Donnel', 'Draug', 'Effie', 'Eirika', 'Eldigan', 'Elise', 'Eliwood', 'Ephraim', 'Est', 'Fae', 'Faye', 'Felicia', 'Fir', 'Florina', 'Frederick', 'Gaius', 'Gordin', 'Gunter', 'Gwendolyn', 'Hana', 'Hawkeye', 'Hector', 'Henry', 'Hinata', 'Hinoka', 'Ike', 'Jaffar', 'Jagen', 'Jakob', 'Jeorge', 'Julia', 'Kagero', 'Karel', 'Klein', 'Lachesis', 'Laslow', 'Leo', 'Lilina', 'Linde', 'Lissa', "Lon'qu", 'Lucina', 'Lucina_(Spring_Festival)', 'Lucius', 'Lukas', 'Lyn', 'Maria', 'Marth', 'Matthew', 'Merric', 'Michalis', 'Minerva', 'Mist', 'Narcian', 'Navarre', 'Niles', 'Ninian', 'Nino', 'Nowi', 'Oboro', 'Odin', 'Ogma', 'Olivia', 'Olwen', 'Palla', 'Peri', 'Priscilla', 'Raigh', 'Raven', 'Rebecca', 'Reinhardt', 'Robin_(F)', 'Robin_(M)', 'Roy', 'Ryoma', 'Saizo', 'Sakura', 'Sanaki', 'Selena', 'Seliph', 'Serra', 'Setsuna', 'Shanna', 'Sharena', 'Sheena', 'Sophia', 'Soren', 'Stahl', 'Subaki', 'Sully', 'Takumi', 'Tharja', 'Tiki_(Adult)', 'Tiki_(Young)', 'Titania', 'Ursula', 'Veronica', 'Virion', 'Wrys', 'Xander', 'Xander_(Spring_Festival)', 'Zephiel']

# %%
feh_df_list = []
for i, item in enumerate(names_fixed):
    response = requests.get('https://feheroes.wiki/{0}'.format(item))
    content = response.content
    parser = BeautifulSoup(content, 'html.parser')
    skills_table = parser.select('.skills-table')
    #print(i, len(skills_table))
    if i == 9:
        print(item)
        temp_headers = []
        temp_data = []
        for j in skills_table:
            headers = j.find_all('th')
            temp_hlist = []
            for k in headers:
                temp_hlist.append(k.text)
            temp_headers.append(temp_hlist)
            
            data = j.find_all('td')
            temp_dlist = []
            for l in data:
                temp_dlist.append(l.text)
            temp_data.append(temp_dlist)
        print(temp_headers)
        print(temp_data)
        #headers = skills_table[0].find_all('th')
        #data = skills_table[0].find_all('td')
        #for j in range(0, len(headers)):
        #    print(headers[j].text)
        #for j in range(0, len(data)):
        #    print(data[j].text)
# Out:
# Beruka
# [['Name', 'Might', 'Range', 'Effect', 'SP Cost', 'Default', 'Unlock'], ['Name', 'Cooldown', 'Effect', 'SP Cost', 'Default', 'Unlock'], ['Name', 'Effect', 'SP Cost', 'Unlock', 'Type']]
# [['Iron Axe', '6', '1', '-', '50', '-', '-', 'Steel Axe', '8', '1', '-', '100', '3', '-', 'Killer Axe', '7', '1', 'Accelerates Special trigger (cooldown count-1).', '200', '4', '3', 'Killer Axe+', '11', '1', 'Accelerates Special trigger (cooldown count-1).', '300', '5', '5'], ['Night Sky', '4', 'Grants +50% to damage dealt.', '100', '4', '3', 'Glimmer', '3', 'Grants +50% to damage dealt.', '200', '-', '4'], ['Defiant Def 1', "Grants Def+3 at start of turn if unit's HP ≤ 50%.", '40', '-', 'A', 'Defiant Def 2', "Grants Def+5 at start of turn if unit's HP ≤ 50%.", '80', '3', 'Defiant Def 3', "Grants Def+7 at start of turn if unit's HP ≤ 50%.", '160', '4', 'Lunge', 'If unit initiates attack, after combat, unit and targeted foe swap places.', '150', '3', 'B']]

# %%
import math
import pandas as pd

feh_hero_dict = {}
feh_weapons_dict = {}
feh_assits_dict = {}
feh_specials_dict = {}
feh_passives_dict = {}
for i, name in enumerate(names_fixed):
    response = requests.get('https://feheroes.wiki/{0}'.format(name))
    content = response.content
    parser = BeautifulSoup(content, 'html.parser')
    skills_table = parser.select('.skills-table')
    table_heads = []
    table_data = []
    dataframes = []
    
    for j in skills_table:
        headers = j.find_all('th')
        temp_hlist = []
        for k in headers:
            temp_hlist.append(k.text)
            
        data = j.find_all('td')
        temp_dlist = []
        for l in data:
            temp_dlist.append(l.text)
            
        table_heads.append(temp_hlist)
        table_data.append(temp_dlist)
        
    for index, each in enumerate(table_heads):
        if each[1] == 'Effect':
            intended_passive_total = math.ceil(len(table_data[index])/len(table_heads[index]))
            ipt = intended_passive_total
            #print(ipt)
            passive_fixed = table_data[index][:]
            for m in range(0, ipt):
                start = m * len(table_heads[index])
                end = ((m+1) * len(table_heads[index])) - 1
                #print('end: ', end)
                if m < 3:
                    current_type = table_data[index][4]
                elif m < 6 and m > 2:
                    current_type = table_data[index][17]
                elif m < 9 and m > 5:
                    current_type = table_data[index][30]
                #print(current_type)
                if end > len(passive_fixed) - 1:
                    passive_fixed.insert(end, current_type)
                elif passive_fixed[end] != current_type:
                    passive_fixed.insert(end, current_type)
            table_data[index] = passive_fixed
            #print(table_data[index])
            #print(passive_fixed)
    
    for index, item in enumerate(table_heads):
        #print(len(item), len(table_data[index]))
        #print(table_data[index])
        rows = []
        for i in range(0, int(len(table_data[index])/len(item))):
            temp_l = []
            start = i * len(item)
            for j in range(0, len(item)):
                current = start + j
                temp_l.append(table_data[index][current])
            rows.append(temp_l)
        #print(rows)
        df = pd.DataFrame(rows, columns=item)
        dataframes.append(df)
    #print(dataframes)
    feh_hero_dict[name] = dataframes
                
    

        
#print(feh_hero_dict.keys())
#print(feh_hero_dict.values())
#print(feh_hero_dict['Abel'][0])

for key, value in feh_hero_dict.items():
    print(key)
    print(value)
# Out:
# Ike
# [           Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3       Ragnell    16     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       -      -
# 3  Enables counterattack regardless of distance i...     400       5      -  ,        Name Cooldown                                             Effect  \
# 0  New Moon        3     Resolve combat as if foe suffered Def/Res-30%.
# 1      Luna        3     Resolve combat as if foe suffered Def/Res-50%.
# 2    Aether        5  Resolve combat as if foe suffered Def/Res-50%....
#
#   SP Cost Default Unlock
# 0     100       5      -
# 1     200       -      5
# 2     500       -      5  ,              Name                                             Effect SP Cost  \
# 0   Heavy Blade 1  If unit's Atk - foe's Atk ≥ 5, unit gains Spec...      60
# 1   Heavy Blade 2  If unit's Atk - foe's Atk ≥ 3, unit gains Spec...     120
# 2   Heavy Blade 3  If unit's Atk - foe's Atk ≥ 1, unit gains Spec...     240
# 3  Swordbreaker 1  If unit's HP ≥ 90% in combat against a sword u...      50
# 4  Swordbreaker 2  If unit's HP ≥ 70% in combat against a sword u...     100
# 5  Swordbreaker 3  If unit's HP ≥ 50% in combat against a sword u...     200
#
#   Unlock Type
# 0      -    A
# 1      -    A
# 2      5    A
# 3      -    B
# 4      -    B
# 5      5    B  ]
# Veronica
# [       Name Might Range                                             Effect  \
# 0  Élivágar    14     2  If unit initiates attack, bonuses on foes with...
#
#   SP Cost Default Unlock
# 0     400       -      -  ]
# Sheena
# [          Name Might Range                                           Effect  \
# 0     Iron Axe     6     1                                                -
# 1    Steel Axe     8     1                                                -
# 2   Killer Axe     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Axe+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       4      -
# 3     300       5      5  ,          Name Cooldown                                             Effect  \
# 0     Buckler        3  Reduces damage inflicted by attacks from adjac...
# 1  Escutcheon        2  Reduces damage inflicted by attacks from adjac...
#
#   SP Cost Default Unlock
# 0     100       4      -
# 1     200       -      4  ,              Name                                             Effect  \
# 0  Svalinn Shield           Neutralizes "effective against" bonuses.
# 1   Fortify Def 1  Grants adjacent allies Def+2 through their nex...
# 2               C                                      Fortify Def 2
# 3               -                                      Fortify Armor
#
#                                              SP Cost Unlock Type
# 0                                                200      4    A
# 1                                                 50      -    A
# 2  Grants adjacent allies Def+3 through their nex...    100    A
# 3  Grants adjacent armor allies Def/Res+6 through...    200    4  ]
# Gordin
# [         Name Might Range                                             Effect  \
# 0    Iron Bow     4     2                   Effective against flying units.
# 1   Steel Bow     6     2                   Effective against flying units.
# 2   Brave Bow     4     2  Spd-5. Effective against flying units. Attacks...
# 3  Brave Bow+     7     2  Spd-5. Effective against flying units. Attacks...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     300       5      5  ,     Name Range                                    Effect SP Cost Default  \
# 0  Shove     1  Push adjacent ally 1 space farther away.     150       4
#
#   Unlock
# 0      3  ,         Name                                             Effect SP Cost  \
# 0  Attack +1                                      Grants Atk+1.      30
# 1  Attack +2                                      Grants Atk+2.      60
# 2  Attack +3                                      Grants Atk+3.     120
# 3  Vantage 1  Unit counterattacks first when attacked at HP ...      50
# 4  Vantage 2  Unit counterattacks first when attacked at HP ...     100
# 5  Vantage 3  Unit counterattacks first when attacked at HP ...     200
#
#   Unlock Type
# 0      -    A
# 1      3    A
# 2      4    A
# 3      3    B
# 4      4    B
# 5      5    B  ]
# Wrys
# [      Name Might Range                                             Effect  \
# 0  Assault    10     2                                                  -
# 1     Slow     5     2  After any combat, inflicts Spd-6 on foe throug...
#
#   SP Cost Default Unlock
# 0      50       -      1
# 1     150       -      3  ,            Name Range                                             Effect  \
# 0          Heal     1                                     Restores 5 HP.
# 1     Reconcile     1        Restores 7 HP each to target and this unit.
# 2  Rehabilitate     1  Restores 7 HP or more the further below 50% th...
#
#   SP Cost Default Unlock
# 0       -       1      -
# 1     100       3      2
# 2     200       -      4  ,              Name Cooldown                                             Effect  \
# 0           Imbue        1  When healing an ally with a staff, increases r...
# 1  Heavenly Light        2  When healing an ally with a staff, all other a...
#
#   SP Cost Default Unlock
# 0      50       4      2
# 1     150       -      3  ,               Name                                             Effect SP Cost  \
# 0  Live to Serve 1  When healing allies with a staff, unit also re...      40
# 1  Live to Serve 2  When healing allies with a staff, unit also re...      80
# 2  Live to Serve 3  When healing allies with a staff, unit also re...     160
#
#   Unlock Type
# 0      3    B
# 1      4    B
# 2      5    B  ]
# Setsuna
# [              Name Might Range  \
# 0         Iron Bow     4     2
# 1        Steel Bow     6     2
# 2   Assassin's Bow     7     2
# 3  Assassin's Bow+    11     2
#
#                                               Effect SP Cost Default Unlock
# 0                   Effective against flying units.       50       -      -
# 1                   Effective against flying units.      100       3      -
# 2  Effective against flying units. If target has ...     200       4      3
# 3  Effective against flying units. If target has ...     300       5      5  ,              Name Range                                             Effect  \
# 0  Reciprocal Aid     1  Swap HP with adjacent ally (neither unit can g...
#
#   SP Cost Default Unlock
# 0     150       4      3  ,            Name                                             Effect SP Cost  \
# 0         HP +3                               Grants +3 to max HP.      40
# 1         HP +4                               Grants +4 to max HP.      80
# 2         HP +5                               Grants +5 to max HP.     160
# 3  Bowbreaker 1  If unit's HP ≥ 90% in combat against a bow use...      50
# 4  Bowbreaker 2  If unit's HP ≥ 70% in combat against a bow use...     100
# 5  Bowbreaker 3  If unit's HP ≥ 50% in combat against a bow use...     200
#
#   Unlock Type
# 0      3    A
# 1      4    A
# 2      5    A
# 3      -    B
# 4      3    B
# 5      4    B  ]
# Barst
# [         Name Might Range                                       Effect  \
# 0    Iron Axe     6     1                                            -
# 1   Steel Axe     8     1                                            -
# 2   Brave Axe     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Axe+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     300       -      5  ,          Name Range                                         Effect SP Cost  \
# 0  Reposition     1  Moves adjacent ally to opposite side of unit.     150
#
#   Default Unlock
# 0       4      3  ,          Name                                             Effect  \
# 0  Knock Back  If unit initiates attack, foe is moved 1 space...
# 1  Spur Atk 1        Grants adjacent allies Atk+2 during combat.
# 2           C                                         Spur Atk 2
# 3           3                                         Spur Atk 3
#
#                                        SP Cost Unlock Type
# 0                                          150      3    B
# 1                                           50      -    B
# 2  Grants adjacent allies Atk+3 during combat.    100    B
# 3  Grants adjacent allies Atk+4 during combat.    200    4  ]
# Camus
# [       Name Might Range                                             Effect  \
# 0  Gradivus    16     1  Enables counterattack regardless of distance i...
#
#   SP Cost Default Unlock
# 0     400       -      -  ]
# Raigh
# [         Name Might Range                            Effect SP Cost Default  \
# 0        Flux     4     2                                 -      50       2
# 1        Ruin     6     2                                 -     100       3
# 2   Rauðrwolf     6     2  Effective against cavalry units.     200       4
# 3  Rauðrwolf+    10     2  Effective against cavalry units.     300       -
#
#   Unlock
# 0      -
# 1      2
# 2      3
# 3      5  ,            Name Range                                             Effect  \
# 0  Rally Attack     1  Grants Atk+4 to an adjacent ally until the end...
#
#   SP Cost Default Unlock
# 0     150       4      3  ,          Name                                             Effect SP Cost  \
# 0       HP +3                               Grants +3 to max HP.      40
# 1       HP +4                               Grants +4 to max HP.      80
# 2       HP +5                               Grants +5 to max HP.     160
# 3  Seal Res 1  After combat, foe suffers Res-3 through its ne...      40
# 4  Seal Res 2  After combat, foe suffers Res-5 through its ne...      80
# 5  Seal Res 3  After combat, foe suffers Res-7 through its ne...     160
#
#   Unlock Type
# 0      3    A
# 1      4    A
# 2      5    A
# 3      -    B
# 4      2    B
# 5      4    B  ]
# Catria
# [            Name Might Range                                           Effect  \
# 0     Iron Lance     6     1                                                -
# 1    Steel Lance     8     1                                                -
# 2   Killer Lance     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Lance+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     300       5      5  ,        Name Cooldown                                          Effect SP Cost  \
# 0  New Moon        3  Resolve combat as if foe suffered Def/Res-30%.     100
# 1      Luna        3  Resolve combat as if foe suffered Def/Res-50%.     200
#
#   Default Unlock
# 0       4      -
# 1       -      4  ,              Name                                             Effect SP Cost  \
# 0  Armored Blow 1  Grants Def+2 during combat if unit initiates t...      50
# 1  Armored Blow 2  Grants Def+4 during combat if unit initiates t...     100
# 2  Armored Blow 3  Grants Def+6 during combat if unit initiates t...     200
# 3      Seal Atk 1  After combat, foe suffers Atk-3 through its ne...      40
# 4      Seal Atk 2  After combat, foe suffers Atk-5 through its ne...      80
# 5      Seal Atk 3  After combat, foe suffers Atk-7 through its ne...     160
#
#   Unlock Type
# 0      -    A
# 1      -    A
# 2      4    A
# 3      -    B
# 4      4    B
# 5      5    B  ]
# Ryoma
# [           Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3      Raijinto    16     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       -      -
# 3  Enables counterattack regardless of distance i...     400       5      -  ,         Name Cooldown                         Effect SP Cost Default Unlock
# 0  Night Sky        4   Grants +50% to damage dealt.     100       5      -
# 1      Astra        5  Grants +150% to damage dealt.     200       -      5,             Name                                             Effect SP Cost  \
# 0  Defiant Atk 1  Grants Atk+3 at start of turn if unit's HP ≤ 50%.      40
# 1  Defiant Atk 2  Grants Atk+5 at start of turn if unit's HP ≤ 50%.      80
# 2  Defiant Atk 3  Grants Atk+7 at start of turn if unit's HP ≤ 50%.     160
# 3     Hone Spd 1  Grants adjacent allies Spd+2 through their nex...      50
# 4     Hone Spd 2  Grants adjacent allies Spd+3 through their nex...     100
# 5     Hone Spd 3  Grants adjacent allies Spd+4 through their nex...     200
#
#   Unlock Type
# 0      -    A
# 1      -    A
# 2      5    A
# 3      -    C
# 4      -    C
# 5      5    C  ]
# Alfonse
# [           Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3     Fólkvangr    16     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       2      -
# 1                                                  -     100       -      2
# 2                                                  -     200       -      3
# 3  Grants Atk+5 at start of turn if unit's HP ≤ 50%.     400       -      5  ,        Name Cooldown                     Effect SP Cost Default Unlock
# 0  Daylight        4  Heal 30% of damage dealt.     100       2      -
# 1       Sol        4  Heal 50% of damage dealt.     200       -      4,            Name                                             Effect SP Cost  \
# 0  Death Blow 1  Grants Atk+2 during combat if unit initiates t...      50
# 1  Death Blow 2  Grants Atk+4 during combat if unit initiates t...     100
# 2  Death Blow 3  Grants Atk+6 during combat if unit initiates t...     200
# 3    Spur Atk 1        Grants adjacent allies Atk+2 during combat.      50
# 4    Spur Atk 2        Grants adjacent allies Atk+3 during combat.     100
# 5    Spur Atk 3        Grants adjacent allies Atk+4 during combat.     200
#
#   Unlock Type
# 0      1    A
# 1      2    A
# 2      4    A
# 3      3    C
# 4      4    C
# 5      5    C  ]
# Leo
# [        Name Might Range                                             Effect  \
# 0       Flux     4     2                                                  -
# 1       Ruin     6     2                                                  -
# 2     Fenrir     9     2                                                  -
# 3  Brynhildr    14     2  If unit initiates attack, restricts foe's next...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       -      -
# 3     400       5      -  ,             Name Cooldown                                             Effect  \
# 0   Rising Light        5  Before combat this unit initiates, foes in an ...
# 1  Blazing Light        5  Before combat this unit initiates, foes in an ...
#
#   SP Cost Default Unlock
# 0     150       5      -
# 1     300       -      5  ,               Name                                             Effect SP Cost  \
# 0  Quick Riposte 1  Unit automatically makes a follow-up attack if...      60
# 1  Quick Riposte 2  Unit automatically makes a follow-up attack if...     120
# 2  Quick Riposte 3  Unit automatically makes a follow-up attack if...     240
# 3    Savage Blow 1  If unit initiates attack, foes within 2 spaces...      50
# 4    Savage Blow 2  If unit initiates attack, foes within 2 spaces...     100
# 5    Savage Blow 3  If unit initiates attack, foes within 2 spaces...     200
#
#   Unlock Type
# 0      -    B
# 1      -    B
# 2      5    B
# 3      -    C
# 4      -    C
# 5      5    C  ]
# Fae
# [            Name Might Range  \
# 0    Fire Breath     6     1
# 1   Fire Breath+     8     1
# 2   Light Breath     9     1
# 3  Light Breath+    13     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2  Grants adjacent allies Def/Res+4 through their...     200       4      -
# 3  Grants adjacent allies Def/Res+4 through their...     300       5      5  ,         Name Range                                             Effect SP Cost  \
# 0  Draw Back     1  Unit moves 1 space away from target ally, who ...     150
#
#   Default Unlock
# 0       4      -  ,              Name                                             Effect SP Cost  \
# 0       Renewal 1  At the start of every fourth turn, restores 10...      60
# 1       Renewal 2  At the start of every third turn, restores 10 HP.     120
# 2       Renewal 3  At the start of every second turn, restores 10...     240
# 3  Threaten Atk 1  Inflicts Atk-3 on foes within 2 spaces through...      50
# 4  Threaten Atk 2  Inflicts Atk-4 on foes within 2 spaces through...     100
# 5  Threaten Atk 3  Inflicts Atk-5 on foes within 2 spaces through...     200
#
#   Unlock Type
# 0      -    B
# 1      -    B
# 2      4    B
# 3      -    C
# 4      4    C
# 5      5    C  ]
# Ursula
# [        Name Might Range                            Effect SP Cost Default  \
# 0    Thunder     4     2                                 -      50       -
# 1  Elthunder     6     2                                 -     100       3
# 2   Blárwolf     6     2  Effective against cavalry units.     200       4
# 3  Blárwolf+    10     2  Effective against cavalry units.     300       -
#
#   Unlock
# 0      -
# 1      -
# 2      3
# 3      5  ,               Name Cooldown  \
# 0   Rising Thunder        5
# 1  Growing Thunder        5
#
#                                               Effect SP Cost Default Unlock
# 0  Before combat this unit initiates, foes in an ...     150       4      3
# 1  Before combat this unit initiates, foes in a w...     300       -      4  ,              Name                                             Effect SP Cost  \
# 0    Death Blow 1  Grants Atk+2 during combat if unit initiates t...      50
# 1    Death Blow 2  Grants Atk+4 during combat if unit initiates t...     100
# 2    Death Blow 3  Grants Atk+6 during combat if unit initiates t...     200
# 3  Threaten Res 1  Inflicts Res-3 on foes within 2 spaces through...      50
# 4  Threaten Res 2  Inflicts Res-4 on foes within 2 spaces through...     100
# 5  Threaten Res 3  Inflicts Res-5 on foes within 2 spaces through...     200
#
#   Unlock Type
# 0      3    A
# 1      4    A
# 2      5    A
# 3      -    C
# 4      3    C
# 5      4    C  ]
# Fir
# [            Name Might Range                                           Effect  \
# 0     Iron Sword     6     1                                                -
# 1    Steel Sword     8     1                                                -
# 2   Killing Edge     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killing Edge+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     300       5      5  ,             Name Cooldown                                     Effect SP Cost  \
# 0  Chilling Wind        4  Boosts damage dealt by 50% of unit's Res.     100
# 1        Glacies        4  Boosts damage dealt by 80% of unit's Res.     200
#
#   Default Unlock
# 0       4      3
# 1       -      4  ,        Name                                            Effect SP Cost Unlock  \
# 0  Speed +1                                     Grants Spd+1.      30      -
# 1  Speed +2                                     Grants Spd+2.      60      3
# 2  Speed +3                                     Grants Spd+3.     120      4
# 3    Pass 1  Units can pass through foes if its own HP ≥ 75%.      50      3
# 4    Pass 2  Units can pass through foes if its own HP ≥ 50%.     100      4
# 5    Pass 3  Units can pass through foes if its own HP ≥ 25%.     200      5
#
#   Type
# 0    A
# 1    A
# 2    A
# 3    B
# 4    B
# 5    B  ]
# Lissa
# [      Name Might Range                                             Effect  \
# 0  Assault    10     2                                                  -
# 1  Gravity     6     2  After any combat, prevents foe from moving mor...
#
#   SP Cost Default Unlock
# 0      50       -      1
# 1     150       -      3  ,            Name Range                                             Effect  \
# 0          Heal     1                                     Restores 5 HP.
# 1     Reconcile     1        Restores 7 HP each to target and this unit.
# 2  Rehabilitate     1  Restores 7 HP or more the further below 50% th...
#
#   SP Cost Default Unlock
# 0       -       1      -
# 1     100       3      2
# 2     200       -      4  ,                 Name Cooldown  \
# 0              Imbue        1
# 1  Kindled-Fire Balm        1
#
#                                               Effect SP Cost Default Unlock
# 0  When healing an ally with a staff, increases r...      50       4      2
# 1  When healing an ally with a staff, grants all ...     150       -      3  ,         Name                                             Effect SP Cost  \
# 0  Renewal 1  At the start of every fourth turn, restores 10...      60
# 1  Renewal 2  At the start of every third turn, restores 10 HP.     120
# 2  Renewal 3  At the start of every second turn, restores 10...     240
#
#   Unlock Type
# 0      3    B
# 1      4    B
# 2      5    B  ]
# Mist
# [      Name Might Range                                             Effect  \
# 0  Assault    10     2                                                  -
# 1     Slow     5     2  After any combat, inflicts Spd-6 on foe throug...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     150       -      5  ,       Name Range                                             Effect SP Cost  \
# 0     Heal     1                                     Restores 5 HP.       -
# 1     Mend     1                                    Restores 10 HP.     100
# 2  Recover     1  Restores 15 HP.Slows Special trigger (cooldown...     200
#
#   Default Unlock
# 0       -      -
# 1       -      -
# 2       5      -  ,       Name Cooldown                                             Effect  \
# 0    Imbue        1  When healing an ally with a staff, increases r...
# 1  Miracle        5  If HP > 1, survive a lethal attack with 1 HP r...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     200       5      -  ,              Name                                            Effect SP Cost  \
# 0      Spur Res 1       Grants adjacent allies Res+2 during combat.      50
# 1  Spur Def Res 1   Grants adjacent allies Def/Res +2 during combat     120
# 2  Spur Def Res 2  Grants adjacent allies Def/Res +3 during combat.     240
#
#   Unlock Type
# 0      -    C
# 1      -    C
# 2      5    C  ]
# Narcian
# [           Name Might Range  \
# 0      Iron Axe     6     1
# 1     Steel Axe     8     1
# 2   Emerald Axe     8     1
# 3  Emerald Axe+    12     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       2      -
# 1                                                  -     100       3      2
# 2  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 3  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5  ,           Name Cooldown                                             Effect  \
# 0  Retribution        3  Grants bonus to damage dealt equal to 30% of d...
# 1    Vengeance        3  Grants bonus to damage dealt equal to 50% of d...
#
#   SP Cost Default Unlock
# 0     100       -      3
# 1     200       -      4  ,              Name                                             Effect SP Cost  \
# 0  Lancebreaker 1  If unit's HP ≥ 90% in combat against a lance u...      50
# 1  Lancebreaker 2  If unit's HP ≥ 70% in combat against a lance u...     100
# 2  Lancebreaker 3  If unit's HP ≥ 50% in combat against a lance u...     200
# 3   Savage Blow 1  If unit initiates attack, foes within 2 spaces...      50
# 4   Savage Blow 2  If unit initiates attack, foes within 2 spaces...     100
# 5   Savage Blow 3  If unit initiates attack, foes within 2 spaces...     200
#
#   Unlock Type
# 0      2    B
# 1      3    B
# 2      4    B
# 3      3    C
# 4      4    C
# 5      5    C  ]
# Cain
# [           Name Might Range                                       Effect  \
# 0    Iron Sword     6     1                                            -
# 1   Steel Sword     8     1                                            -
# 2   Brave Sword     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Sword+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       4      -
# 3     300       5      5  ,          Name Cooldown                                             Effect  \
# 0     Buckler        3  Reduces damage inflicted by attacks from adjac...
# 1  Escutcheon        2  Reduces damage inflicted by attacks from adjac...
#
#   SP Cost Default Unlock
# 0     100       4      -
# 1     200       -      4  ,                Name                                             Effect  \
# 0  Wings of Mercy 1  Enables unit to warp adjacent to any ally with...
# 1  Wings of Mercy 2  Enables unit to warp adjacent to any ally with...
# 2  Wings of Mercy 3  Enables unit to warp adjacent to any ally with...
# 3    Threaten Atk 1  Inflicts Atk-3 on foes within 2 spaces through...
# 4    Threaten Atk 2  Inflicts Atk-4 on foes within 2 spaces through...
# 5    Threaten Atk 3  Inflicts Atk-5 on foes within 2 spaces through...
#
#   SP Cost Unlock Type
# 0      60      -    B
# 1     120      -    B
# 2     240      4    B
# 3      50      -    C
# 4     100      4    C
# 5     200      5    C  ]
# Anna
# [         Name Might Range                                            Effect  \
# 0    Iron Axe     6     1                                                 -
# 1   Steel Axe     8     1                                                 -
# 2  Silver Axe    11     1                                                 -
# 3      Nóatún    16     1  Unit may move adjacent to any ally when HP ≤ 40%
#
#   SP Cost Default Unlock
# 0      50       2      -
# 1     100       -      2
# 2     200       -      3
# 3     400       -      5  ,         Name Cooldown                         Effect SP Cost Default Unlock
# 0  Night Sky        4   Grants +50% to damage dealt.     100       2      -
# 1      Astra        5  Grants +150% to damage dealt.     200       -      4,          Name                                             Effect SP Cost  \
# 0   Vantage 1  Unit counterattacks first when attacked at HP ...      50
# 1   Vantage 2  Unit counterattacks first when attacked at HP ...     100
# 2   Vantage 3  Unit counterattacks first when attacked at HP ...     200
# 3  Spur Res 1        Grants adjacent allies Res+2 during combat.      50
# 4  Spur Res 2        Grants adjacent allies Res+3 during combat.     100
# 5  Spur Res 3        Grants adjacent allies Res+4 during combat.     200
#
#   Unlock Type
# 0      3    B
# 1      4    B
# 2      5    B
# 3      -    C
# 4      2    C
# 5      4    C  ]
# Virion
# [          Name Might Range                            Effect SP Cost Default  \
# 0     Iron Bow     4     2  Effective against flying units.       50       1
# 1    Steel Bow     6     2  Effective against flying units.      100       3
# 2   Silver Bow     9     2  Effective against flying units.      200       4
# 3  Silver Bow+    13     2  Effective against flying units.      300       -
#
#   Unlock
# 0      -
# 1      2
# 2      3
# 3      5  ,         Name Cooldown                         Effect SP Cost Default Unlock
# 0  Night Sky        4   Grants +50% to damage dealt.     100       4      3
# 1      Astra        5  Grants +150% to damage dealt.     200       -      4,             Name                                             Effect SP Cost  \
# 0  Defiant Res 1  Grants Res+3 at start of turn if unit's HP ≤ 50%.      40
# 1  Defiant Res 2  Grants Res+5 at start of turn if unit's HP ≤ 50%.      80
# 2  Defiant Res 3  Grants Res+7 at start of turn if unit's HP ≤ 50%.     160
# 3     Seal Spd 1  After combat, foe suffers Spd-3 through its ne...      40
# 4     Seal Spd 2  After combat, foe suffers Spd-5 through its ne...      80
# 5     Seal Spd 3  After combat, foe suffers Spd-7 through its ne...     160
#
#   Unlock Type
# 0      3    A
# 1      4    A
# 2      5    A
# 3      1    B
# 4      2    B
# 5      4    B  ]
# Saizo
# [            Name Might Range  \
# 0    Iron Dagger     3     2
# 1   Steel Dagger     5     2
# 2   Smoke Dagger     6     2
# 3  Smoke Dagger+     9     2
#
#                                               Effect SP Cost Default Unlock
# 0  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 1  After combat, inflicts Def/Res-3 on foe throug...     100       3      -
# 2  After combat, inflicts Def/Res-4 on foes withi...     200       4      3
# 3  After combat, inflicts Def/Res-6 on foes withi...     300       -      5  ,             Name Range                                      Effect SP Cost  \
# 0  Harsh Command     1  Converts penalties on target into bonuses.     150
#
#   Default Unlock
# 0       4      3  ,               Name                                             Effect SP Cost  \
# 0  Poison Strike 1  Inflicts 4 damage to foe after any combat this...      60
# 1  Poison Strike 2  Inflicts 7 damage to foe after any combat this...     120
# 2  Poison Strike 3  Inflicts 10 damage to foe after any combat thi...     240
# 3       Spur Spd 1        Grants adjacent allies Spd+2 during combat.      50
# 4       Spur Spd 2        Grants adjacent allies Spd+3 during combat.     100
# 5       Spur Spd 3        Grants adjacent allies Spd+4 during combat.     200
#
#   Unlock Type
# 0      -    B
# 1      3    B
# 2      4    B
# 3      3    C
# 4      4    C
# 5      5    C  ]
# Tiki_(Young)
# [           Name Might Range Effect SP Cost Default Unlock
# 0   Fire Breath     6     1      -      50       -      -
# 1  Fire Breath+     8     1      -     100       -      -
# 2   Flametongue    11     1      -     200       -      -
# 3  Flametongue+    15     1      -     300       5      -,             Name Cooldown                                             Effect  \
# 0   Rising Flame        5  Before combat this unit initiates, foes in an ...
# 1  Growing Flame        5  Before combat this unit initiates, foes in a w...
#
#   SP Cost Default Unlock
# 0     150       5      -
# 1     300       -      5  ,                Name                                             Effect  \
# 0    Armored Blow 1  Grants Def+2 during combat if unit initiates t...
# 1    Armored Blow 2  Grants Def+4 during combat if unit initiates t...
# 2    Armored Blow 3  Grants Def+6 during combat if unit initiates t...
# 3  Breath of Life 1  If unit initiates attack, adjacent allies reco...
# 4  Breath of Life 2  If unit initiates attack, adjacent allies reco...
# 5  Breath of Life 3  If unit initiates attack, adjacent allies reco...
#
#   SP Cost Unlock Type
# 0      50      -    A
# 1     100      -    A
# 2     200      5    A
# 3      50      -    C
# 4     100      -    C
# 5     200      5    C  ]
# Shanna
# [            Name Might Range                                           Effect  \
# 0     Iron Lance     6     1                                                -
# 1    Steel Lance     8     1                                                -
# 2   Killer Lance     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Lance+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     300       -      5  ,             Name Cooldown                                     Effect SP Cost  \
# 0  Chilling Wind        4  Boosts damage dealt by 50% of unit's Res.     100
# 1        Iceberg        3  Boosts damage dealt by 50% of unit's Res.     200
#
#   Default Unlock
# 0       4      3
# 1       -      4  ,              Name                                             Effect SP Cost  \
# 0   Desperation 1  If unit initiates combat with HP ≤ 25%, follow...      50
# 1   Desperation 2  If unit initiates combat with HP ≤ 50%, follow...     100
# 2   Desperation 3  If unit initiates combat with HP ≤ 75%, follow...     200
# 3  Threaten Spd 1  Inflicts Spd-3 on foes within 2 spaces through...      50
# 4  Threaten Spd 2  Inflicts Spd-4 on foes within 2 spaces through...     100
# 5  Threaten Spd 3  Inflicts Spd-5 on foes within 2 spaces through...     200
#
#   Unlock Type
# 0      -    B
# 1      3    B
# 2      4    B
# 3      3    C
# 4      4    C
# 5      5    C  ]
# Abel
# [           Name Might Range                                       Effect  \
# 0    Iron Lance     6     1                                            -
# 1   Steel Lance     8     1                                            -
# 2   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       4      -
# 3     300       5      5  ,              Name Cooldown                                             Effect  \
# 0  Holy Vestments        3  Reduces damage inflicted by attacks from foes ...
# 1           Aegis        3  Reduces damage inflicted by attacks from foes ...
#
#   SP Cost Default Unlock
# 0     100       4      -
# 1     200       -      4  ,              Name                                             Effect SP Cost  \
# 0           HP +3                               Grants +3 to max HP.      40
# 1           HP +4                               Grants +4 to max HP.      80
# 2           HP +5                               Grants +5 to max HP.     160
# 3  Swordbreaker 1  If unit's HP ≥ 90% in combat against a sword u...      50
# 4  Swordbreaker 2  If unit's HP ≥ 70% in combat against a sword u...     100
# 5  Swordbreaker 3  If unit's HP ≥ 50% in combat against a sword u...     200
#
#   Unlock Type
# 0      -    A
# 1      4    A
# 2      5    A
# 3      -    B
# 4      -    B
# 5      4    B  ]
# Laslow
# [            Name Might Range Effect SP Cost Default Unlock
# 0     Iron Sword     6     1      -      50       -      -
# 1    Steel Sword     8     1      -     100       3      -
# 2   Silver Sword    11     1      -     200       4      3
# 3  Silver Sword+    15     1      -     300       -      5,        Name Cooldown                     Effect SP Cost Default Unlock
# 0  Daylight        4  Heal 30% of damage dealt.     100       4      3
# 1  Noontime        3  Heal 30% of damage dealt.     200       -      4,            Name                                             Effect SP Cost  \
# 0  Axebreaker 1  If unit's HP ≥ 90% in combat against an axe us...      50
# 1  Axebreaker 2  If unit's HP ≥ 70% in combat against an axe us...     100
# 2  Axebreaker 3  If unit's HP ≥ 50% in combat against an axe us...     200
# 3    Hone Spd 1  Grants adjacent allies Spd+2 through their nex...      50
# 4    Hone Spd 2  Grants adjacent allies Spd+3 through their nex...     100
# 5    Hone Spd 3  Grants adjacent allies Spd+4 through their nex...     200
#
#   Unlock Type
# 0      -    B
# 1      3    B
# 2      4    B
# 3      3    C
# 4      4    C
# 5      5    C  ]
# Sully
# [              Name Might Range  \
# 0       Iron Lance     6     1
# 1      Steel Lance     8     1
# 2   Sapphire Lance     8     1
# 3  Sapphire Lance+    12     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       1      -
# 1                                                  -     100       3      2
# 2  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 3  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5  ,         Name Range                                             Effect SP Cost  \
# 0  Draw Back     1  Unit moves 1 space away from target ally, who ...     150
#
#   Default Unlock
# 0       4      3  ,              Name                                             Effect SP Cost  \
# 0  Swordbreaker 1  If unit's HP ≥ 90% in combat against a sword u...      50
# 1  Swordbreaker 2  If unit's HP ≥ 70% in combat against a sword u...     100
# 2  Swordbreaker 3  If unit's HP ≥ 50% in combat against a sword u...     200
# 3      Spur Def 1        Grants adjacent allies Def+2 during combat.      50
# 4      Spur Def 2        Grants adjacent allies Def+3 during combat.     100
# 5      Spur Def 3        Grants adjacent allies Def+4 during combat.     200
#
#   Unlock Type
# 0      -    B
# 1      4    B
# 2      5    B
# 3      -    C
# 4      -    C
# 5      4    C  ]
# Azama
# [      Name Might Range                                            Effect  \
# 0  Assault    10     2                                                 -
# 1     Pain     3     2  Inflicts 10 damage on targeted foe after combat.
#
#   SP Cost Default Unlock
# 0      50       -      3
# 1     150       -      3  ,         Name Range                                             Effect SP Cost  \
# 0       Heal     1                                     Restores 5 HP.       -
# 1  Reconcile     1        Restores 7 HP each to target and this unit.     100
# 2     Martyr     1  Restores HP=7+ this unit's suffered damage.Uni...     200
#
#   Default Unlock
# 0       3      -
# 1       3      -
# 2       -      4  ,                Name Cooldown  \
# 0             Imbue        1
# 1  Solid-Earth Balm        1
#
#                                               Effect SP Cost Default Unlock
# 0  When healing an ally with a staff, increases r...      50       -      3
# 1  When healing an ally with a staff, grants all ...     150       -      3  ,              Name                                             Effect SP Cost  \
# 0  Threaten Atk 1  Inflicts Atk-3 on foes within 2 spaces through...      50
# 1  Threaten Atk 2  Inflicts Atk-4 on foes within 2 spaces through...     100
# 2  Threaten Atk 3  Inflicts Atk-5 on foes within 2 spaces through...     200
#
#   Unlock Type
# 0      3    C
# 1      4    C
# 2      5    C  ]
# Merric
# [         Name Might Range                            Effect SP Cost Default  \
# 0        Wind     4     2                                 -      50       -
# 1      Elwind     6     2                                 -     100       -
# 2  Rexcalibur     9     2                                 -     200       4
# 3   Excalibur    14     2  Effective against flying units.      400       5
#
#   Unlock
# 0      -
# 1      -
# 2      -
# 3      5  ,            Name Cooldown                                             Effect  \
# 0   Rising Wind        5  Before combat this unit initiates, foes in an ...
# 1  Growing Wind        5  Before combat this unit initiates, foes in a w...
#
#   SP Cost Default Unlock
# 0     150       4      -
# 1     300       -      4  ,          Name                                       Effect SP Cost Unlock Type
# 0       HP +3                         Grants +3 to max HP.      40      -    A
# 1       HP +4                         Grants +4 to max HP.      80      4    A
# 2       HP +5                         Grants +5 to max HP.     160      5    A
# 3  Spur Res 1  Grants adjacent allies Res+2 during combat.      50      -    C
# 4  Spur Res 2  Grants adjacent allies Res+3 during combat.     100      -    C
# 5  Spur Res 3  Grants adjacent allies Res+4 during combat.     200      4    C]
# Tiki_(Adult)
# [                Name Might Range  \
# 0        Fire Breath     6     1
# 1       Fire Breath+     8     1
# 2   Lightning Breath     7     1
# 3  Lightning Breath+    11     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       -      -
# 1                                                  -     100       3      -
# 2  Enables counterattack regardless of attacker's...     200       4      3
# 3  Enables counterattack regardless of attacker's...     300       5      5  ,             Name Cooldown                                     Effect SP Cost  \
# 0  Glowing Ember        4  Boosts damage dealt by 50% of unit's Def.     100
# 1        Bonfire        3  Boosts damage dealt by 50% of unit's Def.     200
#
#   Default Unlock
# 0       4      3
# 1       -      4  ,             Name                                             Effect SP Cost  \
# 0  Defiant Atk 1  Grants Atk+3 at start of turn if unit's HP ≤ 50%.      40
# 1  Defiant Atk 2  Grants Atk+5 at start of turn if unit's HP ≤ 50%.      80
# 2  Defiant Atk 3  Grants Atk+7 at start of turn if unit's HP ≤ 50%.     160
# 3     Spur Res 1        Grants adjacent allies Res+2 during combat.      50
# 4     Spur Res 2        Grants adjacent allies Res+3 during combat.     100
# 5     Spur Res 3        Grants adjacent allies Res+4 during combat.     200
#
#   Unlock Type
# 0      -    A
# 1      3    A
# 2      4    A
# 3      3    C
# 4      4    C
# 5      5    C  ]
# Hector
# [         Name Might Range                                             Effect  \
# 0    Iron Axe     6     1                                                  -
# 1   Steel Axe     8     1                                                  -
# 2  Silver Axe    11     1                                                  -
# 3      Armads    16     1  Unit makes a guaranteed follow-up attack when ...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       -      -
# 3     400       5      -  ,       Name Cooldown                                             Effect  \
# 0  Buckler        3  Reduces damage inflicted by attacks from adjac...
# 1   Pavise        3  Reduces damage inflicted by attacks from adjac...
#
#   SP Cost Default Unlock
# 0     100       5      -
# 1     200       -      5  ,               Name                                             Effect  \
# 0  Distant Counter  Enables unit to counterattack regardless of di...
# 1       Spur Atk 1        Grants adjacent allies Atk+2 during combat.
# 2                C                                         Spur Atk 2
# 3                -                                         Goad Armor
#
#                                              SP Cost Unlock Type
# 0                                                300      5    A
# 1                                                 50      -    A
# 2        Grants adjacent allies Atk+3 during combat.    100    A
# 3  Grants armored allies within 2 spaces Spd/Atk+...    200    5  ]
# Chrom_(Spring_Festival)
# [          Name Might Range                                             Effect  \
# 0     Iron Axe     6     1                                                  -
# 1    Steel Axe     8     1                                                  -
# 2   Carrot Axe     9     1  If unit initiates attack, unit recovers 4 HP a...
# 3  Carrot Axe+    13     1  If unit initiates attack, unit recovers 4 HP a...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       -      -
# 3     300       5      -  ,     Name Range                                    Effect SP Cost Default  \
# 0  Shove     1  Push adjacent ally 1 space farther away.     150       5
#
#   Unlock
# 0      -  ,                Name                                             Effect  \
# 0        Defense +1                                      Grants Def+1.
# 1     Attack Def +1                                  Grants Atk/Def+1.
# 2     Attack Def +2                                  Grants Atk/Def+2.
# 3  Axe Experience 1  If unit survives, unit gets 1.5x EXP.(If simil...
# 4  Axe Experience 2  If unit survives, all axe users on team get 1....
# 5  Axe Experience 3  If unit survives, all axe users on team get 2x...
#
#   SP Cost Unlock Type
# 0      30      -    A
# 1      80      -    A
# 2     160      5    A
# 3      50      -    C
# 4     100      -    C
# 5     200      5    C  ]
# Robin_(M)
# [         Name Might Range                                       Effect  \
# 0     Thunder     4     2                                            -
# 1   Elthunder     6     2                                            -
# 2   Blárraven     7     2  Grants weapon advantage vs. colorless foes.
# 3  Blárraven+    11     2  Grants weapon advantage vs. colorless foes.
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     300       5      5  ,             Name Cooldown                                     Effect SP Cost  \
# 0  Glowing Ember        4  Boosts damage dealt by 50% of unit's Def.     100
# 1        Bonfire        3  Boosts damage dealt by 50% of unit's Def.     200
#
#   Default Unlock
# 0       4      3
# 1       -      4  ,             Name                                             Effect SP Cost  \
# 0  Defiant Spd 1  Grants Spd+3 at start of turn if unit's HP ≤ 50%.      40
# 1  Defiant Spd 2  Grants Spd+5 at start of turn if unit's HP ≤ 50%.      80
# 2  Defiant Spd 3  Grants Spd+7 at start of turn if unit's HP ≤ 50%.     160
# 3     Spur Def 1        Grants adjacent allies Def+2 during combat.      50
# 4     Spur Def 2        Grants adjacent allies Def+3 during combat.     100
# 5     Spur Def 3        Grants adjacent allies Def+4 during combat.     200
#
#   Unlock Type
# 0      3    A
# 1      4    A
# 2      5    A
# 3      -    C
# 4      3    C
# 5      4    C  ]
# Lukas
# [            Name Might Range                                           Effect  \
# 0     Iron Lance     6     1                                                -
# 1    Steel Lance     8     1                                                -
# 2   Killer Lance     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Lance+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       4      -
# 3     300       5      -  ,              Name Cooldown                                             Effect  \
# 0  Holy Vestments        3  Reduces damage inflicted by attacks from foes ...
# 1     Sacred Cowl        2  Reduces damage inflicted by attacks from foes ...
#
#   SP Cost Default Unlock
# 0     100       4      -
# 1     200       -      4  ,              Name                                             Effect SP Cost  \
# 0  Fortress Def 1                       Grants Def+3.Inflicts Atk-3.      40
# 1  Fortress Def 2                       Grants Def+4.Inflicts Atk-3.      80
# 2  Fortress Def 3                       Grants Def+5.Inflicts Atk-3.     160
# ...
# 0  Hone Atk 1  Grants adjacent allies Atk+2 through their nex...      50
# 1  Hone Atk 2  Grants adjacent allies Atk+3 through their nex...     100
# 2  Hone Atk 3  Grants adjacent allies Atk+4 through their nex...     200
#
#   Unlock Type
# 0      3    C
# 1      4    C
# 2      5    C  ]
# Robin_(F)
# [         Name Might Range                            Effect SP Cost Default  \
# 0        Wind     4     2                                 -      50       2
# 1      Elwind     6     2                                 -     100       3
# 2   Gronnwolf     6     2  Effective against cavalry units.     200       4
# 3  Gronnwolf+    10     2  Effective against cavalry units.     300       -
#
#   Unlock
# 0      -
# 1      2
# 2      3
# 3      5  ,             Name Cooldown                                     Effect SP Cost  \
# 0  Glowing Ember        4  Boosts damage dealt by 50% of unit's Def.     100
# 1          Ignis        4  Boosts damage dealt by 80% of unit's Def.     200
#
#   Default Unlock
# 0       -      3
# 1       -      4  ,               Name                                             Effect SP Cost  \
# 0    Defiant Res 1  Grants Res+3 at start of turn if unit's HP ≤ 50%.      40
# 1    Defiant Res 2  Grants Res+5 at start of turn if unit's HP ≤ 50%.      80
# 2    Defiant Res 3  Grants Res+7 at start of turn if unit's HP ≤ 50%.     160
# 3  B Tomebreaker 1  If unit's HP ≥ 90% in combat against a blue to...      50
# 4  B Tomebreaker 2  If unit's HP ≥ 70% in combat against a blue to...     100
# 5  B Tomebreaker 3  If unit's HP ≥ 50% in combat against a blue to...     200
#
#   Unlock Type
# 0      3    A
# 1      4    A
# 2      5    A
# 3      2    B
# 4      3    B
# 5      4    B  ]
# Clair
# [            Name Might Range Effect SP Cost Default Unlock
# 0     Iron Lance     6     1      -      50       -      -
# 1    Steel Lance     8     1      -     100       -      -
# 2   Silver Lance    11     1      -     200       4      -
# 3  Silver Lance+    15     1      -     300       5      -,             Name Range                                      Effect SP Cost  \
# 0  Harsh Command     1  Converts penalties on target into bonuses.     150
#
#   Default Unlock
# 0       4      -  ,           Name                                             Effect  \
# 0  Hit and Run  If unit initiates attack, unit retreats 1 spac...
# 1   Spur Spd 1        Grants adjacent allies Spd+2 during combat.
# 2            C                                         Spur Spd 2
# 3            4                                         Spur Spd 3
#
#                                        SP Cost Unlock Type
# 0                                          150      4    B
# 1                                           50      -    B
# 2  Grants adjacent allies Spd+3 during combat.    100    B
# 3  Grants adjacent allies Spd+4 during combat.    200    5  ]
# Linde
# [        Name Might Range                                             Effect  \
# 0    Thunder     4     2                                                  -
# 1  Elthunder     6     2                                                  -
# 2     Thoron     9     2                                                  -
# 3       Aura    14     2  Restores 5 HP to adjacent allies after any com...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       -      -
# 3     400       5      -  ,                Name Range                                             Effect  \
# 0  Ardent Sacrifice     1  Heals adjacent ally 10 HP.Unit loses 10 HP (bu...
#
#   SP Cost Default Unlock
# 0     150       5      -  ,             Name                                             Effect SP Cost  \
# 0       Speed +1                                      Grants Spd+1.      30
# 1       Speed +2                                      Grants Spd+2.      60
# 2       Speed +3                                      Grants Spd+3.     120
# 3  Fortify Res 1  Grants adjacent allies Res+2 through their nex...      50
# 4  Fortify Res 2  Grants adjacent allies Res+3 through their nex...     100
# 5  Fortify Res 3  Grants adjacent allies Res+4 through their nex...     200
#
#   Unlock Type
# 0      -    A
# 1      -    A
# 2      5    A
# 3      -    C
# 4      -    C
# 5      5    C  ]
# Est
# [           Name Might Range                             Effect SP Cost  \
# 0    Iron Lance     6     1                                  -      50
# 1   Steel Lance     8     1                                  -     100
# 2   Heavy Spear     8     1  Effective against armored units.      200
# 3  Heavy Spear+    12     1  Effective against armored units.      300
#
#   Default Unlock
# 0       -      -
# 1       3      -
# 2       4      3
# 3       -      5  ,     Name Range                                    Effect SP Cost Default  \
# 0  Shove     1  Push adjacent ally 1 space farther away.     150       4
#
#   Unlock
# 0      3  ,             Name                                             Effect SP Cost  \
# 0  Defiant Res 1  Grants Res+3 at start of turn if unit's HP ≤ 50%.      40
# 1  Defiant Res 2  Grants Res+5 at start of turn if unit's HP ≤ 50%.      80
# 2  Defiant Res 3  Grants Res+7 at start of turn if unit's HP ≤ 50%.     160
# 3     Seal Spd 1  After combat, foe suffers Spd-3 through its ne...      40
# 4     Seal Spd 2  After combat, foe suffers Spd-5 through its ne...      80
# 5     Seal Spd 3  After combat, foe suffers Spd-7 through its ne...     160
#
#   Unlock Type
# 0      -    A
# 1      3    A
# 2      4    A
# 3      3    B
# 4      4    B
# 5      5    B  ]
# Niles
# [          Name Might Range                                             Effect  \
# 0     Iron Bow     4     2                   Effective against flying units.
# 1    Steel Bow     6     2                   Effective against flying units.
# 2   Killer Bow     5     2  Effective against flying units. Accelerates Sp...
# 3  Killer Bow+     9     2  Effective against flying units. Accelerates Sp...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     300       -      5  ,             Name Cooldown                                     Effect SP Cost  \
# 0  Chilling Wind        4  Boosts damage dealt by 50% of unit's Res.     100
# 1        Iceberg        3  Boosts damage dealt by 50% of unit's Res.     200
#
#   Default Unlock
# 0       4      3
# 1       -      4  ,              Name                                             Effect SP Cost  \
# 0  Warding Blow 1  Grants Res+2 during combat if unit initiates a...      50
# 1  Warding Blow 2  Grants Res+4 during combat if unit initiates a...     100
# 2  Warding Blow 3  Grants Res+6 during combat if unit initiates a...     200
# 3      Spur Res 1        Grants adjacent allies Res+2 during combat.      50
# 4      Spur Res 2        Grants adjacent allies Res+3 during combat.     100
# 5      Spur Res 3        Grants adjacent allies Res+4 during combat.     200
#
#   Unlock Type
# 0      -    A
# 1      3    A
# 2      4    A
# 3      3    C
# 4      4    C
# 5      5    C  ]
# Zephiel
# [           Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3     Eckesachs    16     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       -      -
# 1                                                  -     100       3      -
# 2                                                  -     200       4      3
# 3  Inflicts Def-4 on foes within 2 spaces through...     400       -      5  ,           Name Cooldown                                             Effect  \
# 0  Retribution        3  Grants bonus to damage dealt equal to 30% of d...
# 1     Reprisal        2  Grants bonus to damage dealt equal to 30% of d...
#
#   SP Cost Default Unlock
# 0     100       4      3
# 1     200       -      4  ,                Name                                             Effect  \
# 0  Life and Death 1               Grants Atk/Spd+3.Inflicts Def/Res-3.
# 1  Life and Death 2               Grants Atk/Spd+4.Inflicts Def/Res-4.
# 2  Life and Death 3               Grants Atk/Spd+5.Inflicts Def/Res-5.
# 3    Wary Fighter 1  Prevents follow-up attacks in combat from unit...
# 4    Wary Fighter 2  Prevents follow-up attacks in combat from unit...
# 5    Wary Fighter 3  Prevents follow-up attacks in combat from unit...
#
#   SP Cost Unlock Type
# 0      50      -    A
# 1     100      4    A
# 2     200      5    A
# 3      60      -    B
# 4     120      -    B
# 5     240      4    B  ]
# Takumi
# [         Name Might Range                                             Effect  \
# 0    Iron Bow     4     2                   Effective against flying units.
# 1   Steel Bow     6     2                   Effective against flying units.
# 2  Silver Bow     9     2                   Effective against flying units.
# 3  Fujin Yumi    14     2  Effective against flying units. Unit can pass ...
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       -      -
# 3     400       5      -  ,           Name Cooldown                                             Effect  \
# 0  Retribution        3  Grants bonus to damage dealt equal to 30% of d...
# 1    Vengeance        3  Grants bonus to damage dealt equal to 50% of d...
#
#   SP Cost Default Unlock
# 0     100       5      -
# 1     200       -      5  ,              Name                                             Effect  \
# 0   Close Counter  Enables unit to counterattack regardless of di...
# 1  Threaten Spd 1  Inflicts Spd-3 on foes within 2 spaces through...
# 2               C                                     Threaten Spd 2
# 3               -                                     Threaten Spd 3
#
#                                              SP Cost Unlock Type
# 0                                                300      5    A
# 1                                                 50      -    A
# 2  Inflicts Spd-4 on foes within 2 spaces through...    100    A
# 3  Inflicts Spd-5 on foes within 2 spaces through...    200    5  ]
# Michalis
# [         Name Might Range                                           Effect  \
# 0    Iron Axe     6     1                                                -
# 1   Steel Axe     8     1                                                -
# 2  Silver Axe    11     1                                                -
# 3  Hauteclere    16     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     400       -      5  ,               Name Cooldown  \
# 0   Rising Thunder        5
# 1  Blazing Thunder        5
#
#                                               Effect SP Cost Default Unlock
# 0  Before combat this unit initiates, foes in an ...     150       4      3
# 1  Before combat this unit initiates, foes in an ...     300       -      4  ,              Name                                             Effect  \
# 0   Iote's Shield           Neutralizes "effective against" bonuses.
# 1  Threaten Def 1  Inflicts Def-3 on foes within 2 spaces through...
# 2               C                                     Threaten Def 2
# 3               3                                     Threaten Def 3
#
#                                              SP Cost Unlock Type
# 0                                                200      4    A
# 1                                                 50      -    A
# 2  Inflicts Def-4 on foes within 2 spaces through...    100    A
# 3  Inflicts Def-5 on foes within 2 spaces through...    200    4  ]
# Alm
# [           Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3      Falchion    16     1
#
#                                               Effect SP Cost Default Unlock
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       -      -
# 3  Effective against dragons. At the start of eve...     400       5      -  ,             Name Cooldown               Effect SP Cost Default Unlock
# 0    Dragon Gaze        4  Grants +30% to Atk.     100       5      -
# 1  Draconic Aura        3  Grants +30% to Atk.     200       -      5,           Name                                             Effect SP Cost  \
# 0    Attack +1                                      Grants Atk+1.      30
# 1    Attack +2                                      Grants Atk+2.      60
# 2    Attack +3                                      Grants Atk+3.     120
# 3  Windsweep 1  If unit initiates attack, no follow-up occurs....      60
# 4  Windsweep 2  If unit initiates attack, no follow-up occurs....     120
# 5  Windsweep 3  If unit initiates attack, no follow-up occurs....     240
#
#   Unlock Type
# 0      -    A
# 1      -    A
# 2      5    A
# 3      -    B
# 4      -    B
# 5      5    B  ]
# Olwen
# [           Name Might Range                                       Effect  \
# 0       Thunder     4     2                                            -
# 1     Elthunder     6     2                                            -
# 2        Thoron     9     2                                            -
# 3  Dire Thunder     9     2  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       -      -
# 3     400       5      -  ,          Name Range                                         Effect SP Cost  \
# 0  Reposition     1  Moves adjacent ally to opposite side of unit.     150
#
#   Default Unlock
# 0       5      -  ,              Name                                             Effect SP Cost  \
# 0  Warding Blow 1  Grants Res+2 during combat if unit initiates a...      50
# 1  Warding Blow 2  Grants Res+4 during combat if unit initiates a...     100
# 2  Warding Blow 3  Grants Res+6 during combat if unit initiates a...     200
# 3      Spur Res 1        Grants adjacent allies Res+2 during combat.      50
# 4      Spur Res 2        Grants adjacent allies Res+3 during combat.     100
# 5    Ward Cavalry  Grants cavalry allies within 2 spaces Def/Res+...     200
#
#   Unlock Type
# 0      -    A
# 1      -    A
# 2      5    A
# 3      -    C
# 4      -    C
# 5      5    C  ]
# Beruka
# [          Name Might Range                                           Effect  \
# 0     Iron Axe     6     1                                                -
# 1    Steel Axe     8     1                                                -
# 2   Killer Axe     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Axe+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       3      -
# 2     200       4      3
# 3     300       5      5  ,         Name Cooldown                        Effect SP Cost Default Unlock
# 0  Night Sky        4  Grants +50% to damage dealt.     100       4      3
# 1    Glimmer        3  Grants +50% to damage dealt.     200       -      4,             Name                                             Effect SP Cost  \
# 0  Defiant Def 1  Grants Def+3 at start of turn if unit's HP ≤ 50%.      40
# 1  Defiant Def 2  Grants Def+5 at start of turn if unit's HP ≤ 50%.      80
# 2  Defiant Def 3  Grants Def+7 at start of turn if unit's HP ≤ 50%.     160
# 3          Lunge  If unit initiates attack, after combat, unit a...     150
#
#   Unlock Type
# 0      -    A
# 1      3    A
# 2      4    A
# 3      3    B  ]

# %%
#now that all the tables are created and linked to the hero in a dictionary, I can go through each key in the dict
#and make four complete dataframes, weapons, specials, assits, and passives.

# %%
#print(feh_hero_dict['Abel'][0].columns)
#for i in feh_hero_dict['Abel'][0].columns:
#    print(i)

count = 0
for key, value in feh_hero_dict.items():
    if count < 1:
        print(key)
        for each in value:
            print(each.columns[1])
        for each in value:
            print(each.shape)
    count += 1
# Out:
# Ike
# Might
# Cooldown
# Effect
# (4, 7)
# (3, 6)
# (6, 5)

# %%
def sorted_dataframes(feh_dict):
    weapons = []
    assists = []
    specials = []
    passives = []
    count = 0
    for key, value in feh_dict.items():
        for each in value:
            if each.columns[1] == 'Might':
                #print(each.shape[0])
                #print(each)
                key_list = []
                for i in range(0, each.shape[0]):
                    key_list.append(key)
                #print(key_list)
                new_add = each.copy()
                new_add['Hero'] = key_list
                weapons.append(new_add)
            elif each.columns[1] == 'Range':
                key_list = []
                for i in range(0, each.shape[0]):
                    key_list.append(key)
                new_add = each.copy()
                new_add['Hero'] = key_list
                assists.append(new_add)
            elif each.columns[1] == 'Cooldown':
                key_list = []
                for i in range(0, each.shape[0]):
                    key_list.append(key)
                new_add = each.copy()
                new_add['Hero'] = key_list
                specials.append(new_add)
            elif each.columns[1] == 'Effect':
                key_list = []
                for i in range(0, each.shape[0]):
                    key_list.append(key)
                new_add = each.copy()
                new_add['Hero'] = key_list
                passives.append(new_add)
        #print(weapons)
        character_info = []
        if len(weapons) > 0:
            character_info.append(weapons)
        if len(assists) > 0:
            character_info.append(assists)
        if len(specials) > 0:
            character_info.append(specials)
        if len(passives) > 0:
            character_info.append(passives)
        
        #count += 1
        #if count > 0:
        #    break
            
    return(character_info)

                
#add each dataframe to the respective list, also add a new column and fill the column with the name of hero it
#belongs to. one way to do this is use DataFrame.shape[0] with gives you how many rows are in the dataframe.
#make a list that length, and fill it with the key for that dataframe. then DataFrame[key][each]['Hero'] = list
#that will create a column named hero, which all dataframes will have, and add the list as an unique ID


sorted_feh = sorted_dataframes(feh_hero_dict)
print(sorted_feh)
# Out:
# [[           Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3       Ragnell    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       -      -
# 3  Enables counterattack regardless of distance i...     400       5      -
#
#   Hero
# 0  Ike
# 1  Ike
# 2  Ike
# 3  Ike  ,        Name Might Range                                             Effect  \
# 0  Élivágar    14     2  If unit initiates attack, bonuses on foes with...
#
#   SP Cost Default Unlock      Hero
# 0     400       -      -  Veronica  ,           Name Might Range                                           Effect  \
# 0     Iron Axe     6     1                                                -
# 1    Steel Axe     8     1                                                -
# 2   Killer Axe     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Axe+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Sheena
# 1     100       -      -  Sheena
# 2     200       4      -  Sheena
# 3     300       5      5  Sheena  ,          Name Might Range                                             Effect  \
# 0    Iron Bow     4     2                   Effective against flying units.
# 1   Steel Bow     6     2                   Effective against flying units.
# 2   Brave Bow     4     2  Spd-5. Effective against flying units. Attacks...
# 3  Brave Bow+     7     2  Spd-5. Effective against flying units. Attacks...
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Gordin
# 1     100       3      -  Gordin
# 2     200       4      3  Gordin
# 3     300       5      5  Gordin  ,       Name Might Range                                             Effect  \
# 0  Assault    10     2                                                  -
# 1     Slow     5     2  After any combat, inflicts Spd-6 on foe throug...
#
#   SP Cost Default Unlock  Hero
# 0      50       -      1  Wrys
# 1     150       -      3  Wrys  ,               Name Might Range  \
# 0         Iron Bow     4     2
# 1        Steel Bow     6     2
# 2   Assassin's Bow     7     2
# 3  Assassin's Bow+    11     2
#
#                                               Effect SP Cost Default Unlock  \
# 0                   Effective against flying units.       50       -      -
# 1                   Effective against flying units.      100       3      -
# 2  Effective against flying units. If target has ...     200       4      3
# 3  Effective against flying units. If target has ...     300       5      5
#
#       Hero
# 0  Setsuna
# 1  Setsuna
# 2  Setsuna
# 3  Setsuna  ,          Name Might Range                                       Effect  \
# 0    Iron Axe     6     1                                            -
# 1   Steel Axe     8     1                                            -
# 2   Brave Axe     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Axe+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Barst
# 1     100       3      -  Barst
# 2     200       4      3  Barst
# 3     300       -      5  Barst  ,        Name Might Range                                             Effect  \
# 0  Gradivus    16     1  Enables counterattack regardless of distance i...
#
#   SP Cost Default Unlock   Hero
# 0     400       -      -  Camus  ,          Name Might Range                            Effect SP Cost Default  \
# 0        Flux     4     2                                 -      50       2
# 1        Ruin     6     2                                 -     100       3
# 2   Rauðrwolf     6     2  Effective against cavalry units.     200       4
# 3  Rauðrwolf+    10     2  Effective against cavalry units.     300       -
#
#   Unlock   Hero
# 0      -  Raigh
# 1      2  Raigh
# 2      3  Raigh
# 3      5  Raigh  ,             Name Might Range                                           Effect  \
# 0     Iron Lance     6     1                                                -
# 1    Steel Lance     8     1                                                -
# 2   Killer Lance     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Lance+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Catria
# 1     100       3      -  Catria
# 2     200       4      3  Catria
# 3     300       5      5  Catria  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3      Raijinto    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       -      -
# 3  Enables counterattack regardless of distance i...     400       5      -
#
#     Hero
# 0  Ryoma
# 1  Ryoma
# 2  Ryoma
# 3  Ryoma  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3     Fólkvangr    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       2      -
# 1                                                  -     100       -      2
# 2                                                  -     200       -      3
# 3  Grants Atk+5 at start of turn if unit's HP ≤ 50%.     400       -      5
#
#       Hero
# 0  Alfonse
# 1  Alfonse
# 2  Alfonse
# 3  Alfonse  ,         Name Might Range                                             Effect  \
# 0       Flux     4     2                                                  -
# 1       Ruin     6     2                                                  -
# 2     Fenrir     9     2                                                  -
# 3  Brynhildr    14     2  If unit initiates attack, restricts foe's next...
#
#   SP Cost Default Unlock Hero
# 0      50       -      -  Leo
# 1     100       -      -  Leo
# 2     200       -      -  Leo
# 3     400       5      -  Leo  ,             Name Might Range  \
# 0    Fire Breath     6     1
# 1   Fire Breath+     8     1
# 2   Light Breath     9     1
# 3  Light Breath+    13     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2  Grants adjacent allies Def/Res+4 through their...     200       4      -
# 3  Grants adjacent allies Def/Res+4 through their...     300       5      5
#
#   Hero
# 0  Fae
# 1  Fae
# 2  Fae
# 3  Fae  ,         Name Might Range                            Effect SP Cost Default  \
# 0    Thunder     4     2                                 -      50       -
# 1  Elthunder     6     2                                 -     100       3
# 2   Blárwolf     6     2  Effective against cavalry units.     200       4
# 3  Blárwolf+    10     2  Effective against cavalry units.     300       -
#
#   Unlock    Hero
# 0      -  Ursula
# 1      -  Ursula
# 2      3  Ursula
# 3      5  Ursula  ,             Name Might Range                                           Effect  \
# 0     Iron Sword     6     1                                                -
# 1    Steel Sword     8     1                                                -
# 2   Killing Edge     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killing Edge+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock Hero
# 0      50       -      -  Fir
# 1     100       3      -  Fir
# 2     200       4      3  Fir
# 3     300       5      5  Fir  ,       Name Might Range                                             Effect  \
# 0  Assault    10     2                                                  -
# 1  Gravity     6     2  After any combat, prevents foe from moving mor...
#
#   SP Cost Default Unlock   Hero
# 0      50       -      1  Lissa
# 1     150       -      3  Lissa  ,       Name Might Range                                             Effect  \
# 0  Assault    10     2                                                  -
# 1     Slow     5     2  After any combat, inflicts Spd-6 on foe throug...
#
#   SP Cost Default Unlock  Hero
# 0      50       -      -  Mist
# 1     150       -      5  Mist  ,            Name Might Range  \
# 0      Iron Axe     6     1
# 1     Steel Axe     8     1
# 2   Emerald Axe     8     1
# 3  Emerald Axe+    12     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       2      -
# 1                                                  -     100       3      2
# 2  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 3  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5
#
#       Hero
# 0  Narcian
# 1  Narcian
# 2  Narcian
# 3  Narcian  ,            Name Might Range                                       Effect  \
# 0    Iron Sword     6     1                                            -
# 1   Steel Sword     8     1                                            -
# 2   Brave Sword     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Sword+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock  Hero
# 0      50       -      -  Cain
# 1     100       -      -  Cain
# 2     200       4      -  Cain
# 3     300       5      5  Cain  ,          Name Might Range                                            Effect  \
# 0    Iron Axe     6     1                                                 -
# 1   Steel Axe     8     1                                                 -
# 2  Silver Axe    11     1                                                 -
# 3      Nóatún    16     1  Unit may move adjacent to any ally when HP ≤ 40%
#
#   SP Cost Default Unlock  Hero
# 0      50       2      -  Anna
# 1     100       -      2  Anna
# 2     200       -      3  Anna
# 3     400       -      5  Anna  ,           Name Might Range                            Effect SP Cost Default  \
# 0     Iron Bow     4     2  Effective against flying units.       50       1
# 1    Steel Bow     6     2  Effective against flying units.      100       3
# 2   Silver Bow     9     2  Effective against flying units.      200       4
# 3  Silver Bow+    13     2  Effective against flying units.      300       -
#
#   Unlock    Hero
# 0      -  Virion
# 1      2  Virion
# 2      3  Virion
# 3      5  Virion  ,             Name Might Range  \
# 0    Iron Dagger     3     2
# 1   Steel Dagger     5     2
# 2   Smoke Dagger     6     2
# 3  Smoke Dagger+     9     2
#
#                                               Effect SP Cost Default Unlock  \
# 0  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 1  After combat, inflicts Def/Res-3 on foe throug...     100       3      -
# 2  After combat, inflicts Def/Res-4 on foes withi...     200       4      3
# 3  After combat, inflicts Def/Res-6 on foes withi...     300       -      5
#
#     Hero
# 0  Saizo
# 1  Saizo
# 2  Saizo
# 3  Saizo  ,            Name Might Range Effect SP Cost Default Unlock          Hero
# 0   Fire Breath     6     1      -      50       -      -  Tiki_(Young)
# 1  Fire Breath+     8     1      -     100       -      -  Tiki_(Young)
# 2   Flametongue    11     1      -     200       -      -  Tiki_(Young)
# 3  Flametongue+    15     1      -     300       5      -  Tiki_(Young),             Name Might Range                                           Effect  \
# 0     Iron Lance     6     1                                                -
# 1    Steel Lance     8     1                                                -
# 2   Killer Lance     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Lance+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Shanna
# 1     100       3      -  Shanna
# 2     200       4      3  Shanna
# 3     300       -      5  Shanna  ,            Name Might Range                                       Effect  \
# 0    Iron Lance     6     1                                            -
# 1   Steel Lance     8     1                                            -
# 2   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock  Hero
# 0      50       -      -  Abel
# 1     100       -      -  Abel
# 2     200       4      -  Abel
# 3     300       5      5  Abel  ,             Name Might Range Effect SP Cost Default Unlock    Hero
# 0     Iron Sword     6     1      -      50       -      -  Laslow
# 1    Steel Sword     8     1      -     100       3      -  Laslow
# 2   Silver Sword    11     1      -     200       4      3  Laslow
# 3  Silver Sword+    15     1      -     300       -      5  Laslow,               Name Might Range  \
# 0       Iron Lance     6     1
# 1      Steel Lance     8     1
# 2   Sapphire Lance     8     1
# 3  Sapphire Lance+    12     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       1      -
# 1                                                  -     100       3      2
# 2  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 3  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5
#
#     Hero
# 0  Sully
# 1  Sully
# 2  Sully
# 3  Sully  ,       Name Might Range                                            Effect  \
# 0  Assault    10     2                                                 -
# 1     Pain     3     2  Inflicts 10 damage on targeted foe after combat.
#
#   SP Cost Default Unlock   Hero
# 0      50       -      3  Azama
# 1     150       -      3  Azama  ,          Name Might Range                            Effect SP Cost Default  \
# 0        Wind     4     2                                 -      50       -
# 1      Elwind     6     2                                 -     100       -
# 2  Rexcalibur     9     2                                 -     200       4
# 3   Excalibur    14     2  Effective against flying units.      400       5
#
#   Unlock    Hero
# 0      -  Merric
# 1      -  Merric
# 2      -  Merric
# 3      5  Merric  ,                 Name Might Range  \
# 0        Fire Breath     6     1
# 1       Fire Breath+     8     1
# 2   Lightning Breath     7     1
# 3  Lightning Breath+    11     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       3      -
# 2  Enables counterattack regardless of attacker's...     200       4      3
# 3  Enables counterattack regardless of attacker's...     300       5      5
#
#            Hero
# 0  Tiki_(Adult)
# 1  Tiki_(Adult)
# 2  Tiki_(Adult)
# 3  Tiki_(Adult)  ,          Name Might Range                                             Effect  \
# 0    Iron Axe     6     1                                                  -
# 1   Steel Axe     8     1                                                  -
# 2  Silver Axe    11     1                                                  -
# 3      Armads    16     1  Unit makes a guaranteed follow-up attack when ...
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Hector
# 1     100       -      -  Hector
# 2     200       -      -  Hector
# 3     400       5      -  Hector  ,           Name Might Range                                             Effect  \
# 0     Iron Axe     6     1                                                  -
# 1    Steel Axe     8     1                                                  -
# 2   Carrot Axe     9     1  If unit initiates attack, unit recovers 4 HP a...
# 3  Carrot Axe+    13     1  If unit initiates attack, unit recovers 4 HP a...
#
#   SP Cost Default Unlock                     Hero
# 0      50       -      -  Chrom_(Spring_Festival)
# 1     100       -      -  Chrom_(Spring_Festival)
# 2     200       -      -  Chrom_(Spring_Festival)
# 3     300       5      -  Chrom_(Spring_Festival)  ,          Name Might Range                                       Effect  \
# 0     Thunder     4     2                                            -
# 1   Elthunder     6     2                                            -
# 2   Blárraven     7     2  Grants weapon advantage vs. colorless foes.
# 3  Blárraven+    11     2  Grants weapon advantage vs. colorless foes.
#
#   SP Cost Default Unlock       Hero
# 0      50       -      -  Robin_(M)
# 1     100       3      -  Robin_(M)
# 2     200       4      3  Robin_(M)
# 3     300       5      5  Robin_(M)  ,             Name Might Range                                           Effect  \
# 0     Iron Lance     6     1                                                -
# 1    Steel Lance     8     1                                                -
# 2   Killer Lance     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Lance+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Lukas
# 1     100       -      -  Lukas
# 2     200       4      -  Lukas
# 3     300       5      -  Lukas  ,           Name Might Range                                             Effect  \
# 0         Wind     4     2                                                  -
# 1       Elwind     6     2                                                  -
# 2   Gronnblade     9     2  Slows Special trigger (cooldown count+1).Adds ...
# 3  Gronnblade+    13     2  Slows Special trigger (cooldown count+1).Adds ...
#
#   SP Cost Default Unlock  Hero
# 0      50       -      -  Nino
# 1     100       3      -  Nino
# 2     200       4      3  Nino
# 3     300       -      5  Nino  ,               Name Might Range  \
# 0       Iron Lance     6     1
# 1      Steel Lance     8     1
# 2   Sapphire Lance     8     1
# 3  Sapphire Lance+    12     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       1      -
# 1                                                  -     100       3      2
# 2  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 3  Gives Atk+20% if weapon-triangle advantage, At...     300       5      5
#
#      Hero
# 0  Subaki
# 1  Subaki
# 2  Subaki
# 3  Subaki  ,           Name Might Range                                       Effect  \
# 0   Iron Sword     6     1                                            -
# 1  Steel Sword     8     1                                            -
# 2       Wo Dao     9     1  Grants +10 to damage when Special triggers.
# 3      Wo Dao+    13     1  Grants +10 to damage when Special triggers.
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Karel
# 1     100       -      -  Karel
# 2     200       -      -  Karel
# 3     300       5      -  Karel  ,              Name Might Range  \
# 0     Iron Dagger     3     2
# 1    Steel Dagger     5     2
# 2   Poison Dagger     2     2
# 3  Poison Dagger+     5     2
#
#                                               Effect SP Cost Default Unlock  \
# 0  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 1  After combat, inflicts Def/Res-3 on foe throug...     100       -      -
# 2  Effective against infantry units. Infantry foe...     200       4      -
# 3  Effective against infantry units. Infantry foe...     300       5      5
#
#      Hero
# 0  Kagero
# 1  Kagero
# 2  Kagero
# 3  Kagero  ,           Name Might Range                                             Effect  \
# 0   Iron Sword     6     1                                                  -
# 1  Steel Sword     8     1                                                  -
# 2   Ruby Sword     8     1  Gives Atk+20% if weapon-triangle advantage, At...
# 3  Ruby Sword+    12     1  Gives Atk+20% if weapon-triangle advantage, At...
#
#   SP Cost Default Unlock   Hero
# 0      50       1      -  Stahl
# 1     100       3      2  Stahl
# 2     200       4      3  Stahl
# 3     300       -      5  Stahl  ,            Name Might Range                             Effect SP Cost  \
# 0    Iron Sword     6     1                                  -      50
# 1   Steel Sword     8     1                                  -     100
# 2   Armorslayer     8     1  Effective against armored units.      200
# 3  Armorslayer+    12     1  Effective against armored units.      300
#
#   Default Unlock   Hero
# 0       -      -  Caeda
# 1       -      -  Caeda
# 2       4      -  Caeda
# 3       5      5  Caeda  ,            Name Might Range                                       Effect  \
# 0    Iron Lance     6     1                                            -
# 1   Steel Lance     8     1                                            -
# 2   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock      Hero
# 0      50       -      -  Cordelia
# 1     100       -      -  Cordelia
# 2     200       4      -  Cordelia
# 3     300       5      5  Cordelia  ,          Name Might Range                                             Effect  \
# 0    Iron Bow     4     2                   Effective against flying units.
# 1   Steel Bow     6     2                   Effective against flying units.
# 2  Silver Bow     9     2                   Effective against flying units.
# 3     Parthia    14     2  Effective against flying units. Grants Res+4 d...
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Jeorge
# 1     100       -      -  Jeorge
# 2     200       4      -  Jeorge
# 3     400       5      5  Jeorge  ,            Name Might Range                             Effect SP Cost  \
# 0    Iron Lance     6     1                                  -      50
# 1   Steel Lance     8     1                                  -     100
# 2   Heavy Spear     8     1  Effective against armored units.      200
# 3  Heavy Spear+    12     1  Effective against armored units.      300
#
#   Default Unlock     Hero
# 0       -      -  Florina
# 1       3      -  Florina
# 2       4      3  Florina
# 3       -      5  Florina  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3     Sieglinde    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       4      -
# 3  Grants adjacent allies Atk+3 through their nex...     400       5      5
#
#      Hero
# 0  Eirika
# 1  Eirika
# 2  Eirika
# 3  Eirika  ,              Name Might Range  \
# 0     Iron Dagger     3     2
# 1    Steel Dagger     5     2
# 2   Silver Dagger     7     2
# 3  Silver Dagger+    10     2
#
#                                               Effect SP Cost Default Unlock  \
# 0  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 1  After combat, inflicts Def/Res-3 on foe throug...     100       -      -
# 2  After combat, inflicts Def/Res-5 on foe throug...     200       4      -
# 3  After combat, inflicts Def/Res-7 on foe throug...     300       5      5
#
#     Hero
# 0  Jakob
# 1  Jakob
# 2  Jakob
# 3  Jakob  ,          Name Might Range                                             Effect  \
# 0        Wind     4     2                                                  -
# 1      Elwind     6     2                                                  -
# 2  Rexcalibur     9     2                                                  -
# 3        Naga    14     2  Effective against dragons. Grants Def/Res+2 wh...
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Julia
# 1     100       -      -  Julia
# 2     200       -      -  Julia
# 3     400       5      -  Julia  ,       Name Might Range                                             Effect  \
# 0  Assault    10     2                                                  -
# 1  Gravity     6     2  After any combat, prevents foe from moving mor...
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Elise
# 1     150       -      -  Elise  ,            Name Might Range                                           Effect  \
# 0    Iron Sword     6     1                                                -
# 1   Steel Sword     8     1                                                -
# 2  Killing Edge     7     1  Accelerates Special trigger (cooldown count-1).
# 3   Mystletainn    16     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock     Hero
# 0      50       -      -  Eldigan
# 1     100       -      -  Eldigan
# 2     200       -      -  Eldigan
# 3     400       5      -  Eldigan  ,            Name Might Range  \
# 0      Iron Axe     6     1
# 1     Steel Axe     8     1
# 2   Emerald Axe     8     1
# 3  Emerald Axe+    12     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2  Gives Atk+20% if weapon-triangle advantage, At...     200       -      -
# 3  Gives Atk+20% if weapon-triangle advantage, At...     300       5      -
#
#       Hero
# 0  Titania
# 1  Titania
# 2  Titania
# 3  Titania  ,            Name Might Range                                       Effect  \
# 0    Iron Sword     6     1                                            -
# 1   Steel Sword     8     1                                            -
# 2   Brave Sword     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Sword+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock   Hero
# 0      50       2      -  Draug
# 1     100       -      2  Draug
# 2     200       4      3  Draug
# 3     300       5      5  Draug  ,          Name Might Range                                           Effect  \
# 0    Iron Axe     6     1                                                -
# 1   Steel Axe     8     1                                                -
# 2  Silver Axe    11     1                                                -
# 3  Hauteclere    16     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock     Hero
# 0      50       -      -  Minerva
# 1     100       -      -  Minerva
# 2     200       -      -  Minerva
# 3     400       5      -  Minerva  ,         Name Might Range                             Effect SP Cost Default  \
# 0   Iron Axe     6     1                                  -      50       -
# 1  Steel Axe     8     1                                  -     100       3
# 2     Hammer     8     1  Effective against armored units.      200       4
# 3    Hammer+    12     1  Effective against armored units.      200       5
#
#   Unlock     Hero
# 0      -  Cherche
# 1      -  Cherche
# 2      3  Cherche
# 3      5  Cherche  ,             Name Might Range Effect SP Cost Default Unlock    Hero
# 0     Iron Sword     6     1      -      50       1      -  Olivia
# 1    Steel Sword     8     1      -     100       3      2  Olivia
# 2   Silver Sword    11     1      -     200       4      3  Olivia
# 3  Silver Sword+    15     1      -     300       -      5  Olivia,            Name Might Range                             Effect SP Cost  \
# 0    Iron Sword     6     1                                  -      50
# 1   Steel Sword     8     1                                  -     100
# 2   Armorslayer     8     1  Effective against armored units.      200
# 3  Armorslayer+    12     1  Effective against armored units.      300
#
#   Default Unlock  Hero
# 0       1      -  Hana
# 1       3      2  Hana
# 2       4      3  Hana
# 3       5      5  Hana  ,           Name Might Range                                       Effect  \
# 0         Wind     4     2                                            -
# 1       Elwind     6     2                                            -
# 2   Gronnraven     7     2  Grants weapon advantage vs. colorless foes.
# 3  Gronnraven+    11     2  Grants weapon advantage vs. colorless foes.
#
#   SP Cost Default Unlock     Hero
# 0      50       1      -  Cecilia
# 1     100       3      2  Cecilia
# 2     200       4      3  Cecilia
# 3     300       -      5  Cecilia  ,         Name Might Range                             Effect SP Cost Default  \
# 0   Iron Axe     6     1                                  -      50       -
# 1  Steel Axe     8     1                                  -     100       3
# 2     Hammer     8     1  Effective against armored units.      200       4
# 3    Hammer+    12     1  Effective against armored units.      200       -
#
#   Unlock    Hero
# 0      -  Bartre
# 1      -  Bartre
# 2      3  Bartre
# 3      5  Bartre  ,            Name Might Range  \
# 0   Fire Breath     6     1
# 1  Fire Breath+     8     1
# 2   Dark Breath     9     1
# 3  Dark Breath+    13     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       3      -
# 2  After this unit attacks, foes within 2 spaces ...     200       4      3
# 3  After this unit attacks, foes within 2 spaces ...     300       -      5
#
#          Hero
# 0  Corrin_(F)
# 1  Corrin_(F)
# 2  Corrin_(F)
# 3  Corrin_(F)  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3      Falchion    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       -      -
# 3  Effective against dragons. At the start of eve...     400       5      -
#
#      Hero
# 0  Lucina
# 1  Lucina
# 2  Lucina
# 3  Lucina  ,       Name Might Range                                             Effect  \
# 0  Assault    10     2                                                  -
# 1     Fear     5     2  After combat, inflicts Atk-6 on targeted foe t...
#
#   SP Cost Default Unlock     Hero
# 0      50       -      -  Clarine
# 1     150       -      3  Clarine  ,           Name Might Range                                       Effect  \
# 0         Flux     4     2                                            -
# 1         Ruin     6     2                                            -
# 2   Rauðrraven     7     2  Grants weapon advantage vs. colorless foes.
# 3  Rauðrraven+    11     2  Grants weapon advantage vs. colorless foes.
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Henry
# 1     100       3      -  Henry
# 2     200       4      3  Henry
# 3     300       -      5  Henry  ,             Name Might Range                                           Effect  \
# 0     Iron Lance     6     1                                                -
# 1    Steel Lance     8     1                                                -
# 2   Killer Lance     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Lance+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock       Hero
# 0      50       -      -  Gwendolyn
# 1     100       3      -  Gwendolyn
# 2     200       4      3  Gwendolyn
# 3     300       -      5  Gwendolyn  ,            Name Might Range                                       Effect  \
# 0    Iron Sword     6     1                                            -
# 1   Steel Sword     8     1                                            -
# 2   Brave Sword     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Sword+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock  Hero
# 0      50       -      -  Ogma
# 1     100       -      -  Ogma
# 2     200       4      -  Ogma
# 3     300       5      5  Ogma  ,          Name Might Range                                       Effect  \
# 0    Iron Axe     6     1                                            -
# 1   Steel Axe     8     1                                            -
# 2   Brave Axe     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Axe+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Raven
# 1     100       -      -  Raven
# 2     200       4      -  Raven
# 3     300       5      5  Raven  ,          Name Might Range                                             Effect  \
# 0     Thunder     4     2                                                  -
# 1   Elthunder     6     2                                                  -
# 2   Blárblade     9     2  Slows Special trigger (cooldown count+1).Adds ...
# 3  Blárblade+    13     2  Slows Special trigger (cooldown count+1).Adds ...
#
#   SP Cost Default Unlock  Hero
# 0      50       -      -  Odin
# 1     100       3      -  Odin
# 2     200       4      3  Odin
# 3     300       -      5  Odin  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3     Siegfried    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       3      -
# 2                                                  -     200       4      3
# 3  Enables counterattack regardless of distance i...     400       -      5
#
#      Hero
# 0  Xander
# 1  Xander
# 2  Xander
# 3  Xander  ,            Name Might Range  \
# 0      Iron Axe     6     1
# 1     Steel Axe     8     1
# 2   Emerald Axe     8     1
# 3  Emerald Axe+    12     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       3      -
# 2  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 3  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5
#
#      Hero
# 0  Arthur
# 1  Arthur
# 2  Arthur
# 3  Arthur  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3          Yato    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       4      -
# 3  Grants Spd+4 during combat if unit initiates a...     400       5      5
#
#          Hero
# 0  Corrin_(M)
# 1  Corrin_(M)
# 2  Corrin_(M)
# 3  Corrin_(M)  ,          Name Might Range                                             Effect  \
# 0        Wind     4     2                                                  -
# 1      Elwind     6     2                                                  -
# 2   Green Egg     7     2  If unit initiates attack, unit recovers 4 HP a...
# 3  Green Egg+    11     2  If unit initiates attack, unit recovers 4 HP a...
#
#   SP Cost Default Unlock                       Hero
# 0      50       -      -  Camilla_(Spring_Festival)
# 1     100       -      -  Camilla_(Spring_Festival)
# 2     200       -      -  Camilla_(Spring_Festival)
# 3     300       5      -  Camilla_(Spring_Festival)  ,           Name Might Range                                             Effect  \
# 0   Iron Sword     6     1                                                  -
# 1  Steel Sword     8     1                                                  -
# 2   Ruby Sword     8     1  Gives Atk+20% if weapon-triangle advantage, At...
# 3  Ruby Sword+    12     1  Gives Atk+20% if weapon-triangle advantage, At...
#
#   SP Cost Default Unlock   Hero
# 0      50       -      -  Palla
# 1     100       3      -  Palla
# 2     200       4      3  Palla
# 3     300       5      5  Palla  ,           Name Might Range                            Effect SP Cost Default  \
# 0     Iron Bow     4     2  Effective against flying units.       50       -
# 1    Steel Bow     6     2  Effective against flying units.      100       -
# 2   Silver Bow     9     2  Effective against flying units.      200       4
# 3  Silver Bow+    13     2  Effective against flying units.      300       5
#
#   Unlock     Hero
# 0      -  Rebecca
# 1      -  Rebecca
# 2      -  Rebecca
# 3      5  Rebecca  ,       Name Might Range                                             Effect  \
# 0  Assault    10     2                                                  -
# 1     Fear     5     2  After combat, inflicts Atk-6 on targeted foe t...
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Sakura
# 1     150       -      4  Sakura  ,            Name Might Range                                       Effect  \
# 0    Iron Lance     6     1                                            -
# 1   Steel Lance     8     1                                            -
# 2   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock    Hero
# 0      50       -      -  Hinoka
# 1     100       -      -  Hinoka
# 2     200       -      -  Hinoka
# 3     300       5      -  Hinoka  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3      Falchion    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       4      -
# 3  Effective against dragons. At the start of eve...     400       5      5
#
#     Hero
# 0  Marth
# 1  Marth
# 2  Marth
# 3  Marth  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3     Sol Katti    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       -      -
# 3  If wielder initiates attack at HP ≤ 50%, any f...     400       5      -
#
#   Hero
# 0  Lyn
# 1  Lyn
# 2  Lyn
# 3  Lyn  ,            Name Might Range                                       Effect  \
# 0    Iron Lance     6     1                                            -
# 1   Steel Lance     8     1                                            -
# 2   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock    Hero
# 0      50       1      -  Donnel
# 1     100       3      2  Donnel
# 2     200       4      3  Donnel
# 3     300       -      5  Donnel  ,             Name Might Range                                           Effect  \
# 0     Iron Lance     6     1                                                -
# 1    Steel Lance     8     1                                                -
# 2   Killer Lance     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Lance+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock  Hero
# 0      50       -      -  Peri
# 1     100       -      -  Peri
# 2     200       4      -  Peri
# 3     300       5      5  Peri  ,          Name Might Range                                             Effect  \
# 0  Valaskjálf    14     2  Enables unit at ≤ 50% HP to strike first, even...
#
#   SP Cost Default Unlock   Hero
# 0     400       -      -  Bruno  ,             Name Might Range Effect SP Cost Default Unlock   Hero
# 0     Iron Lance     6     1      -      50       -      -  Effie
# 1    Steel Lance     8     1      -     100       -      -  Effie
# 2   Silver Lance    11     1      -     200       4      -  Effie
# 3  Silver Lance+    15     1      -     300       5      5  Effie,             Name Might Range Effect SP Cost Default Unlock   Hero
# 0     Iron Lance     6     1      -      50       -      -  Jagen
# 1    Steel Lance     8     1      -     100       3      -  Jagen
# 2   Silver Lance    11     1      -     200       4      3  Jagen
# 3  Silver Lance+    15     1      -     300       -      5  Jagen,             Name Might Range                                        Effect  \
# 0     Iron Sword     6     1                                             -
# 1    Steel Sword     8     1                                             -
# 2   Silver Sword    11     1                                             -
# 3  Binding Blade    16     1  Grants Def/Res+2 when this unit is attacked.
#
#   SP Cost Default Unlock Hero
# 0      50       -      -  Roy
# 1     100       -      -  Roy
# 2     200       4      -  Roy
# 3     400       5      5  Roy  ,           Name Might Range Effect SP Cost Default Unlock   Hero
# 0         Wind     4     2      -      50       -      -  Soren
# 1       Elwind     6     2      -     100       -      -  Soren
# 2   Rexcalibur     9     2      -     200       -      -  Soren
# 3  Rexcalibur+    13     2      -     300       5      -  Soren,             Name Might Range  \
# 0    Iron Dagger     3     2
# 1   Steel Dagger     5     2
# 2   Rogue Dagger     4     2
# 3  Rogue Dagger+     7     2
#
#                                               Effect SP Cost Default Unlock  \
# 0  After combat, inflicts Def/Res-3 on foe throug...      50       2      -
# 1  After combat, inflicts Def/Res-3 on foe throug...     100       3      2
# 2  After combat, inflicts Def/Res-3 on foe throug...     200       4      3
# 3  After combat, inflicts Def/Res-5 on foe throug...     300       -      5
#
#       Hero
# 0  Matthew
# 1  Matthew
# 2  Matthew
# 3  Matthew  ,           Name Might Range                                           Effect  \
# 0     Iron Axe     6     1                                                -
# 1    Steel Axe     8     1                                                -
# 2   Killer Axe     7     1  Accelerates Special trigger (cooldown count-1).
# 3  Killer Axe+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock     Hero
# 0      50       -      -  Hawkeye
# 1     100       -      -  Hawkeye
# 2     200       4      3  Hawkeye
# 3     300       5      5  Hawkeye  ,       Name Might Range                                             Effect  \
# 0  Assault    10     2                                                  -
# 1    Panic     7     2  After combat, bonuses on targeted foe become p...
#
#   SP Cost Default Unlock   Hero
# 0      50       -      4  Maria
# 1     150       -      4  Maria  ,         Name Might Range                                             Effect  \
# 0    Thunder     4     2                                                  -
# 1  Elthunder     6     2                                                  -
# 2   Blue Egg     7     2  If unit initiates attack, unit recovers 4 HP a...
# 3  Blue Egg+    11     2  If unit initiates attack, unit recovers 4 HP a...
#
#   SP Cost Default Unlock                      Hero
# 0      50       -      -  Lucina_(Spring_Festival)
# 1     100       -      -  Lucina_(Spring_Festival)
# 2     200       -      -  Lucina_(Spring_Festival)
# 3     300       5      -  Lucina_(Spring_Festival)  ,           Name Might Range Effect SP Cost Default Unlock    Hero
# 0     Iron Axe     6     1      -      50       1      -  Gunter
# 1    Steel Axe     8     1      -     100       3      2  Gunter
# 2   Silver Axe    11     1      -     200       4      3  Gunter
# 3  Silver Axe+    15     1      -     300       -      5  Gunter,       Name Might Range                            Effect SP Cost Default  \
# 0  Assault    10     2                                 -      50       -
# 1   Absorb     4     2  Recovers HP=50% of damage dealt.     150       -
#
#   Unlock      Hero
# 0      -  Lachesis
# 1      4  Lachesis  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3      Falchion    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       4      -
# 3  Effective against dragons. At the start of eve...     400       5      5
#
#     Hero
# 0  Chrom
# 1  Chrom
# 2  Chrom
# 3  Chrom  ,            Name Might Range                             Effect SP Cost  \
# 0    Iron Sword     6     1                                  -      50
# 1   Steel Sword     8     1                                  -     100
# 2   Armorslayer     8     1  Effective against armored units.      200
# 3  Armorslayer+    12     1  Effective against armored units.      300
#
#   Default Unlock    Hero
# 0       -      -  Selena
# 1       3      -  Selena
# 2       4      3  Selena
# 3       5      5  Selena  ,            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3      Durandal    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       3      -
# 2                                                  -     200       4      3
# 3  Grants Atk+4 during combat if unit initiates a...     400       5      5
#
#       Hero
# 0  Eliwood
# 1  Eliwood
# 2  Eliwood
# 3  Eliwood  ,           Name Might Range                                             Effect  \
# 0   Iron Sword     6     1                                                  -
# 1  Steel Sword     8     1                                                  -
# 2   Ruby Sword     8     1  Gives Atk+20% if weapon-triangle advantage, At...
# 3  Ruby Sword+    12     1  Gives Atk+20% if weapon-triangle advantage, At...
#
#   SP Cost Default Unlock    Hero
# ...
#
#   Unlock Type   Hero
# 0      -    A  Klein
# 1      -    A  Klein
# 2      4    A  Klein
# 3      -    B  Klein
# 4      4    B  Klein
# 5      5    B  Klein  ,             Name                                             Effect SP Cost  \
# 0  Defiant Atk 1  Grants Atk+3 at start of turn if unit's HP ≤ 50%.      40
# 1  Defiant Atk 2  Grants Atk+5 at start of turn if unit's HP ≤ 50%.      80
# 2  Defiant Atk 3  Grants Atk+7 at start of turn if unit's HP ≤ 50%.     160
# 3         Pass 1   Units can pass through foes if its own HP ≥ 75%.      50
# 4         Pass 2   Units can pass through foes if its own HP ≥ 50%.     100
# 5         Pass 3   Units can pass through foes if its own HP ≥ 25%.     200
#
#   Unlock Type   Hero
# 0      3    A  Gaius
# 1      4    A  Gaius
# 2      5    A  Gaius
# 3      -    B  Gaius
# 4      3    B  Gaius
# 5      4    B  Gaius  ,                Name                                             Effect  \
# 0     Resistance +1                                      Grants Res+1.
# 1     Resistance +2                                      Grants Res+2.
# 2     Resistance +3                                      Grants Res+3.
# 3  Breath of Life 1  If unit initiates attack, adjacent allies reco...
# 4  Breath of Life 2  If unit initiates attack, adjacent allies reco...
# 5  Breath of Life 3  If unit initiates attack, adjacent allies reco...
#
#   SP Cost Unlock Type     Hero
# 0      30      3    A  Felicia
# 1      60      4    A  Felicia
# 2     120      5    A  Felicia
# 3      50      1    C  Felicia
# 4     100      2    C  Felicia
# 5     200      4    C  Felicia  ,         Name                                             Effect SP Cost  \
# 0   Speed +1                                      Grants Spd+1.      30
# 1   Speed +2                                      Grants Spd+2.      60
# 2   Speed +3                                      Grants Spd+3.     120
# 3  Vantage 1  Unit counterattacks first when attacked at HP ...      50
# 4  Vantage 2  Unit counterattacks first when attacked at HP ...     100
# 5  Vantage 3  Unit counterattacks first when attacked at HP ...     200
#
#   Unlock Type    Hero
# 0      3    A  Lon'qu
# 1      4    A  Lon'qu
# 2      5    A  Lon'qu
# 3      -    B  Lon'qu
# 4      3    B  Lon'qu
# 5      4    B  Lon'qu  ,              Name                                             Effect  \
# 0  Live for Honor  If unit survives, get 1.5x normal badges from ...
# 1   Fortify Def 1  Grants adjacent allies Def+2 through their nex...
# 2               C                                      Fortify Def 2
# 3               -                                      Fortify Def 3
#
#                                              SP Cost Unlock Type  \
# 0                                                100      5    B
# 1                                                 50      -    B
# 2  Grants adjacent allies Def+3 through their nex...    100    B
# 3  Grants adjacent allies Def+4 through their nex...    200    5
#
#                        Hero
# 0  Xander_(Spring_Festival)
# 1  Xander_(Spring_Festival)
# 2  Xander_(Spring_Festival)
# 3  Xander_(Spring_Festival)  ,              Name                                             Effect SP Cost  \
# 0  Darting Blow 1  Grants Spd+2 during combat if unit initiates t...      50
# 1  Darting Blow 2  Grants Spd+4 during combat if unit initiates t...     100
# 2  Darting Blow 3  Grants Spd+6 during combat if unit initiates t...     200
# 3      Spur Res 1        Grants adjacent allies Res+2 during combat.      50
# 4      Spur Res 2        Grants adjacent allies Res+3 during combat.     100
# 5      Spur Res 3        Grants adjacent allies Res+4 during combat.     200
#
#   Unlock Type    Hero
# 0      -    A  Tharja
# 1      -    A  Tharja
# 2      4    A  Tharja
# 3      -    C  Tharja
# 4      4    C  Tharja
# 5      5    C  Tharja  ,          Name                                       Effect SP Cost Unlock  \
# 0   Attack +1                                Grants Atk+1.      30      -
# 1   Attack +2                                Grants Atk+2.      60      4
# 2   Attack +3                                Grants Atk+3.     120      5
# 3  Spur Atk 1  Grants adjacent allies Atk+2 during combat.      50      -
# 4  Spur Atk 2  Grants adjacent allies Atk+3 during combat.     100      -
# 5  Spur Atk 3  Grants adjacent allies Atk+4 during combat.     200      4
#
#   Type    Hero
# 0    A  Lilina
# 1    A  Lilina
# 2    A  Lilina
# 3    C  Lilina
# 4    C  Lilina
# 5    C  Lilina  ,                Name                                             Effect  \
# 0  Wings of Mercy 1  Enables unit to warp adjacent to any ally with...
# 1  Wings of Mercy 2  Enables unit to warp adjacent to any ally with...
# 2  Wings of Mercy 3  Enables unit to warp adjacent to any ally with...
# 3     Fortify Def 1  Grants adjacent allies Def+2 through their nex...
# 4     Fortify Def 2  Grants adjacent allies Def+3 through their nex...
# 5     Fortify Def 3  Grants adjacent allies Def+4 through their nex...
#
#   SP Cost Unlock Type       Hero
# 0      60      3    B  Frederick
# 1     120      4    B  Frederick
# 2     240      5    B  Frederick
# 3      50      -    C  Frederick
# 4     100      3    C  Frederick
# 5     200      4    C  Frederick  ,            Name                                             Effect SP Cost  \
# 0     Vantage 1  Unit counterattacks first when attacked at HP ...      50
# 1     Vantage 2  Unit counterattacks first when attacked at HP ...     100
# 2     Vantage 3  Unit counterattacks first when attacked at HP ...     200
# 3    Spur Atk 1        Grants adjacent allies Atk+2 during combat.      50
# 4    Spur Atk 2        Grants adjacent allies Atk+3 during combat.     100
# 5  Goad Cavalry  Grants cavalry allies within 2 spaces Spd/Atk+...     200
#
#   Unlock Type       Hero
# 0      -    B  Reinhardt
# 1      -    B  Reinhardt
# 2      4    B  Reinhardt
# 3      -    C  Reinhardt
# 4      4    C  Reinhardt
# 5      5    C  Reinhardt  ,     Name                Effect SP Cost Unlock Type    Hero
# 0  HP +3  Grants +3 to max HP.      40      -    A  Lucius
# 1  HP +4  Grants +4 to max HP.      80      4    A  Lucius
# 2  HP +5  Grants +5 to max HP.     160      5    A  Lucius,              Name                                             Effect SP Cost  \
# 0  Darting Blow 1  Grants Spd+2 during combat if unit initiates t...      50
# 1  Darting Blow 2  Grants Spd+4 during combat if unit initiates t...     100
# 2  Darting Blow 3  Grants Spd+6 during combat if unit initiates t...     200
# 3   Savage Blow 1  If unit initiates attack, foes within 2 spaces...      50
# 4   Savage Blow 2  If unit initiates attack, foes within 2 spaces...     100
# 5   Savage Blow 3  If unit initiates attack, foes within 2 spaces...     200
#
#   Unlock Type     Hero
# 0      -    A  Camilla
# 1      4    A  Camilla
# 2      5    A  Camilla
# 3      -    C  Camilla
# 4      -    C  Camilla
# 5      4    C  Camilla  ,               Name                                             Effect SP Cost  \
# 0   Escape Route 1  Enables unit whose own HP is ≤ 30% to warp adj...      60
# 1   Escape Route 2  Enables unit whose own HP is ≤ 40% to warp adj...     120
# 2   Escape Route 3  Enables unit whose own HP is ≤ 50% to warp adj...     240
# 3    Fortify Def 1  Grants adjacent allies Def+2 through their nex...      50
# 4    Fortify Def 2  Grants adjacent allies Def+3 through their nex...     100
# 5  Fortify Dragons  Grants adjacent Dragon allies Def/Res+6 throug...     200
#
#   Unlock Type    Hero
# 0      -    B  Ninian
# 1      -    B  Ninian
# 2      5    B  Ninian
# 3      -    C  Ninian
# 4      -    C  Ninian
# 5      5    C  Ninian  ,          Name                                             Effect SP Cost  \
# 0  Hone Atk 1  Grants adjacent allies Atk+2 through their nex...      50
# 1  Hone Atk 2  Grants adjacent allies Atk+3 through their nex...     100
# 2  Hone Atk 3  Grants adjacent allies Atk+4 through their nex...     200
#
#   Unlock Type   Hero
# 0      3    C  Serra
# 1      4    C  Serra
# 2      5    C  Serra  ,               Name                                             Effect SP Cost  \
# 0    Defiant Res 1  Grants Res+3 at start of turn if unit's HP ≤ 50%.      40
# 1    Defiant Res 2  Grants Res+5 at start of turn if unit's HP ≤ 50%.      80
# 2    Defiant Res 3  Grants Res+7 at start of turn if unit's HP ≤ 50%.     160
# 3  B Tomebreaker 1  If unit's HP ≥ 90% in combat against a blue to...      50
# 4  B Tomebreaker 2  If unit's HP ≥ 70% in combat against a blue to...     100
# 5  B Tomebreaker 3  If unit's HP ≥ 50% in combat against a blue to...     200
#
#   Unlock Type       Hero
# 0      3    A  Robin_(F)
# 1      4    A  Robin_(F)
# 2      5    A  Robin_(F)
# 3      2    B  Robin_(F)
# 4      3    B  Robin_(F)
# 5      4    B  Robin_(F)  ,           Name                                             Effect  \
# 0  Hit and Run  If unit initiates attack, unit retreats 1 spac...
# 1   Spur Spd 1        Grants adjacent allies Spd+2 during combat.
# 2            C                                         Spur Spd 2
# 3            4                                         Spur Spd 3
#
#                                        SP Cost Unlock Type   Hero
# 0                                          150      4    B  Clair
# 1                                           50      -    B  Clair
# 2  Grants adjacent allies Spd+3 during combat.    100    B  Clair
# 3  Grants adjacent allies Spd+4 during combat.    200    5  Clair  ,             Name                                             Effect SP Cost  \
# 0       Speed +1                                      Grants Spd+1.      30
# 1       Speed +2                                      Grants Spd+2.      60
# 2       Speed +3                                      Grants Spd+3.     120
# 3  Fortify Res 1  Grants adjacent allies Res+2 through their nex...      50
# 4  Fortify Res 2  Grants adjacent allies Res+3 through their nex...     100
# 5  Fortify Res 3  Grants adjacent allies Res+4 through their nex...     200
#
#   Unlock Type   Hero
# 0      -    A  Linde
# 1      -    A  Linde
# 2      5    A  Linde
# 3      -    C  Linde
# 4      -    C  Linde
# 5      5    C  Linde  ,             Name                                             Effect SP Cost  \
# 0  Defiant Res 1  Grants Res+3 at start of turn if unit's HP ≤ 50%.      40
# 1  Defiant Res 2  Grants Res+5 at start of turn if unit's HP ≤ 50%.      80
# 2  Defiant Res 3  Grants Res+7 at start of turn if unit's HP ≤ 50%.     160
# 3     Seal Spd 1  After combat, foe suffers Spd-3 through its ne...      40
# 4     Seal Spd 2  After combat, foe suffers Spd-5 through its ne...      80
# 5     Seal Spd 3  After combat, foe suffers Spd-7 through its ne...     160
#
#   Unlock Type Hero
# 0      -    A  Est
# 1      3    A  Est
# 2      4    A  Est
# 3      3    B  Est
# 4      4    B  Est
# 5      5    B  Est  ,              Name                                             Effect SP Cost  \
# 0  Warding Blow 1  Grants Res+2 during combat if unit initiates a...      50
# 1  Warding Blow 2  Grants Res+4 during combat if unit initiates a...     100
# 2  Warding Blow 3  Grants Res+6 during combat if unit initiates a...     200
# 3      Spur Res 1        Grants adjacent allies Res+2 during combat.      50
# 4      Spur Res 2        Grants adjacent allies Res+3 during combat.     100
# 5      Spur Res 3        Grants adjacent allies Res+4 during combat.     200
#
#   Unlock Type   Hero
# 0      -    A  Niles
# 1      3    A  Niles
# 2      4    A  Niles
# 3      3    C  Niles
# 4      4    C  Niles
# 5      5    C  Niles  ,                Name                                             Effect  \
# 0  Life and Death 1               Grants Atk/Spd+3.Inflicts Def/Res-3.
# 1  Life and Death 2               Grants Atk/Spd+4.Inflicts Def/Res-4.
# 2  Life and Death 3               Grants Atk/Spd+5.Inflicts Def/Res-5.
# 3    Wary Fighter 1  Prevents follow-up attacks in combat from unit...
# 4    Wary Fighter 2  Prevents follow-up attacks in combat from unit...
# 5    Wary Fighter 3  Prevents follow-up attacks in combat from unit...
#
#   SP Cost Unlock Type     Hero
# 0      50      -    A  Zephiel
# 1     100      4    A  Zephiel
# 2     200      5    A  Zephiel
# 3      60      -    B  Zephiel
# 4     120      -    B  Zephiel
# 5     240      4    B  Zephiel  ,              Name                                             Effect  \
# 0   Close Counter  Enables unit to counterattack regardless of di...
# 1  Threaten Spd 1  Inflicts Spd-3 on foes within 2 spaces through...
# 2               C                                     Threaten Spd 2
# 3               -                                     Threaten Spd 3
#
#                                              SP Cost Unlock Type    Hero
# 0                                                300      5    A  Takumi
# 1                                                 50      -    A  Takumi
# 2  Inflicts Spd-4 on foes within 2 spaces through...    100    A  Takumi
# 3  Inflicts Spd-5 on foes within 2 spaces through...    200    5  Takumi  ,              Name                                             Effect  \
# 0   Iote's Shield           Neutralizes "effective against" bonuses.
# 1  Threaten Def 1  Inflicts Def-3 on foes within 2 spaces through...
# 2               C                                     Threaten Def 2
# 3               3                                     Threaten Def 3
#
#                                              SP Cost Unlock Type      Hero
# 0                                                200      4    A  Michalis
# 1                                                 50      -    A  Michalis
# 2  Inflicts Def-4 on foes within 2 spaces through...    100    A  Michalis
# 3  Inflicts Def-5 on foes within 2 spaces through...    200    4  Michalis  ,           Name                                             Effect SP Cost  \
# 0    Attack +1                                      Grants Atk+1.      30
# 1    Attack +2                                      Grants Atk+2.      60
# 2    Attack +3                                      Grants Atk+3.     120
# 3  Windsweep 1  If unit initiates attack, no follow-up occurs....      60
# 4  Windsweep 2  If unit initiates attack, no follow-up occurs....     120
# 5  Windsweep 3  If unit initiates attack, no follow-up occurs....     240
#
#   Unlock Type Hero
# 0      -    A  Alm
# 1      -    A  Alm
# 2      5    A  Alm
# 3      -    B  Alm
# 4      -    B  Alm
# 5      5    B  Alm  ,              Name                                             Effect SP Cost  \
# 0  Warding Blow 1  Grants Res+2 during combat if unit initiates a...      50
# 1  Warding Blow 2  Grants Res+4 during combat if unit initiates a...     100
# 2  Warding Blow 3  Grants Res+6 during combat if unit initiates a...     200
# 3      Spur Res 1        Grants adjacent allies Res+2 during combat.      50
# 4      Spur Res 2        Grants adjacent allies Res+3 during combat.     100
# 5    Ward Cavalry  Grants cavalry allies within 2 spaces Def/Res+...     200
#
#   Unlock Type   Hero
# 0      -    A  Olwen
# 1      -    A  Olwen
# 2      5    A  Olwen
# 3      -    C  Olwen
# 4      -    C  Olwen
# 5      5    C  Olwen  ,             Name                                             Effect SP Cost  \
# 0  Defiant Def 1  Grants Def+3 at start of turn if unit's HP ≤ 50%.      40
# 1  Defiant Def 2  Grants Def+5 at start of turn if unit's HP ≤ 50%.      80
# 2  Defiant Def 3  Grants Def+7 at start of turn if unit's HP ≤ 50%.     160
# 3          Lunge  If unit initiates attack, after combat, unit a...     150
#
#   Unlock Type    Hero
# 0      -    A  Beruka
# 1      3    A  Beruka
# 2      4    A  Beruka
# 3      3    B  Beruka  ]]

# %%
print(len(sorted_feh[3]))
# Out:
# 125

# %%
print(feh_hero_dict['Abel'])
# Out:
# [           Name Might Range                                       Effect  \
# 0    Iron Lance     6     1                                            -
# 1   Steel Lance     8     1                                            -
# 2   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 3  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#   SP Cost Default Unlock
# 0      50       -      -
# 1     100       -      -
# 2     200       4      -
# 3     300       5      5  ,              Name Cooldown                                             Effect  \
# 0  Holy Vestments        3  Reduces damage inflicted by attacks from foes ...
# 1           Aegis        3  Reduces damage inflicted by attacks from foes ...
#
#   SP Cost Default Unlock
# 0     100       4      -
# 1     200       -      4  ,              Name                                             Effect SP Cost  \
# 0           HP +3                               Grants +3 to max HP.      40
# 1           HP +4                               Grants +4 to max HP.      80
# 2           HP +5                               Grants +5 to max HP.     160
# 3  Swordbreaker 1  If unit's HP ≥ 90% in combat against a sword u...      50
# 4  Swordbreaker 2  If unit's HP ≥ 70% in combat against a sword u...     100
# 5  Swordbreaker 3  If unit's HP ≥ 50% in combat against a sword u...     200
#
#   Unlock Type
# 0      -    A
# 1      4    A
# 2      5    A
# 3      -    B
# 4      -    B
# 5      4    B  ]

# %%
def concat_df_list(skill):
    skill_df = skill[0]
    for df in skill[1:]:
        skill_df = pd.concat([skill_df, df], ignore_index=True)
    return skill_df
weapons_df_unsorted = concat_df_list(sorted_feh[0])
w_df = weapons_df_unsorted.copy()
#print(w_df.index.values)
w_df['IndexCol'] = w_df.index.values
w_df = w_df.sort_values(['Hero', 'IndexCol'])
print(w_df)
#print(weapons_df)
#weap_alphabetical = weapons_df.sort_values('Hero')
#print(weap_alphabetical)
# Out:
#                 Name Might Range  \
# 88        Iron Lance     6     1
# 89       Steel Lance     8     1
# 90       Brave Lance     5     1
# 91      Brave Lance+     8     1
# 36        Iron Sword     6     1
# 37       Steel Sword     8     1
# 38      Silver Sword    11     1
# 39         Fólkvangr    16     1
# 467       Iron Sword     6     1
# 468      Steel Sword     8     1
# 469     Silver Sword    11     1
# 470         Falchion    16     1
# 68          Iron Axe     6     1
# 69         Steel Axe     8     1
# 70        Silver Axe    11     1
# 71            Nóatún    16     1
# 246         Iron Axe     6     1
# 247        Steel Axe     8     1
# 248      Emerald Axe     8     1
# 249     Emerald Axe+    12     1
# 100          Assault    10     2
# 101             Pain     3     2
# 375       Iron Lance     6     1
# 376      Steel Lance     8     1
# 377   Sapphire Lance     8     1
# 378  Sapphire Lance+    12     1
# 19          Iron Axe     6     1
# 20         Steel Axe     8     1
# 21         Brave Axe     5     1
# 22        Brave Axe+     8     1
# ..               ...   ...   ...
# 81      Fire Breath+     8     1
# 82       Flametongue    11     1
# 83      Flametongue+    15     1
# 180         Iron Axe     6     1
# 181        Steel Axe     8     1
# 182      Emerald Axe     8     1
# 183     Emerald Axe+    12     1
# 48           Thunder     4     2
# 49         Elthunder     6     2
# 50          Blárwolf     6     2
# 51         Blárwolf+    10     2
# 4           Élivágar    14     2
# 72          Iron Bow     4     2
# 73         Steel Bow     6     2
# 74        Silver Bow     9     2
# 75       Silver Bow+    13     2
# 13           Assault    10     2
# 14              Slow     5     2
# 242       Iron Sword     6     1
# 243      Steel Sword     8     1
# 244     Silver Sword    11     1
# 245        Siegfried    16     1
# 403       Iron Lance     6     1
# 404      Steel Lance     8     1
# 405     Carrot Lance     9     1
# 406    Carrot Lance+    13     1
# 455       Iron Sword     6     1
# 456      Steel Sword     8     1
# 457     Silver Sword    11     1
# 458        Eckesachs    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 88                                                   -      50       -      -
# 89                                                   -     100       -      -
# 90         Spd-5. Attack twice when initiating combat.     200       4      -
# 91         Spd-5. Attack twice when initiating combat.     300       5      5
# 36                                                   -      50       2      -
# 37                                                   -     100       -      2
# 38                                                   -     200       -      3
# 39   Grants Atk+5 at start of turn if unit's HP ≤ 50%.     400       -      5
# 467                                                  -      50       -      -
# 468                                                  -     100       -      -
# 469                                                  -     200       -      -
# 470  Effective against dragons. At the start of eve...     400       5      -
# 68                                                   -      50       2      -
# 69                                                   -     100       -      2
# 70                                                   -     200       -      3
# 71    Unit may move adjacent to any ally when HP ≤ 40%     400       -      5
# 246                                                  -      50       -      -
# 247                                                  -     100       3      -
# 248  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 249  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5
# 100                                                  -      50       -      3
# 101   Inflicts 10 damage on targeted foe after combat.     150       -      3
# 375                                                  -      50       -      -
# 376                                                  -     100       -      -
# 377  Gives Atk+20% if weapon-triangle advantage, At...     200       -      -
# 378  Gives Atk+20% if weapon-triangle advantage, At...     300       5      -
# 19                                                   -      50       -      -
# 20                                                   -     100       3      -
# 21         Spd-5. Attack twice when initiating combat.     200       4      3
# 22         Spd-5. Attack twice when initiating combat.     300       -      5
# ..                                                 ...     ...     ...    ...
# 81                                                   -     100       -      -
# 82                                                   -     200       -      -
# 83                                                   -     300       5      -
# 180                                                  -      50       -      -
# 181                                                  -     100       -      -
# 182  Gives Atk+20% if weapon-triangle advantage, At...     200       -      -
# 183  Gives Atk+20% if weapon-triangle advantage, At...     300       5      -
# 48                                                   -      50       -      -
# 49                                                   -     100       3      -
# 50                    Effective against cavalry units.     200       4      3
# 51                    Effective against cavalry units.     300       -      5
# 4    If unit initiates attack, bonuses on foes with...     400       -      -
# 72                    Effective against flying units.       50       1      -
# 73                    Effective against flying units.      100       3      2
# 74                    Effective against flying units.      200       4      3
# 75                    Effective against flying units.      300       -      5
# 13                                                   -      50       -      1
# 14   After any combat, inflicts Spd-6 on foe throug...     150       -      3
# 242                                                  -      50       -      -
# 243                                                  -     100       3      -
# 244                                                  -     200       4      3
# 245  Enables counterattack regardless of distance i...     400       -      5
# 403                                                  -      50       -      -
# 404                                                  -     100       -      -
# 405  If unit initiates attack, unit recovers 4 HP a...     200       -      -
# 406  If unit initiates attack, unit recovers 4 HP a...     300       5      -
# 455                                                  -      50       -      -
# 456                                                  -     100       3      -
# 457                                                  -     200       4      3
# 458  Inflicts Def-4 on foes within 2 spaces through...     400       -      5
#
#                          Hero  IndexCol
# 88                       Abel        88
# 89                       Abel        89
# 90                       Abel        90
# 91                       Abel        91
# 36                    Alfonse        36
# 37                    Alfonse        37
# 38                    Alfonse        38
# 39                    Alfonse        39
# 467                       Alm       467
# 468                       Alm       468
# 469                       Alm       469
# 470                       Alm       470
# 68                       Anna        68
# 69                       Anna        69
# 70                       Anna        70
# 71                       Anna        71
# 246                    Arthur       246
# 247                    Arthur       247
# 248                    Arthur       248
# 249                    Arthur       249
# 100                     Azama       100
# 101                     Azama       101
# 375                     Azura       375
# 376                     Azura       376
# 377                     Azura       377
# 378                     Azura       378
# 19                      Barst        19
# 20                      Barst        20
# 21                      Barst        21
# 22                      Barst        22
# ..                        ...       ...
# 81               Tiki_(Young)        81
# 82               Tiki_(Young)        82
# 83               Tiki_(Young)        83
# 180                   Titania       180
# 181                   Titania       181
# 182                   Titania       182
# 183                   Titania       183
# 48                     Ursula        48
# 49                     Ursula        49
# 50                     Ursula        50
# 51                     Ursula        51
# 4                    Veronica         4
# 72                     Virion        72
# 73                     Virion        73
# 74                     Virion        74
# 75                     Virion        75
# 13                       Wrys        13
# 14                       Wrys        14
# 242                    Xander       242
# 243                    Xander       243
# 244                    Xander       244
# 245                    Xander       245
# 403  Xander_(Spring_Festival)       403
# 404  Xander_(Spring_Festival)       404
# 405  Xander_(Spring_Festival)       405
# 406  Xander_(Spring_Festival)       406
# 455                   Zephiel       455
# 456                   Zephiel       456
# 457                   Zephiel       457
# 458                   Zephiel       458
#
# [479 rows x 9 columns]

# %%
def concat_and_sort(skill):
    skill_df = skill[0]
    for df in skill[1:]:
        skill_df = pd.concat([skill_df, df], ignore_index=True)
    skill_df['IndexCol'] = skill_df.index.values
    skill_df = skill_df.sort_values(['Hero', 'IndexCol'])
    return skill_df
weapons_df = concat_and_sort(sorted_feh[0])
assits_df = concat_and_sort(sorted_feh[1])
specials_df = concat_and_sort(sorted_feh[2])
passives_df = concat_and_sort(sorted_feh[3])
print(weapons_df.head(4))
print(assits_df.head(8))
print(specials_df.head(8))
print(passives_df.head(8))
# Out:
#             Name Might Range                                       Effect  \
# 88    Iron Lance     6     1                                            -
# 89   Steel Lance     8     1                                            -
# 90   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 91  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#    SP Cost Default Unlock  Hero  IndexCol
# 88      50       -      -  Abel        88
# 89     100       -      -  Abel        89
# 90     200       4      -  Abel        90
# 91     300       5      5  Abel        91
#            Name Range                                             Effect  \
# 39         Swap     1                 Swap places with an adjacent ally.
# 16         Heal     1                                     Restores 5 HP.
# 17    Reconcile     1        Restores 7 HP each to target and this unit.
# 18       Martyr     1  Restores HP=7+ this unit's suffered damage.Uni...
# 66         Sing     1  Enables target to take another action.Cannot b...
# 5    Reposition     1      Moves adjacent ally to opposite side of unit.
# 35        Smite     1          Push adjacent ally 2 spaces farther away.
# 23  Rally Speed     1  Grants Spd+4 to an adjacent ally until the end...
#
#    SP Cost Default Unlock    Hero  IndexCol
# 39     150       4      3  Arthur        39
# 16       -       3      -   Azama        16
# 17     100       3      -   Azama        17
# 18     200       -      4   Azama        18
# 66     150       5      -   Azura        66
# 5      150       4      3   Barst         5
# 35     150       4      3  Bartre        35
# 23     150       4      -   Caeda        23
#                Name Cooldown  \
# 35   Holy Vestments        3
# 36            Aegis        3
# 11         Daylight        4
# 12              Sol        4
# 161     Dragon Gaze        4
# 162   Draconic Aura        3
# 27        Night Sky        4
# 28            Astra        5
#
#                                                 Effect SP Cost Default Unlock  \
# 35   Reduces damage inflicted by attacks from foes ...     100       4      -
# 36   Reduces damage inflicted by attacks from foes ...     200       -      4
# 11                           Heal 30% of damage dealt.     100       2      -
# 12                           Heal 50% of damage dealt.     200       -      4
# 161                                Grants +30% to Atk.     100       5      -
# 162                                Grants +30% to Atk.     200       -      5
# 27                        Grants +50% to damage dealt.     100       2      -
# 28                       Grants +150% to damage dealt.     200       -      4
#
#         Hero  IndexCol
# 35      Abel        35
# 36      Abel        36
# 11   Alfonse        11
# 12   Alfonse        12
# 161      Alm       161
# 162      Alm       162
# 27      Anna        27
# 28      Anna        28
#                Name                                             Effect  \
# 125           HP +3                               Grants +3 to max HP.
# 126           HP +4                               Grants +4 to max HP.
# 127           HP +5                               Grants +5 to max HP.
# 128  Swordbreaker 1  If unit's HP ≥ 90% in combat against a sword u...
# 129  Swordbreaker 2  If unit's HP ≥ 70% in combat against a sword u...
# 130  Swordbreaker 3  If unit's HP ≥ 50% in combat against a sword u...
# 47     Death Blow 1  Grants Atk+2 during combat if unit initiates t...
# 48     Death Blow 2  Grants Atk+4 during combat if unit initiates t...
#
#     SP Cost Unlock Type     Hero  IndexCol
# 125      40      -    A     Abel       125
# 126      80      4    A     Abel       126
# 127     160      5    A     Abel       127
# 128      50      -    B     Abel       128
# 129     100      -    B     Abel       129
# 130     200      4    B     Abel       130
# 47       50      1    A  Alfonse        47
# 48      100      2    A  Alfonse        48

# %%
radiance_hero_pool = {'5': [('red', ['Alm', 'Eirika', 'Eldigan', 'Ogma', 'Cain', 'Corrin', 'Karel', 'Chrom', 'Caeda', 'Seliph',
                            'Marth', 'Ryoma', 'Lyn', 'Lucina', 'Roy', 'Tiki', 'Sanaki', 'Tharja', 'Lilina', 'Leo']),
                          ('blue', ['Azura', 'Abel', 'Ephraim', 'Effie', 'Catria', 'Clair', 'Cordelia', 'Hinoka', 
                            'Peri','Lukas', 'Ninian', 'Nowi', 'Olwen', 'Reinhardt', 'Linde']), 
                          ('green', ['Camilla', 'Sheena', 'Hector', 'Hawkeye', 'Minerva', 'Raven', 'Fae', 
                                     'Merric', 'Julia']), 
                          ('colorless', ['Faye', 'Klein', 'Jeorge','Takumi', 'Rebecca', 'Kagero', 'Jaffar', 'Jakob', 'Elise', 'Sakura', 'Priscilla', 'Maria',
                          'Lachesis', 'Lucius'])], 
                      '4': [('red', ['Erika', 'Eliwood', 'Ogma', 'Olivia', 'Cain', 'Hana', 'Corrin','Chrom', 'Caeda',
                           'Seliph', 'Stahl', 'Draug', 'Palla', 'Hinata', 'Fir', 'Marth', 'Laslow',
                          'Selena', 'Roy', 'Lon\'qu', 'Tiki', 'Sophia', 'Henry', 'Lilina', 'Raigh']),('blue', ['Abel',
                          'Gwendolyn', 'Est', 'Effie', 'Oboro', 'Catria', 'Clair', 'Shanna', 'Jagen', 'Sully',
                          'Subaki', 'Cordelia', 'Donnel', 'Peri', 'Florina', 'Lukas', 'Corrin', 'Nowi', 'Odin',
                          'Reinhardt', 'Robin']),('green', ['Camilla', 'Gunter', 'Sheena', 'Cherche', 'Arthur', 'Bartre',
                          'Barst', 'Frederick', 'Beruka', 'Hawkeye', 'Raven', 'Fae', 'Cecilia', 'Nino', 'Merric']),
                          ('colorless', ['Klein', 'Gordin', 'Jeorge', 'Setsuna', 'Niles', 'Rebecca', 'Virion', 'Kagero', 'Gaius',
                          'Saizo', 'Jakob', 'Felicia', 'Matthew', 'Azama', 'Clarine', 'Sakura', 'Serra', 'Priscilla',
                          'Maria', 'Lachesis', 'Lissa', 'Wrys', 'Lucius'])],
                     '3': [('red', ['Eliwood', 'Olivia', 'Hana', 'Stahl', 'Draug', 'Palla', 'Hinata', 'Fir', 'Laslow',
                          'Selena', 'Lon\'qu', 'Tiki', 'Sophia', 'Henry', 'Raigh']), ('blue', ['Gwendolyn', 'Est', 'Oboro',
                          'Shana', 'Jagen', 'Sully', 'Subaki', 'Donnel', 'Florina', 'Corrin', 'Odin', 'Robin']),
                          ('green', ['Gunter', 'Cherche', 'Arthur', 'Bartre', 'Barst', 'Frederick', 'Beruka', 'Cecilia', 'Nino']),
                          ('colorless', ['Gordin', 'Setsuna', 'Niles', 'Virion', 'Gaius', 'Saizo', 'Felicia', 'Matthew', 'Azama',
                          'Clarine', 'Serra', 'Lissa', 'Wrys'])]}
radiance_focus = ['Ike', 'Titania', 'Soren', 'Mist']

rhp = radiance_hero_pool
print(len(rhp['5']))
print(len(rhp['5'][0][1]))
print(rhp['5'][0][0])
#each key is linked to a list of three tuples. The tuples have two elements, the first is the color in a string,
#the second is the heros at that star, in that color. Is this the best way to do this? Can I figure out a better system?

# generate 5 orbs, based on the percents of getting each color? then open each one, rolling percent on star level,
# and matching to the star and color, then pick from the list.
# Out:
# 4
# 20
# red

# %%
grouped = weapons_df.groupby('Hero', axis = 0)
#grouped.groups
#for key, item in grouped:
#    print(grouped.get_group(key)), '\n\n'
print(grouped.get_group('Abel'))
for name, group in grouped:
    print(name)
    print(group)
# Out:
#             Name Might Range                                       Effect  \
# 88    Iron Lance     6     1                                            -
# 89   Steel Lance     8     1                                            -
# 90   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 91  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#    SP Cost Default Unlock  Hero  IndexCol
# 88      50       -      -  Abel        88
# 89     100       -      -  Abel        89
# 90     200       4      -  Abel        90
# 91     300       5      5  Abel        91
# Abel
#             Name Might Range                                       Effect  \
# 88    Iron Lance     6     1                                            -
# 89   Steel Lance     8     1                                            -
# 90   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 91  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#    SP Cost Default Unlock  Hero  IndexCol
# 88      50       -      -  Abel        88
# 89     100       -      -  Abel        89
# 90     200       4      -  Abel        90
# 91     300       5      5  Abel        91
# Alfonse
#             Name Might Range  \
# 36    Iron Sword     6     1
# 37   Steel Sword     8     1
# 38  Silver Sword    11     1
# 39     Fólkvangr    16     1
#
#                                                Effect SP Cost Default Unlock  \
# 36                                                  -      50       2      -
# 37                                                  -     100       -      2
# 38                                                  -     200       -      3
# 39  Grants Atk+5 at start of turn if unit's HP ≤ 50%.     400       -      5
#
#        Hero  IndexCol
# 36  Alfonse        36
# 37  Alfonse        37
# 38  Alfonse        38
# 39  Alfonse        39
# Alm
#              Name Might Range  \
# 467    Iron Sword     6     1
# 468   Steel Sword     8     1
# 469  Silver Sword    11     1
# 470      Falchion    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 467                                                  -      50       -      -
# 468                                                  -     100       -      -
# 469                                                  -     200       -      -
# 470  Effective against dragons. At the start of eve...     400       5      -
#
#     Hero  IndexCol
# 467  Alm       467
# 468  Alm       468
# 469  Alm       469
# 470  Alm       470
# Anna
#           Name Might Range                                            Effect  \
# 68    Iron Axe     6     1                                                 -
# 69   Steel Axe     8     1                                                 -
# 70  Silver Axe    11     1                                                 -
# 71      Nóatún    16     1  Unit may move adjacent to any ally when HP ≤ 40%
#
#    SP Cost Default Unlock  Hero  IndexCol
# 68      50       2      -  Anna        68
# 69     100       -      2  Anna        69
# 70     200       -      3  Anna        70
# 71     400       -      5  Anna        71
# Arthur
#              Name Might Range  \
# 246      Iron Axe     6     1
# 247     Steel Axe     8     1
# 248   Emerald Axe     8     1
# 249  Emerald Axe+    12     1
#
#                                                 Effect SP Cost Default Unlock  \
# 246                                                  -      50       -      -
# 247                                                  -     100       3      -
# 248  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 249  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5
#
#        Hero  IndexCol
# 246  Arthur       246
# 247  Arthur       247
# 248  Arthur       248
# 249  Arthur       249
# Azama
#         Name Might Range                                            Effect  \
# 100  Assault    10     2                                                 -
# 101     Pain     3     2  Inflicts 10 damage on targeted foe after combat.
#
#     SP Cost Default Unlock   Hero  IndexCol
# 100      50       -      3  Azama       100
# 101     150       -      3  Azama       101
# Azura
#                 Name Might Range  \
# 375       Iron Lance     6     1
# 376      Steel Lance     8     1
# 377   Sapphire Lance     8     1
# 378  Sapphire Lance+    12     1
#
#                                                 Effect SP Cost Default Unlock  \
# 375                                                  -      50       -      -
# 376                                                  -     100       -      -
# 377  Gives Atk+20% if weapon-triangle advantage, At...     200       -      -
# 378  Gives Atk+20% if weapon-triangle advantage, At...     300       5      -
#
#       Hero  IndexCol
# 375  Azura       375
# 376  Azura       376
# 377  Azura       377
# 378  Azura       378
# Barst
#           Name Might Range                                       Effect  \
# 19    Iron Axe     6     1                                            -
# 20   Steel Axe     8     1                                            -
# 21   Brave Axe     5     1  Spd-5. Attack twice when initiating combat.
# 22  Brave Axe+     8     1  Spd-5. Attack twice when initiating combat.
#
#    SP Cost Default Unlock   Hero  IndexCol
# 19      50       -      -  Barst        19
# 20     100       3      -  Barst        20
# 21     200       4      3  Barst        21
# 22     300       -      5  Barst        22
# Bartre
#           Name Might Range                             Effect SP Cost Default  \
# 208   Iron Axe     6     1                                  -      50       -
# 209  Steel Axe     8     1                                  -     100       3
# 210     Hammer     8     1  Effective against armored units.      200       4
# 211    Hammer+    12     1  Effective against armored units.      200       -
#
#     Unlock    Hero  IndexCol
# 208      -  Bartre       208
# 209      -  Bartre       209
# 210      3  Bartre       210
# 211      5  Bartre       211
# Beruka
#             Name Might Range                                           Effect  \
# 475     Iron Axe     6     1                                                -
# 476    Steel Axe     8     1                                                -
# 477   Killer Axe     7     1  Accelerates Special trigger (cooldown count-1).
# 478  Killer Axe+    11     1  Accelerates Special trigger (cooldown count-1).
#
#     SP Cost Default Unlock    Hero  IndexCol
# 475      50       -      -  Beruka       475
# 476     100       3      -  Beruka       476
# 477     200       4      3  Beruka       477
# 478     300       5      5  Beruka       478
# Bruno
#            Name Might Range  \
# 288  Valaskjálf    14     2
#
#                                                 Effect SP Cost Default Unlock  \
# 288  Enables unit at ≤ 50% HP to strike first, even...     400       -      -
#
#       Hero  IndexCol
# 288  Bruno       288
# Caeda
#              Name Might Range                             Effect SP Cost  \
# 146    Iron Sword     6     1                                  -      50
# 147   Steel Sword     8     1                                  -     100
# 148   Armorslayer     8     1  Effective against armored units.      200
# 149  Armorslayer+    12     1  Effective against armored units.      300
#
#     Default Unlock   Hero  IndexCol
# 146       -      -  Caeda       146
# 147       -      -  Caeda       147
# 148       4      -  Caeda       148
# 149       5      5  Caeda       149
# Cain
#             Name Might Range                                       Effect  \
# 64    Iron Sword     6     1                                            -
# 65   Steel Sword     8     1                                            -
# 66   Brave Sword     5     1  Spd-5. Attack twice when initiating combat.
# 67  Brave Sword+     8     1  Spd-5. Attack twice when initiating combat.
#
#    SP Cost Default Unlock  Hero  IndexCol
# 64      50       -      -  Cain        64
# 65     100       -      -  Cain        65
# 66     200       4      -  Cain        66
# 67     300       5      5  Cain        67
# Camilla
#            Name Might Range                                       Effect  \
# 425    Iron Axe     6     1                                            -
# 426   Steel Axe     8     1                                            -
# 427   Brave Axe     5     1  Spd-5. Attack twice when initiating combat.
# 428  Brave Axe+     8     1  Spd-5. Attack twice when initiating combat.
#
#     SP Cost Default Unlock     Hero  IndexCol
# 425      50       -      -  Camilla       425
# 426     100       -      -  Camilla       426
# 427     200       4      -  Camilla       427
# 428     300       5      5  Camilla       428
# Camilla_(Spring_Festival)
#            Name Might Range  \
# 254        Wind     4     2
# 255      Elwind     6     2
# 256   Green Egg     7     2
# 257  Green Egg+    11     2
#
#                                                 Effect SP Cost Default Unlock  \
# 254                                                  -      50       -      -
# 255                                                  -     100       -      -
# 256  If unit initiates attack, unit recovers 4 HP a...     200       -      -
# 257  If unit initiates attack, unit recovers 4 HP a...     300       5      -
#
#                           Hero  IndexCol
# 254  Camilla_(Spring_Festival)       254
# 255  Camilla_(Spring_Festival)       255
# 256  Camilla_(Spring_Festival)       256
# 257  Camilla_(Spring_Festival)       257
# Camus
#         Name Might Range                                             Effect  \
# 23  Gradivus    16     1  Enables counterattack regardless of distance i...
#
#    SP Cost Default Unlock   Hero  IndexCol
# 23     400       -      -  Camus        23
# Catria
#              Name Might Range  \
# 28     Iron Lance     6     1
# 29    Steel Lance     8     1
# 30   Killer Lance     7     1
# 31  Killer Lance+    11     1
#
#                                              Effect SP Cost Default Unlock  \
# 28                                                -      50       -      -
# 29                                                -     100       3      -
# 30  Accelerates Special trigger (cooldown count-1).     200       4      3
# 31  Accelerates Special trigger (cooldown count-1).     300       5      5
#
#       Hero  IndexCol
# 28  Catria        28
# 29  Catria        29
# 30  Catria        30
# 31  Catria        31
# Cecilia
#             Name Might Range                                       Effect  \
# 204         Wind     4     2                                            -
# 205       Elwind     6     2                                            -
# 206   Gronnraven     7     2  Grants weapon advantage vs. colorless foes.
# 207  Gronnraven+    11     2  Grants weapon advantage vs. colorless foes.
#
#     SP Cost Default Unlock     Hero  IndexCol
# 204      50       1      -  Cecilia       204
# 205     100       3      2  Cecilia       205
# 206     200       4      3  Cecilia       206
# 207     300       -      5  Cecilia       207
# Cherche
#           Name Might Range                             Effect SP Cost Default  \
# 192   Iron Axe     6     1                                  -      50       -
# 193  Steel Axe     8     1                                  -     100       3
# 194     Hammer     8     1  Effective against armored units.      200       4
# 195    Hammer+    12     1  Effective against armored units.      200       5
#
#     Unlock     Hero  IndexCol
# 192      -  Cherche       192
# 193      -  Cherche       193
# 194      3  Cherche       194
# 195      5  Cherche       195
# Chrom
#              Name Might Range  \
# 325    Iron Sword     6     1
# 326   Steel Sword     8     1
# 327  Silver Sword    11     1
# 328      Falchion    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 325                                                  -      50       -      -
# 326                                                  -     100       -      -
# 327                                                  -     200       4      -
# 328  Effective against dragons. At the start of eve...     400       5      5
#
#       Hero  IndexCol
# 325  Chrom       325
# 326  Chrom       326
# 327  Chrom       327
# 328  Chrom       328
# Chrom_(Spring_Festival)
#             Name Might Range  \
# 114     Iron Axe     6     1
# 115    Steel Axe     8     1
# 116   Carrot Axe     9     1
# 117  Carrot Axe+    13     1
#
#                                                 Effect SP Cost Default Unlock  \
# 114                                                  -      50       -      -
# 115                                                  -     100       -      -
# 116  If unit initiates attack, unit recovers 4 HP a...     200       -      -
# 117  If unit initiates attack, unit recovers 4 HP a...     300       5      -
#
#                         Hero  IndexCol
# 114  Chrom_(Spring_Festival)       114
# 115  Chrom_(Spring_Festival)       115
# 116  Chrom_(Spring_Festival)       116
# 117  Chrom_(Spring_Festival)       117
# Clair
#               Name Might Range Effect SP Cost Default Unlock   Hero  IndexCol
# 439     Iron Lance     6     1      -      50       -      -  Clair       439
# 440    Steel Lance     8     1      -     100       -      -  Clair       440
# 441   Silver Lance    11     1      -     200       4      -  Clair       441
# 442  Silver Lance+    15     1      -     300       5      -  Clair       442
# Clarine
#         Name Might Range                                             Effect  \
# 220  Assault    10     2                                                  -
# 221     Fear     5     2  After combat, inflicts Atk-6 on targeted foe t...
#
#     SP Cost Default Unlock     Hero  IndexCol
# 220      50       -      -  Clarine       220
# 221     150       -      3  Clarine       221
# Cordelia
#              Name Might Range                                       Effect  \
# 150    Iron Lance     6     1                                            -
# 151   Steel Lance     8     1                                            -
# 152   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 153  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#     SP Cost Default Unlock      Hero  IndexCol
# 150      50       -      -  Cordelia       150
# 151     100       -      -  Cordelia       151
# 152     200       4      -  Cordelia       152
# 153     300       5      5  Cordelia       153
# Corrin_(F)
#              Name Might Range  \
# 212   Fire Breath     6     1
# 213  Fire Breath+     8     1
# 214   Dark Breath     9     1
# 215  Dark Breath+    13     1
#
#                                                 Effect SP Cost Default Unlock  \
# 212                                                  -      50       -      -
# 213                                                  -     100       3      -
# 214  After this unit attacks, foes within 2 spaces ...     200       4      3
# 215  After this unit attacks, foes within 2 spaces ...     300       -      5
#
#            Hero  IndexCol
# 212  Corrin_(F)       212
# 213  Corrin_(F)       213
# 214  Corrin_(F)       214
# 215  Corrin_(F)       215
# Corrin_(M)
#              Name Might Range  \
# 250    Iron Sword     6     1
# 251   Steel Sword     8     1
# 252  Silver Sword    11     1
# 253          Yato    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 250                                                  -      50       -      -
# 251                                                  -     100       -      -
# 252                                                  -     200       4      -
# 253  Grants Spd+4 during combat if unit initiates a...     400       5      5
#
#            Hero  IndexCol
# 250  Corrin_(M)       250
# 251  Corrin_(M)       251
# 252  Corrin_(M)       252
# 253  Corrin_(M)       253
# Donnel
#              Name Might Range                                       Effect  \
# 280    Iron Lance     6     1                                            -
# 281   Steel Lance     8     1                                            -
# 282   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 283  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#     SP Cost Default Unlock    Hero  IndexCol
# 280      50       1      -  Donnel       280
# 281     100       3      2  Donnel       281
# 282     200       4      3  Donnel       282
# 283     300       -      5  Donnel       283
# Draug
#              Name Might Range                                       Effect  \
# 184    Iron Sword     6     1                                            -
# 185   Steel Sword     8     1                                            -
# 186   Brave Sword     5     1  Spd-5. Attack twice when initiating combat.
# 187  Brave Sword+     8     1  Spd-5. Attack twice when initiating combat.
#
#     SP Cost Default Unlock   Hero  IndexCol
# 184      50       2      -  Draug       184
# 185     100       -      2  Draug       185
# 186     200       4      3  Draug       186
# 187     300       5      5  Draug       187
# Effie
#               Name Might Range Effect SP Cost Default Unlock   Hero  IndexCol
# 289     Iron Lance     6     1      -      50       -      -  Effie       289
# 290    Steel Lance     8     1      -     100       -      -  Effie       290
# 291   Silver Lance    11     1      -     200       4      -  Effie       291
# 292  Silver Lance+    15     1      -     300       5      5  Effie       292
# Eirika
#              Name Might Range  \
# 162    Iron Sword     6     1
# 163   Steel Sword     8     1
# 164  Silver Sword    11     1
# 165     Sieglinde    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 162                                                  -      50       -      -
# 163                                                  -     100       -      -
# 164                                                  -     200       4      -
# 165  Grants adjacent allies Atk+3 through their nex...     400       5      5
#
#        Hero  IndexCol
# 162  Eirika       162
# 163  Eirika       163
# 164  Eirika       164
# 165  Eirika       165
# Eldigan
#              Name Might Range  \
# 176    Iron Sword     6     1
# 177   Steel Sword     8     1
# 178  Killing Edge     7     1
# 179   Mystletainn    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 176                                                -      50       -      -
# 177                                                -     100       -      -
# 178  Accelerates Special trigger (cooldown count-1).     200       -      -
# 179  Accelerates Special trigger (cooldown count-1).     400       5      -
#
#         Hero  IndexCol
# 176  Eldigan       176
# 177  Eldigan       177
# 178  Eldigan       178
# 179  Eldigan       179
# Elise
#         Name Might Range                                             Effect  \
# 174  Assault    10     2                                                  -
# 175  Gravity     6     2  After any combat, prevents foe from moving mor...
#
#     SP Cost Default Unlock   Hero  IndexCol
# 174      50       -      -  Elise       174
# 175     150       -      -  Elise       175
# Eliwood
#              Name Might Range  \
# 333    Iron Sword     6     1
# 334   Steel Sword     8     1
# 335  Silver Sword    11     1
# 336      Durandal    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 333                                                  -      50       -      -
# 334                                                  -     100       3      -
# 335                                                  -     200       4      3
# 336  Grants Atk+4 during combat if unit initiates a...     400       5      5
#
#         Hero  IndexCol
# 333  Eliwood       333
# 334  Eliwood       334
# 335  Eliwood       335
# 336  Eliwood       336
# Ephraim
#             Name Might Range  \
# 353   Iron Lance     6     1
# 354  Steel Lance     8     1
# 355  Heavy Spear     8     1
# 356     Siegmund    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 353                                                  -      50       -      -
# 354                                                  -     100       -      -
# 355                  Effective against armored units.      200       -      -
# 356  Grants adjacent allies Atk+3 through their nex...     400       5      -
#
#         Hero  IndexCol
# 353  Ephraim       353
# 354  Ephraim       354
# 355  Ephraim       355
# 356  Ephraim       356
# Est
#              Name Might Range                             Effect SP Cost  \
# 447    Iron Lance     6     1                                  -      50
# 448   Steel Lance     8     1                                  -     100
# 449   Heavy Spear     8     1  Effective against armored units.      200
# 450  Heavy Spear+    12     1  Effective against armored units.      300
#
#     Default Unlock Hero  IndexCol
# 447       -      -  Est       447
# 448       3      -  Est       448
# 449       4      3  Est       449
# 450       -      5  Est       450
# Fae
#              Name Might Range  \
# 44    Fire Breath     6     1
# 45   Fire Breath+     8     1
# 46   Light Breath     9     1
# 47  Light Breath+    13     1
#
#                                                Effect SP Cost Default Unlock  \
# 44                                                  -      50       -      -
# 45                                                  -     100       -      -
# 46  Grants adjacent allies Def/Res+4 through their...     200       4      -
# 47  Grants adjacent allies Def/Res+4 through their...     300       5      5
#
#    Hero  IndexCol
# 44  Fae        44
# 45  Fae        45
# 46  Fae        46
# 47  Fae        47
# Faye
#                Name Might Range  \
# 363        Iron Bow     4     2
# 364       Steel Bow     6     2
# 365   Firesweep Bow     7     2
# 366  Firesweep Bow+    11     2
#
#                                                 Effect SP Cost Default Unlock  \
# 363                   Effective against flying units.       50       -      -
# 364                   Effective against flying units.      100       -      -
# 365  Effective against flying units. Unit and enemi...     200       -      -
# 366  Effective against flying units. Unit and enemi...     300       5      -
#
#      Hero  IndexCol
# 363  Faye       363
# 364  Faye       364
# 365  Faye       365
# 366  Faye       366
# Felicia
#                Name Might Range  \
# 395     Iron Dagger     3     2
# 396    Steel Dagger     5     2
# 397   Silver Dagger     7     2
# 398  Silver Dagger+    10     2
#
#                                                 Effect SP Cost Default Unlock  \
# 395  After combat, inflicts Def/Res-3 on foe throug...      50       1      -
# 396  After combat, inflicts Def/Res-3 on foe throug...     100       3      2
# 397  After combat, inflicts Def/Res-5 on foe throug...     200       4      3
# 398  After combat, inflicts Def/Res-7 on foe throug...     300       5      5
#
#         Hero  IndexCol
# 395  Felicia       395
# 396  Felicia       396
# 397  Felicia       397
# 398  Felicia       398
# Fir
#              Name Might Range  \
# 52     Iron Sword     6     1
# 53    Steel Sword     8     1
# 54   Killing Edge     7     1
# 55  Killing Edge+    11     1
#
#                                              Effect SP Cost Default Unlock  \
# 52                                                -      50       -      -
# 53                                                -     100       3      -
# 54  Accelerates Special trigger (cooldown count-1).     200       4      3
# 55  Accelerates Special trigger (cooldown count-1).     300       5      5
#
#    Hero  IndexCol
# 52  Fir        52
# 53  Fir        53
# 54  Fir        54
# 55  Fir        55
# Florina
#              Name Might Range                             Effect SP Cost  \
# 158    Iron Lance     6     1                                  -      50
# 159   Steel Lance     8     1                                  -     100
# 160   Heavy Spear     8     1  Effective against armored units.      200
# 161  Heavy Spear+    12     1  Effective against armored units.      300
#
#     Default Unlock     Hero  IndexCol
# 158       -      -  Florina       158
# 159       3      -  Florina       159
# 160       4      3  Florina       160
# 161       -      5  Florina       161
# Frederick
#           Name Might Range                             Effect SP Cost Default  \
# 415   Iron Axe     6     1                                  -      50       -
# 416  Steel Axe     8     1                                  -     100       3
# 417     Hammer     8     1  Effective against armored units.      200       4
# 418    Hammer+    12     1  Effective against armored units.      200       5
#
#     Unlock       Hero  IndexCol
# 415      -  Frederick       415
# 416      -  Frederick       416
# 417      3  Frederick       417
# 418      5  Frederick       418
# Gaius
#               Name Might Range  \
# 391    Iron Dagger     3     2
# 392   Steel Dagger     5     2
# 393   Rogue Dagger     4     2
# 394  Rogue Dagger+     7     2
#
#                                                 Effect SP Cost Default Unlock  \
# 391  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 392  After combat, inflicts Def/Res-3 on foe throug...     100       3      -
# 393  After combat, inflicts Def/Res-3 on foe throug...     200       4      3
# 394  After combat, inflicts Def/Res-5 on foe throug...     300       -      5
#
#       Hero  IndexCol
# 391  Gaius       391
# 392  Gaius       392
# 393  Gaius       393
# 394  Gaius       394
# Gordin
#           Name Might Range                                             Effect  \
# 9     Iron Bow     4     2                   Effective against flying units.
# 10   Steel Bow     6     2                   Effective against flying units.
# 11   Brave Bow     4     2  Spd-5. Effective against flying units. Attacks...
# 12  Brave Bow+     7     2  Spd-5. Effective against flying units. Attacks...
#
#    SP Cost Default Unlock    Hero  IndexCol
# 9       50       -      -  Gordin         9
# 10     100       3      -  Gordin        10
# 11     200       4      3  Gordin        11
# 12     300       5      5  Gordin        12
# Gunter
#             Name Might Range Effect SP Cost Default Unlock    Hero  IndexCol
# 319     Iron Axe     6     1      -      50       1      -  Gunter       319
# 320    Steel Axe     8     1      -     100       3      2  Gunter       320
# 321   Silver Axe    11     1      -     200       4      3  Gunter       321
# 322  Silver Axe+    15     1      -     300       -      5  Gunter       322
# Gwendolyn
#               Name Might Range  \
# 226     Iron Lance     6     1
# 227    Steel Lance     8     1
# 228   Killer Lance     7     1
# 229  Killer Lance+    11     1
#
#                                               Effect SP Cost Default Unlock  \
# 226                                                -      50       -      -
# 227                                                -     100       3      -
# 228  Accelerates Special trigger (cooldown count-1).     200       4      3
# 229  Accelerates Special trigger (cooldown count-1).     300       -      5
#
#           Hero  IndexCol
# 226  Gwendolyn       226
# 227  Gwendolyn       227
# 228  Gwendolyn       228
# 229  Gwendolyn       229
# Hana
#              Name Might Range                             Effect SP Cost  \
# 200    Iron Sword     6     1                                  -      50
# 201   Steel Sword     8     1                                  -     100
# 202   Armorslayer     8     1  Effective against armored units.      200
# 203  Armorslayer+    12     1  Effective against armored units.      300
#
#     Default Unlock  Hero  IndexCol
# 200       1      -  Hana       200
# 201       3      2  Hana       201
# 202       4      3  Hana       202
# 203       5      5  Hana       203
# Hawkeye
#             Name Might Range                                           Effect  \
# 309     Iron Axe     6     1                                                -
# 310    Steel Axe     8     1                                                -
# 311   Killer Axe     7     1  Accelerates Special trigger (cooldown count-1).
# 312  Killer Axe+    11     1  Accelerates Special trigger (cooldown count-1).
#
#     SP Cost Default Unlock     Hero  IndexCol
# 309      50       -      -  Hawkeye       309
# 310     100       -      -  Hawkeye       310
# 311     200       4      3  Hawkeye       311
# 312     300       5      5  Hawkeye       312
# Hector
#            Name Might Range  \
# 110    Iron Axe     6     1
# 111   Steel Axe     8     1
# 112  Silver Axe    11     1
# 113      Armads    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 110                                                  -      50       -      -
# 111                                                  -     100       -      -
# 112                                                  -     200       -      -
# 113  Unit makes a guaranteed follow-up attack when ...     400       5      -
#
#        Hero  IndexCol
# 110  Hector       110
# 111  Hector       111
# 112  Hector       112
# 113  Hector       113
# Henry
#             Name Might Range                                       Effect  \
# 222         Flux     4     2                                            -
# 223         Ruin     6     2                                            -
# 224   Rauðrraven     7     2  Grants weapon advantage vs. colorless foes.
# 225  Rauðrraven+    11     2  Grants weapon advantage vs. colorless foes.
#
#     SP Cost Default Unlock   Hero  IndexCol
# 222      50       -      -  Henry       222
# 223     100       3      -  Henry       223
# 224     200       4      3  Henry       224
# 225     300       -      5  Henry       225
# Hinata
#             Name Might Range  \
# 337   Iron Sword     6     1
# 338  Steel Sword     8     1
# 339   Ruby Sword     8     1
# 340  Ruby Sword+    12     1
#
#                                                 Effect SP Cost Default Unlock  \
# 337                                                  -      50       1      -
# 338                                                  -     100       3      2
# 339  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 340  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5
#
#        Hero  IndexCol
# 337  Hinata       337
# 338  Hinata       338
# 339  Hinata       339
# 340  Hinata       340
# Hinoka
#              Name Might Range                                       Effect  \
# 268    Iron Lance     6     1                                            -
# 269   Steel Lance     8     1                                            -
# 270   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 271  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#     SP Cost Default Unlock    Hero  IndexCol
# 268      50       -      -  Hinoka       268
# 269     100       -      -  Hinoka       269
# 270     200       -      -  Hinoka       270
# 271     300       5      -  Hinoka       271
# Ike
#            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3       Ragnell    16     1
#
#                                               Effect SP Cost Default Unlock  \
# 0                                                  -      50       -      -
# 1                                                  -     100       -      -
# 2                                                  -     200       -      -
# 3  Enables counterattack regardless of distance i...     400       5      -
#
#   Hero  IndexCol
# 0  Ike         0
# 1  Ike         1
# 2  Ike         2
# 3  Ike         3
# Jaffar
#                Name Might Range  \
# 383     Iron Dagger     3     2
# 384    Steel Dagger     5     2
# 385   Silver Dagger     7     2
# 386  Deathly Dagger    11     2
#
#                                                 Effect SP Cost Default Unlock  \
# 383  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 384  After combat, inflicts Def/Res-3 on foe throug...     100       -      -
# 385  After combat, inflicts Def/Res-5 on foe throug...     200       -      -
# 386  After combat, inflicts Def/Res-7 on foe throug...     400       5      -
#
#        Hero  IndexCol
# 383  Jaffar       383
# 384  Jaffar       384
# 385  Jaffar       385
# 386  Jaffar       386
# Jagen
#               Name Might Range Effect SP Cost Default Unlock   Hero  IndexCol
# 293     Iron Lance     6     1      -      50       -      -  Jagen       293
# 294    Steel Lance     8     1      -     100       3      -  Jagen       294
# 295   Silver Lance    11     1      -     200       4      3  Jagen       295
# 296  Silver Lance+    15     1      -     300       -      5  Jagen       296
# Jakob
#                Name Might Range  \
# 166     Iron Dagger     3     2
# 167    Steel Dagger     5     2
# 168   Silver Dagger     7     2
# 169  Silver Dagger+    10     2
#
#                                                 Effect SP Cost Default Unlock  \
# 166  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 167  After combat, inflicts Def/Res-3 on foe throug...     100       -      -
# 168  After combat, inflicts Def/Res-5 on foe throug...     200       4      -
# 169  After combat, inflicts Def/Res-7 on foe throug...     300       5      5
#
#       Hero  IndexCol
# 166  Jakob       166
# 167  Jakob       167
# 168  Jakob       168
# 169  Jakob       169
# Jeorge
#            Name Might Range  \
# 154    Iron Bow     4     2
# 155   Steel Bow     6     2
# 156  Silver Bow     9     2
# 157     Parthia    14     2
#
#                                                 Effect SP Cost Default Unlock  \
# 154                   Effective against flying units.       50       -      -
# 155                   Effective against flying units.      100       -      -
# 156                   Effective against flying units.      200       4      -
# 157  Effective against flying units. Grants Res+4 d...     400       5      5
#
#        Hero  IndexCol
# 154  Jeorge       154
# 155  Jeorge       155
# 156  Jeorge       156
# 157  Jeorge       157
# Julia
#            Name Might Range  \
# 170        Wind     4     2
# 171      Elwind     6     2
# 172  Rexcalibur     9     2
# 173        Naga    14     2
#
#                                                 Effect SP Cost Default Unlock  \
# 170                                                  -      50       -      -
# 171                                                  -     100       -      -
# 172                                                  -     200       -      -
# 173  Effective against dragons. Grants Def/Res+2 wh...     400       5      -
#
#       Hero  IndexCol
# 170  Julia       170
# 171  Julia       171
# 172  Julia       172
# 173  Julia       173
# Kagero
#                Name Might Range  \
# 138     Iron Dagger     3     2
# 139    Steel Dagger     5     2
# 140   Poison Dagger     2     2
# 141  Poison Dagger+     5     2
#
#                                                 Effect SP Cost Default Unlock  \
# 138  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 139  After combat, inflicts Def/Res-3 on foe throug...     100       -      -
# 140  Effective against infantry units. Infantry foe...     200       4      -
# 141  Effective against infantry units. Infantry foe...     300       5      5
#
#        Hero  IndexCol
# 138  Kagero       138
# 139  Kagero       139
# 140  Kagero       140
# 141  Kagero       141
# Karel
#             Name Might Range                                       Effect  \
# 134   Iron Sword     6     1                                            -
# 135  Steel Sword     8     1                                            -
# 136       Wo Dao     9     1  Grants +10 to damage when Special triggers.
# 137      Wo Dao+    13     1  Grants +10 to damage when Special triggers.
#
#     SP Cost Default Unlock   Hero  IndexCol
# 134      50       -      -  Karel       134
# 135     100       -      -  Karel       135
# 136     200       -      -  Karel       136
# 137     300       5      -  Karel       137
# Klein
#            Name Might Range  \
# 387    Iron Bow     4     2
# 388   Steel Bow     6     2
# 389   Brave Bow     4     2
# 390  Brave Bow+     7     2
#
#                                                 Effect SP Cost Default Unlock  \
# 387                   Effective against flying units.       50       -      -
# 388                   Effective against flying units.      100       -      -
# 389  Spd-5. Effective against flying units. Attacks...     200       4      -
# 390  Spd-5. Effective against flying units. Attacks...     300       5      5
#
#       Hero  IndexCol
# 387  Klein       387
# 388  Klein       388
# 389  Klein       389
# 390  Klein       390
# Lachesis
#         Name Might Range                            Effect SP Cost Default  \
# 323  Assault    10     2                                 -      50       -
# 324   Absorb     4     2  Recovers HP=50% of damage dealt.     150       -
#
#     Unlock      Hero  IndexCol
# 323      -  Lachesis       323
# 324      4  Lachesis       324
# Laslow
#              Name Might Range Effect SP Cost Default Unlock    Hero  IndexCol
# 92     Iron Sword     6     1      -      50       -      -  Laslow        92
# 93    Steel Sword     8     1      -     100       3      -  Laslow        93
# 94   Silver Sword    11     1      -     200       4      3  Laslow        94
# 95  Silver Sword+    15     1      -     300       -      5  Laslow        95
# Leo
#          Name Might Range                                             Effect  \
# 40       Flux     4     2                                                  -
# 41       Ruin     6     2                                                  -
# 42     Fenrir     9     2                                                  -
# 43  Brynhildr    14     2  If unit initiates attack, restricts foe's next...
#
#    SP Cost Default Unlock Hero  IndexCol
# 40      50       -      -  Leo        40
# 41     100       -      -  Leo        41
# 42     200       -      -  Leo        42
# 43     400       5      -  Leo        43
# Lilina
#            Name Might Range Effect SP Cost Default Unlock    Hero  IndexCol
# 411        Fire     4     2      -      50       -      -  Lilina       411
# 412      Elfire     6     2      -     100       -      -  Lilina       412
# 413   Bolganone     9     2      -     200       4      -  Lilina       413
# 414  Bolganone+    13     2      -     300       5      5  Lilina       414
# Linde
#           Name Might Range                                             Effect  \
# 443    Thunder     4     2                                                  -
# 444  Elthunder     6     2                                                  -
# 445     Thoron     9     2                                                  -
# 446       Aura    14     2  Restores 5 HP to adjacent allies after any com...
#
#     SP Cost Default Unlock   Hero  IndexCol
# 443      50       -      -  Linde       443
# 444     100       -      -  Linde       444
# 445     200       -      -  Linde       445
# 446     400       5      -  Linde       446
# Lissa
#        Name Might Range                                             Effect  \
# 56  Assault    10     2                                                  -
# 57  Gravity     6     2  After any combat, prevents foe from moving mor...
#
#    SP Cost Default Unlock   Hero  IndexCol
# 56      50       -      1  Lissa        56
# 57     150       -      3  Lissa        57
# Lon'qu
#               Name Might Range  \
# 399     Iron Sword     6     1
# 400    Steel Sword     8     1
# 401   Killing Edge     7     1
# 402  Killing Edge+    11     1
#
#                                               Effect SP Cost Default Unlock  \
# 399                                                -      50       -      -
# 400                                                -     100       3      -
# 401  Accelerates Special trigger (cooldown count-1).     200       4      3
# 402  Accelerates Special trigger (cooldown count-1).     300       -      5
#
#        Hero  IndexCol
# 399  Lon'qu       399
# 400  Lon'qu       400
# 401  Lon'qu       401
# 402  Lon'qu       402
# Lucina
#              Name Might Range  \
# 216    Iron Sword     6     1
# 217   Steel Sword     8     1
# 218  Silver Sword    11     1
# 219      Falchion    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 216                                                  -      50       -      -
# 217                                                  -     100       -      -
# 218                                                  -     200       -      -
# 219  Effective against dragons. At the start of eve...     400       5      -
#
#        Hero  IndexCol
# 216  Lucina       216
# 217  Lucina       217
# 218  Lucina       218
# 219  Lucina       219
# Lucina_(Spring_Festival)
#           Name Might Range                                             Effect  \
# 315    Thunder     4     2                                                  -
# 316  Elthunder     6     2                                                  -
# 317   Blue Egg     7     2  If unit initiates attack, unit recovers 4 HP a...
# 318  Blue Egg+    11     2  If unit initiates attack, unit recovers 4 HP a...
#
#     SP Cost Default Unlock                      Hero  IndexCol
# 315      50       -      -  Lucina_(Spring_Festival)       315
# 316     100       -      -  Lucina_(Spring_Festival)       316
# 317     200       -      -  Lucina_(Spring_Festival)       317
# 318     300       5      -  Lucina_(Spring_Festival)       318
# Lucius
#         Name Might Range                                            Effect  \
# 423  Assault    10     2                                                 -
# 424     Pain     3     2  Inflicts 10 damage on targeted foe after combat.
#
#     SP Cost Default Unlock    Hero  IndexCol
# 423      50       -      4  Lucius       423
# 424     150       -      4  Lucius       424
# Lukas
#               Name Might Range  \
# 122     Iron Lance     6     1
# 123    Steel Lance     8     1
# 124   Killer Lance     7     1
# 125  Killer Lance+    11     1
#
#                                               Effect SP Cost Default Unlock  \
# 122                                                -      50       -      -
# 123                                                -     100       -      -
# 124  Accelerates Special trigger (cooldown count-1).     200       4      -
# 125  Accelerates Special trigger (cooldown count-1).     300       5      -
#
#       Hero  IndexCol
# 122  Lukas       122
# 123  Lukas       123
# 124  Lukas       124
# 125  Lukas       125
# Lyn
#              Name Might Range  \
# 276    Iron Sword     6     1
# 277   Steel Sword     8     1
# 278  Silver Sword    11     1
# 279     Sol Katti    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 276                                                  -      50       -      -
# 277                                                  -     100       -      -
# 278                                                  -     200       -      -
# 279  If wielder initiates attack at HP ≤ 50%, any f...     400       5      -
#
#     Hero  IndexCol
# 276  Lyn       276
# 277  Lyn       277
# 278  Lyn       278
# 279  Lyn       279
# Maria
#         Name Might Range                                             Effect  \
# 313  Assault    10     2                                                  -
# 314    Panic     7     2  After combat, bonuses on targeted foe become p...
#
#     SP Cost Default Unlock   Hero  IndexCol
# 313      50       -      4  Maria       313
# 314     150       -      4  Maria       314
# Marth
#              Name Might Range  \
# 272    Iron Sword     6     1
# 273   Steel Sword     8     1
# 274  Silver Sword    11     1
# 275      Falchion    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 272                                                  -      50       -      -
# 273                                                  -     100       -      -
# 274                                                  -     200       4      -
# 275  Effective against dragons. At the start of eve...     400       5      5
#
#       Hero  IndexCol
# 272  Marth       272
# 273  Marth       273
# 274  Marth       274
# 275  Marth       275
# Matthew
#               Name Might Range  \
# 305    Iron Dagger     3     2
# 306   Steel Dagger     5     2
# 307   Rogue Dagger     4     2
# 308  Rogue Dagger+     7     2
#
#                                                 Effect SP Cost Default Unlock  \
# 305  After combat, inflicts Def/Res-3 on foe throug...      50       2      -
# 306  After combat, inflicts Def/Res-3 on foe throug...     100       3      2
# 307  After combat, inflicts Def/Res-3 on foe throug...     200       4      3
# 308  After combat, inflicts Def/Res-5 on foe throug...     300       -      5
#
#         Hero  IndexCol
# 305  Matthew       305
# 306  Matthew       306
# 307  Matthew       307
# 308  Matthew       308
# Merric
#            Name Might Range                            Effect SP Cost Default  \
# 102        Wind     4     2                                 -      50       -
# 103      Elwind     6     2                                 -     100       -
# 104  Rexcalibur     9     2                                 -     200       4
# 105   Excalibur    14     2  Effective against flying units.      400       5
#
#     Unlock    Hero  IndexCol
# 102      -  Merric       102
# 103      -  Merric       103
# 104      -  Merric       104
# 105      5  Merric       105
# Michalis
#            Name Might Range                                           Effect  \
# 463    Iron Axe     6     1                                                -
# 464   Steel Axe     8     1                                                -
# 465  Silver Axe    11     1                                                -
# 466  Hauteclere    16     1  Accelerates Special trigger (cooldown count-1).
#
#     SP Cost Default Unlock      Hero  IndexCol
# 463      50       -      -  Michalis       463
# 464     100       3      -  Michalis       464
# 465     200       4      3  Michalis       465
# 466     400       -      5  Michalis       466
# Minerva
#            Name Might Range                                           Effect  \
# 188    Iron Axe     6     1                                                -
# 189   Steel Axe     8     1                                                -
# 190  Silver Axe    11     1                                                -
# 191  Hauteclere    16     1  Accelerates Special trigger (cooldown count-1).
#
#     SP Cost Default Unlock     Hero  IndexCol
# 188      50       -      -  Minerva       188
# 189     100       -      -  Minerva       189
# 190     200       -      -  Minerva       190
# ...
# 79  Smoke Dagger+     9     2
#
#                                                Effect SP Cost Default Unlock  \
# 76  After combat, inflicts Def/Res-3 on foe throug...      50       -      -
# 77  After combat, inflicts Def/Res-3 on foe throug...     100       3      -
# 78  After combat, inflicts Def/Res-4 on foes withi...     200       4      3
# 79  After combat, inflicts Def/Res-6 on foes withi...     300       -      5
#
#      Hero  IndexCol
# 76  Saizo        76
# 77  Saizo        77
# 78  Saizo        78
# 79  Saizo        79
# Sakura
#         Name Might Range                                             Effect  \
# 266  Assault    10     2                                                  -
# 267     Fear     5     2  After combat, inflicts Atk-6 on targeted foe t...
#
#     SP Cost Default Unlock    Hero  IndexCol
# 266      50       -      -  Sakura       266
# 267     150       -      4  Sakura       267
# Sanaki
#           Name Might Range                                             Effect  \
# 379       Fire     4     2                                                  -
# 380     Elfire     6     2                                                  -
# 381  Bolganone     9     2                                                  -
# 382  Cymbeline    14     2  Grants adjacent allies Atk+4 through their nex...
#
#     SP Cost Default Unlock    Hero  IndexCol
# 379      50       -      -  Sanaki       379
# 380     100       -      -  Sanaki       380
# 381     200       -      -  Sanaki       381
# 382     400       5      -  Sanaki       382
# Selena
#              Name Might Range                             Effect SP Cost  \
# 329    Iron Sword     6     1                                  -      50
# 330   Steel Sword     8     1                                  -     100
# 331   Armorslayer     8     1  Effective against armored units.      200
# 332  Armorslayer+    12     1  Effective against armored units.      300
#
#     Default Unlock    Hero  IndexCol
# 329       -      -  Selena       329
# 330       3      -  Selena       330
# 331       4      3  Selena       331
# 332       5      5  Selena       332
# Seliph
#              Name Might Range                                      Effect  \
# 359    Iron Sword     6     1                                           -
# 360   Steel Sword     8     1                                           -
# 361  Silver Sword    11     1                                           -
# 362       Tyrfing    16     1  Grants Def+4 in battle if unit's HP ≤ 50%.
#
#     SP Cost Default Unlock    Hero  IndexCol
# 359      50       -      -  Seliph       359
# 360     100       -      -  Seliph       360
# 361     200       4      -  Seliph       361
# 362     400       5      5  Seliph       362
# Serra
#         Name Might Range                            Effect SP Cost Default  \
# 433  Assault    10     2                                 -      50       -
# 434   Absorb     4     2  Recovers HP=50% of damage dealt.     150       -
#
#     Unlock   Hero  IndexCol
# 433      -  Serra       433
# 434      3  Serra       434
# Setsuna
#                Name Might Range  \
# 15         Iron Bow     4     2
# 16        Steel Bow     6     2
# 17   Assassin's Bow     7     2
# 18  Assassin's Bow+    11     2
#
#                                                Effect SP Cost Default Unlock  \
# 15                   Effective against flying units.       50       -      -
# 16                   Effective against flying units.      100       3      -
# 17  Effective against flying units. If target has ...     200       4      3
# 18  Effective against flying units. If target has ...     300       5      5
#
#        Hero  IndexCol
# 15  Setsuna        15
# 16  Setsuna        16
# 17  Setsuna        17
# 18  Setsuna        18
# Shanna
#              Name Might Range  \
# 84     Iron Lance     6     1
# 85    Steel Lance     8     1
# 86   Killer Lance     7     1
# 87  Killer Lance+    11     1
#
#                                              Effect SP Cost Default Unlock  \
# 84                                                -      50       -      -
# 85                                                -     100       3      -
# 86  Accelerates Special trigger (cooldown count-1).     200       4      3
# 87  Accelerates Special trigger (cooldown count-1).     300       -      5
#
#       Hero  IndexCol
# 84  Shanna        84
# 85  Shanna        85
# 86  Shanna        86
# 87  Shanna        87
# Sharena
#              Name Might Range  \
# 341    Iron Lance     6     1
# 342   Steel Lance     8     1
# 343  Silver Lance    11     1
# 344      Fensalir    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 341                                                  -      50       2      -
# 342                                                  -     100       -      2
# 343                                                  -     200       -      3
# 344  Inflicts Atk-4 on foes within 2 spaces through...     400       -      5
#
#         Hero  IndexCol
# 341  Sharena       341
# 342  Sharena       342
# 343  Sharena       343
# 344  Sharena       344
# Sheena
#           Name Might Range                                           Effect  \
# 5     Iron Axe     6     1                                                -
# 6    Steel Axe     8     1                                                -
# 7   Killer Axe     7     1  Accelerates Special trigger (cooldown count-1).
# 8  Killer Axe+    11     1  Accelerates Special trigger (cooldown count-1).
#
#   SP Cost Default Unlock    Hero  IndexCol
# 5      50       -      -  Sheena         5
# 6     100       -      -  Sheena         6
# 7     200       4      -  Sheena         7
# 8     300       5      5  Sheena         8
# Sophia
#         Name Might Range Effect SP Cost Default Unlock    Hero  IndexCol
# 371     Flux     4     2      -      50       1      -  Sophia       371
# 372     Ruin     6     2      -     100       3      2  Sophia       372
# 373   Fenrir     9     2      -     200       4      3  Sophia       373
# 374  Fenrir+    13     2      -     300       -      5  Sophia       374
# Soren
#             Name Might Range Effect SP Cost Default Unlock   Hero  IndexCol
# 301         Wind     4     2      -      50       -      -  Soren       301
# 302       Elwind     6     2      -     100       -      -  Soren       302
# 303   Rexcalibur     9     2      -     200       -      -  Soren       303
# 304  Rexcalibur+    13     2      -     300       5      -  Soren       304
# Stahl
#             Name Might Range  \
# 142   Iron Sword     6     1
# 143  Steel Sword     8     1
# 144   Ruby Sword     8     1
# 145  Ruby Sword+    12     1
#
#                                                 Effect SP Cost Default Unlock  \
# 142                                                  -      50       1      -
# 143                                                  -     100       3      2
# 144  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 145  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5
#
#       Hero  IndexCol
# 142  Stahl       142
# 143  Stahl       143
# 144  Stahl       144
# 145  Stahl       145
# Subaki
#                 Name Might Range  \
# 130       Iron Lance     6     1
# 131      Steel Lance     8     1
# 132   Sapphire Lance     8     1
# 133  Sapphire Lance+    12     1
#
#                                                 Effect SP Cost Default Unlock  \
# 130                                                  -      50       1      -
# 131                                                  -     100       3      2
# 132  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 133  Gives Atk+20% if weapon-triangle advantage, At...     300       5      5
#
#        Hero  IndexCol
# 130  Subaki       130
# 131  Subaki       131
# 132  Subaki       132
# 133  Subaki       133
# Sully
#                Name Might Range  \
# 96       Iron Lance     6     1
# 97      Steel Lance     8     1
# 98   Sapphire Lance     8     1
# 99  Sapphire Lance+    12     1
#
#                                                Effect SP Cost Default Unlock  \
# 96                                                  -      50       1      -
# 97                                                  -     100       3      2
# 98  Gives Atk+20% if weapon-triangle advantage, At...     200       4      3
# 99  Gives Atk+20% if weapon-triangle advantage, At...     300       -      5
#
#      Hero  IndexCol
# 96  Sully        96
# 97  Sully        97
# 98  Sully        98
# 99  Sully        99
# Takumi
#            Name Might Range  \
# 459    Iron Bow     4     2
# 460   Steel Bow     6     2
# 461  Silver Bow     9     2
# 462  Fujin Yumi    14     2
#
#                                                 Effect SP Cost Default Unlock  \
# 459                   Effective against flying units.       50       -      -
# 460                   Effective against flying units.      100       -      -
# 461                   Effective against flying units.      200       -      -
# 462  Effective against flying units. Unit can pass ...     400       5      -
#
#        Hero  IndexCol
# 459  Takumi       459
# 460  Takumi       460
# 461  Takumi       461
# 462  Takumi       462
# Tharja
#             Name Might Range  \
# 407         Flux     4     2
# 408         Ruin     6     2
# 409   Rauðrblade     9     2
# 410  Rauðrblade+    13     2
#
#                                                 Effect SP Cost Default Unlock  \
# 407                                                  -      50       -      -
# 408                                                  -     100       -      -
# 409  Slows Special trigger (cooldown count+1).Adds ...     200       4      -
# 410  Slows Special trigger (cooldown count+1).Adds ...     300       5      5
#
#        Hero  IndexCol
# 407  Tharja       407
# 408  Tharja       408
# 409  Tharja       409
# 410  Tharja       410
# Tiki_(Adult)
#                   Name Might Range  \
# 106        Fire Breath     6     1
# 107       Fire Breath+     8     1
# 108   Lightning Breath     7     1
# 109  Lightning Breath+    11     1
#
#                                                 Effect SP Cost Default Unlock  \
# 106                                                  -      50       -      -
# 107                                                  -     100       3      -
# 108  Enables counterattack regardless of attacker's...     200       4      3
# 109  Enables counterattack regardless of attacker's...     300       5      5
#
#              Hero  IndexCol
# 106  Tiki_(Adult)       106
# 107  Tiki_(Adult)       107
# 108  Tiki_(Adult)       108
# 109  Tiki_(Adult)       109
# Tiki_(Young)
#             Name Might Range Effect SP Cost Default Unlock          Hero  \
# 80   Fire Breath     6     1      -      50       -      -  Tiki_(Young)
# 81  Fire Breath+     8     1      -     100       -      -  Tiki_(Young)
# 82   Flametongue    11     1      -     200       -      -  Tiki_(Young)
# 83  Flametongue+    15     1      -     300       5      -  Tiki_(Young)
#
#     IndexCol
# 80        80
# 81        81
# 82        82
# 83        83
# Titania
#              Name Might Range  \
# 180      Iron Axe     6     1
# 181     Steel Axe     8     1
# 182   Emerald Axe     8     1
# 183  Emerald Axe+    12     1
#
#                                                 Effect SP Cost Default Unlock  \
# 180                                                  -      50       -      -
# 181                                                  -     100       -      -
# 182  Gives Atk+20% if weapon-triangle advantage, At...     200       -      -
# 183  Gives Atk+20% if weapon-triangle advantage, At...     300       5      -
#
#         Hero  IndexCol
# 180  Titania       180
# 181  Titania       181
# 182  Titania       182
# 183  Titania       183
# Ursula
#          Name Might Range                            Effect SP Cost Default  \
# 48    Thunder     4     2                                 -      50       -
# 49  Elthunder     6     2                                 -     100       3
# 50   Blárwolf     6     2  Effective against cavalry units.     200       4
# 51  Blárwolf+    10     2  Effective against cavalry units.     300       -
#
#    Unlock    Hero  IndexCol
# 48      -  Ursula        48
# 49      -  Ursula        49
# 50      3  Ursula        50
# 51      5  Ursula        51
# Veronica
#        Name Might Range                                             Effect  \
# 4  Élivágar    14     2  If unit initiates attack, bonuses on foes with...
#
#   SP Cost Default Unlock      Hero  IndexCol
# 4     400       -      -  Veronica         4
# Virion
#            Name Might Range                            Effect SP Cost Default  \
# 72     Iron Bow     4     2  Effective against flying units.       50       1
# 73    Steel Bow     6     2  Effective against flying units.      100       3
# 74   Silver Bow     9     2  Effective against flying units.      200       4
# 75  Silver Bow+    13     2  Effective against flying units.      300       -
#
#    Unlock    Hero  IndexCol
# 72      -  Virion        72
# 73      2  Virion        73
# 74      3  Virion        74
# 75      5  Virion        75
# Wrys
#        Name Might Range                                             Effect  \
# 13  Assault    10     2                                                  -
# 14     Slow     5     2  After any combat, inflicts Spd-6 on foe throug...
#
#    SP Cost Default Unlock  Hero  IndexCol
# 13      50       -      1  Wrys        13
# 14     150       -      3  Wrys        14
# Xander
#              Name Might Range  \
# 242    Iron Sword     6     1
# 243   Steel Sword     8     1
# 244  Silver Sword    11     1
# 245     Siegfried    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 242                                                  -      50       -      -
# 243                                                  -     100       3      -
# 244                                                  -     200       4      3
# 245  Enables counterattack regardless of distance i...     400       -      5
#
#        Hero  IndexCol
# 242  Xander       242
# 243  Xander       243
# 244  Xander       244
# 245  Xander       245
# Xander_(Spring_Festival)
#               Name Might Range  \
# 403     Iron Lance     6     1
# 404    Steel Lance     8     1
# 405   Carrot Lance     9     1
# 406  Carrot Lance+    13     1
#
#                                                 Effect SP Cost Default Unlock  \
# 403                                                  -      50       -      -
# 404                                                  -     100       -      -
# 405  If unit initiates attack, unit recovers 4 HP a...     200       -      -
# 406  If unit initiates attack, unit recovers 4 HP a...     300       5      -
#
#                          Hero  IndexCol
# 403  Xander_(Spring_Festival)       403
# 404  Xander_(Spring_Festival)       404
# 405  Xander_(Spring_Festival)       405
# 406  Xander_(Spring_Festival)       406
# Zephiel
#              Name Might Range  \
# 455    Iron Sword     6     1
# 456   Steel Sword     8     1
# 457  Silver Sword    11     1
# 458     Eckesachs    16     1
#
#                                                 Effect SP Cost Default Unlock  \
# 455                                                  -      50       -      -
# 456                                                  -     100       3      -
# 457                                                  -     200       4      3
# 458  Inflicts Def-4 on foes within 2 spaces through...     400       -      5
#
#         Hero  IndexCol
# 455  Zephiel       455
# 456  Zephiel       456
# 457  Zephiel       457
# 458  Zephiel       458

# %%
Five = {'red': 20, 'blue': 15, 'green': 9, 'colorless': 14}
Four = {'red': 26, 'blue': 21, 'green': 15, 'colorless': 23}
Three = {'red': 15, 'blue': 12, 'green': 9, 'colorless': 13}

total = 0
red_tot = 0
blue_tot = 0
green_tot = 0 
colorless_tot = 0 

red_five = 0
blue_five = 0
green_five = 0
colorless_five = 0 

red_four = 0 
blue_four = 0 
green_four = 0
colorless_four = 0 

red_three = 0 
blue_three = 0 
green_three = 0 
colorless_three = 0


for key, item in Five.items():
  total = total + item
  if key == 'red':
    red_tot = red_tot + item
    red_five = red_five + item
  elif key == 'blue':
    blue_tot = blue_tot + item
    blue_five = blue_five + item
  elif key == 'green':
    green_tot = green_tot + item
    green_five = green_five + item
  elif key == 'colorless':
    colorless_tot = colorless_tot + item
    colorless_five = colorless_five + item
    
for key, item in Four.items():
  total = total + item
  if key == 'red':
    red_tot = red_tot + item
    red_four = red_four + item
  elif key == 'blue':
    blue_tot = blue_tot + item
    blue_four = blue_four + item
  elif key == 'green':
    green_tot = green_tot + item
    green_four = green_four + item
  elif key == 'colorless':
    colorless_tot = colorless_tot + item
    colorless_four = colorless_four + item 
    
for key, item in Three.items():
  total = total + item
  if key == 'red':
    red_tot = red_tot + item
    red_three = red_three + item 
  elif key == 'blue':
    blue_tot = blue_tot + item
    blue_three = blue_three + item 
  elif key == 'green':
    green_tot = green_tot + item
    green_three = green_three + item
  elif key == 'colorless':
    colorless_tot = colorless_tot + item
    colorless_three = colorless_three + item 
    
five_total = red_five+blue_five+green_five+colorless_five
four_total = red_four+blue_four+green_four+colorless_four
three_total = red_three+blue_three+green_three+colorless_three

focus = {'red': 1, 'blue': 0, 'green': 2, 'colorless': 1}

for key, item in focus.items():
  total = total + item
  if key == 'red':
    red_tot = red_tot + item
  elif key == 'blue':
    blue_tot = blue_tot + item
  elif key == 'green':
    green_tot = green_tot + item
  elif key == 'colorless':
    colorless_tot = colorless_tot + item
    
focus_rsp = .03 * (focus['red']/4)
five_rsp = .03 * (Five['red']/five_total)
four_rsp = .36 * (Four['red']/four_total)
three_rsp = .58 * (Three['red']/three_total)

focus_bsp = .03 * (focus['blue']/4)
five_bsp = .03 * (Five['blue']/five_total)
four_bsp = .36 * (Four['blue']/four_total)
three_bsp = .58 * (Three['blue']/three_total)

focus_gsp = .03 * (focus['green']/4)
five_gsp = .03 * (Five['green']/five_total)
four_gsp = .36 * (Four['green']/four_total)
three_gsp = .58 * (Three['green']/three_total)

focus_csp = .03 * (focus['colorless']/4)
five_csp = .03 * (Five['colorless']/five_total)
four_csp = .36 * (Four['colorless']/four_total)
three_csp = .58 * (Three['colorless']/three_total)

red_percents = ['red', focus_rsp, five_rsp, four_rsp, three_rsp]
blue_percents = ['blue', focus_bsp, five_bsp, four_bsp, three_bsp]
green_percents = ['green', focus_gsp, five_gsp, four_gsp, three_gsp]
colorless_percents = ['colorless', focus_csp, five_csp, four_gsp, three_gsp]
all_percents = [red_percents, blue_percents, green_percents, colorless_percents]
for index, i in enumerate(all_percents):
  print(i)
  #print(focus[i[0]])
  print('')
  #print(i[0])
  for ind, j in enumerate(i):
    #print(j)
    #print(ind)
    if ind == 1:
      if focus[i[0]] > 0:
        print('Hero number: ', focus[i[0]], 'Individual percent: ', round((j/focus[i[0]]) * 100, 4))
      else:
        print('No heroes in category.')
    elif ind == 2:
      if Five[i[0]] > 0:
        print('Hero number: ', Five[i[0]], 'Individual percent: ',round((j/Five[i[0]]) * 100, 4))
      else:
        print('No heroes in category.')
    elif ind == 3:
      if Four[i[0]] > 0:
        print('Hero number: ', Four[i[0]], 'Individual percent: ',round((j/Four[i[0]]) * 100, 4))
      else:
        print('No heroes in category.')
    elif ind == 4:
      if Three[i[0]] > 0:
        print('Hero number: ', Three[i[0]], 'Individual percent: ',round((j/Three[i[0]]) * 100, 4))
      else:
        print('No heroes in category.')

  print('')
# Out:
# ['red', 0.0075, 0.010344827586206896, 0.11011764705882353, 0.17755102040816326]
#
# Hero number:  1 Individual percent:  0.75
# Hero number:  20 Individual percent:  0.0517
# Hero number:  26 Individual percent:  0.4235
# Hero number:  15 Individual percent:  1.1837
#
# ['blue', 0.0, 0.007758620689655172, 0.08894117647058823, 0.1420408163265306]
#
# No heroes in category.
# Hero number:  15 Individual percent:  0.0517
# Hero number:  21 Individual percent:  0.4235
# Hero number:  12 Individual percent:  1.1837
#
# ['green', 0.015, 0.004655172413793103, 0.06352941176470589, 0.10653061224489796]
#
# Hero number:  2 Individual percent:  0.75
# Hero number:  9 Individual percent:  0.0517
# Hero number:  15 Individual percent:  0.4235
# Hero number:  9 Individual percent:  1.1837
#
# ['colorless', 0.0075, 0.007241379310344828, 0.06352941176470589, 0.10653061224489796]
#
# Hero number:  1 Individual percent:  0.75
# Hero number:  14 Individual percent:  0.0517
# Hero number:  23 Individual percent:  0.2762
# Hero number:  13 Individual percent:  0.8195

# %%
wep_df = weapons_df.copy()
wep_df['Unlock'] = wep_df['Unlock'].replace('-', 0)

ass_df = assits_df.copy()
ass_df['Unlock'] = ass_df['Unlock'].replace('-', 0)

spe_df = specials_df.copy()
spe_df['Unlock'] = spe_df['Unlock'].replace('-', 0)

pas_df = passives_df.copy()
pas_df['Unlock'] = pas_df['Unlock'].replace('-', 0)

print(wep_df.head())
print(ass_df.head())
print(spe_df.head())
print(pas_df.head())
# Out:
#             Name Might Range                                       Effect  \
# 88    Iron Lance     6     1                                            -
# 89   Steel Lance     8     1                                            -
# 90   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 91  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
# 36    Iron Sword     6     1                                            -
#
#    SP Cost Default Unlock     Hero  IndexCol
# 88      50       -      0     Abel        88
# 89     100       -      0     Abel        89
# 90     200       4      0     Abel        90
# 91     300       5      5     Abel        91
# 36      50       2      0  Alfonse        36
#          Name Range                                             Effect  \
# 39       Swap     1                 Swap places with an adjacent ally.
# 16       Heal     1                                     Restores 5 HP.
# 17  Reconcile     1        Restores 7 HP each to target and this unit.
# 18     Martyr     1  Restores HP=7+ this unit's suffered damage.Uni...
# 66       Sing     1  Enables target to take another action.Cannot b...
#
#    SP Cost Default Unlock    Hero  IndexCol
# 39     150       4      3  Arthur        39
# 16       -       3      0   Azama        16
# 17     100       3      0   Azama        17
# 18     200       -      4   Azama        18
# 66     150       5      0   Azura        66
#                Name Cooldown  \
# 35   Holy Vestments        3
# 36            Aegis        3
# 11         Daylight        4
# 12              Sol        4
# 161     Dragon Gaze        4
#
#                                                 Effect SP Cost Default Unlock  \
# 35   Reduces damage inflicted by attacks from foes ...     100       4      0
# 36   Reduces damage inflicted by attacks from foes ...     200       -      4
# 11                           Heal 30% of damage dealt.     100       2      0
# 12                           Heal 50% of damage dealt.     200       -      4
# 161                                Grants +30% to Atk.     100       5      0
#
#         Hero  IndexCol
# 35      Abel        35
# 36      Abel        36
# 11   Alfonse        11
# 12   Alfonse        12
# 161      Alm       161
#                Name                                             Effect  \
# 125           HP +3                               Grants +3 to max HP.
# 126           HP +4                               Grants +4 to max HP.
# 127           HP +5                               Grants +5 to max HP.
# 128  Swordbreaker 1  If unit's HP ≥ 90% in combat against a sword u...
# 129  Swordbreaker 2  If unit's HP ≥ 70% in combat against a sword u...
#
#     SP Cost Unlock Type  Hero  IndexCol
# 125      40      0    A  Abel       125
# 126      80      4    A  Abel       126
# 127     160      5    A  Abel       127
# 128      50      0    B  Abel       128
# 129     100      0    B  Abel       129

# %%
wdf = wep_df.copy()
wdf['Unlock'] = pd.to_numeric(wdf['Unlock'])

valid = wdf[(wdf['Hero'] == 'Xander') & (wdf['Unlock'] <= 3)]
print(valid)
# Out:
#              Name Might Range Effect SP Cost Default  Unlock    Hero  IndexCol
# 242    Iron Sword     6     1      -      50       -       0  Xander       242
# 243   Steel Sword     8     1      -     100       3       0  Xander       243
# 244  Silver Sword    11     1      -     200       4       3  Xander       244

# %%
for i in radiance_hero_pool['5']:
    print(i)
five_radiance = []
for i in radiance_hero_pool['5']:
    for j in i[1]:
        five_radiance.append(j)
        
print(five_radiance)

four_radiance = []
for i in radiance_hero_pool['4']:
    for j in i[1]:
        four_radiance.append(j)
        
three_radiance = []
for i in radiance_hero_pool['3']:
    for j in i[1]:
        three_radiance.append(j)
# Out:
# ('red', ['Alm', 'Eirika', 'Eldigan', 'Ogma', 'Cain', 'Corrin', 'Karel', 'Chrom', 'Caeda', 'Seliph', 'Marth', 'Ryoma', 'Lyn', 'Lucina', 'Roy', 'Tiki', 'Sanaki', 'Tharja', 'Lilina', 'Leo'])
# ('blue', ['Azura', 'Abel', 'Ephraim', 'Effie', 'Catria', 'Clair', 'Cordelia', 'Hinoka', 'Peri', 'Lukas', 'Ninian', 'Nowi', 'Olwen', 'Reinhardt', 'Linde'])
# ('green', ['Camilla', 'Sheena', 'Hector', 'Hawkeye', 'Minerva', 'Raven', 'Fae', 'Merric', 'Julia'])
# ('colorless', ['Faye', 'Klein', 'Jeorge', 'Takumi', 'Rebecca', 'Kagero', 'Jaffar', 'Jakob', 'Elise', 'Sakura', 'Priscilla', 'Maria', 'Lachesis', 'Lucius'])
# ['Alm', 'Eirika', 'Eldigan', 'Ogma', 'Cain', 'Corrin', 'Karel', 'Chrom', 'Caeda', 'Seliph', 'Marth', 'Ryoma', 'Lyn', 'Lucina', 'Roy', 'Tiki', 'Sanaki', 'Tharja', 'Lilina', 'Leo', 'Azura', 'Abel', 'Ephraim', 'Effie', 'Catria', 'Clair', 'Cordelia', 'Hinoka', 'Peri', 'Lukas', 'Ninian', 'Nowi', 'Olwen', 'Reinhardt', 'Linde', 'Camilla', 'Sheena', 'Hector', 'Hawkeye', 'Minerva', 'Raven', 'Fae', 'Merric', 'Julia', 'Faye', 'Klein', 'Jeorge', 'Takumi', 'Rebecca', 'Kagero', 'Jaffar', 'Jakob', 'Elise', 'Sakura', 'Priscilla', 'Maria', 'Lachesis', 'Lucius']

# %%
df_group = [wep_df, ass_df, spe_df, pas_df]
for df in df_group:
    df['Unlock'] = pd.to_numeric(df['Unlock'])
    print(df['Unlock'].head())
# Out:
# 88    0
# 89    0
# 90    0
# 91    5
# 36    0
# Name: Unlock, dtype: int64
# 39    3
# 16    0
# 17    0
# 18    4
# 66    0
# Name: Unlock, dtype: int64
# 35     0
# 36     4
# 11     0
# 12     4
# 161    0
# Name: Unlock, dtype: int64
# 125    0
# 126    4
# 127    5
# 128    0
# 129    0
# Name: Unlock, dtype: int64

# %%
five_weps = []
for hero in five_radiance:
    five_weps.append(wep_df[wep_df['Hero'] == hero])
def radiance_concat(df_list):
    for index, item in enumerate(df_list):
        if index == 0:
            new_df = item
        if index >= 1:
            new_df = pd.concat([new_df, item], ignore_index=True)
    return new_df

five_rad_wep = radiance_concat(five_weps)
#print(five_rad_wep.head())
for hero in five_radiance:
    print(hero)
    print(five_rad_wep[five_rad_wep['Hero'] == hero])
# Out:
# Alm
#            Name Might Range  \
# 0    Iron Sword     6     1
# 1   Steel Sword     8     1
# 2  Silver Sword    11     1
# 3      Falchion    16     1
#
#                                               Effect SP Cost Default  Unlock  \
# 0                                                  -      50       -       0
# 1                                                  -     100       -       0
# 2                                                  -     200       -       0
# 3  Effective against dragons. At the start of eve...     400       5       0
#
#   Hero  IndexCol
# 0  Alm       467
# 1  Alm       468
# 2  Alm       469
# 3  Alm       470
# Eirika
#            Name Might Range  \
# 4    Iron Sword     6     1
# 5   Steel Sword     8     1
# 6  Silver Sword    11     1
# 7     Sieglinde    16     1
#
#                                               Effect SP Cost Default  Unlock  \
# 4                                                  -      50       -       0
# 5                                                  -     100       -       0
# 6                                                  -     200       4       0
# 7  Grants adjacent allies Atk+3 through their nex...     400       5       5
#
#      Hero  IndexCol
# 4  Eirika       162
# 5  Eirika       163
# 6  Eirika       164
# 7  Eirika       165
# Eldigan
#             Name Might Range                                           Effect  \
# 8     Iron Sword     6     1                                                -
# 9    Steel Sword     8     1                                                -
# 10  Killing Edge     7     1  Accelerates Special trigger (cooldown count-1).
# 11   Mystletainn    16     1  Accelerates Special trigger (cooldown count-1).
#
#    SP Cost Default  Unlock     Hero  IndexCol
# 8       50       -       0  Eldigan       176
# 9      100       -       0  Eldigan       177
# 10     200       -       0  Eldigan       178
# 11     400       5       0  Eldigan       179
# Ogma
#             Name Might Range                                       Effect  \
# 12    Iron Sword     6     1                                            -
# 13   Steel Sword     8     1                                            -
# 14   Brave Sword     5     1  Spd-5. Attack twice when initiating combat.
# 15  Brave Sword+     8     1  Spd-5. Attack twice when initiating combat.
#
#    SP Cost Default  Unlock  Hero  IndexCol
# 12      50       -       0  Ogma       230
# 13     100       -       0  Ogma       231
# 14     200       4       0  Ogma       232
# 15     300       5       5  Ogma       233
# Cain
#             Name Might Range                                       Effect  \
# 16    Iron Sword     6     1                                            -
# 17   Steel Sword     8     1                                            -
# 18   Brave Sword     5     1  Spd-5. Attack twice when initiating combat.
# 19  Brave Sword+     8     1  Spd-5. Attack twice when initiating combat.
#
#    SP Cost Default  Unlock  Hero  IndexCol
# 16      50       -       0  Cain        64
# 17     100       -       0  Cain        65
# 18     200       4       0  Cain        66
# 19     300       5       5  Cain        67
# Corrin
# Empty DataFrame
# Columns: [Name, Might, Range, Effect, SP Cost, Default, Unlock, Hero, IndexCol]
# Index: []
# Karel
#            Name Might Range                                       Effect  \
# 20   Iron Sword     6     1                                            -
# 21  Steel Sword     8     1                                            -
# 22       Wo Dao     9     1  Grants +10 to damage when Special triggers.
# 23      Wo Dao+    13     1  Grants +10 to damage when Special triggers.
#
#    SP Cost Default  Unlock   Hero  IndexCol
# 20      50       -       0  Karel       134
# 21     100       -       0  Karel       135
# 22     200       -       0  Karel       136
# 23     300       5       0  Karel       137
# Chrom
#             Name Might Range  \
# 24    Iron Sword     6     1
# 25   Steel Sword     8     1
# 26  Silver Sword    11     1
# 27      Falchion    16     1
#
#                                                Effect SP Cost Default  Unlock  \
# 24                                                  -      50       -       0
# 25                                                  -     100       -       0
# 26                                                  -     200       4       0
# 27  Effective against dragons. At the start of eve...     400       5       5
#
#      Hero  IndexCol
# 24  Chrom       325
# 25  Chrom       326
# 26  Chrom       327
# 27  Chrom       328
# Caeda
#             Name Might Range                             Effect SP Cost  \
# 28    Iron Sword     6     1                                  -      50
# 29   Steel Sword     8     1                                  -     100
# 30   Armorslayer     8     1  Effective against armored units.      200
# 31  Armorslayer+    12     1  Effective against armored units.      300
#
#    Default  Unlock   Hero  IndexCol
# 28       -       0  Caeda       146
# 29       -       0  Caeda       147
# 30       4       0  Caeda       148
# 31       5       5  Caeda       149
# Seliph
#             Name Might Range                                      Effect  \
# 32    Iron Sword     6     1                                           -
# 33   Steel Sword     8     1                                           -
# 34  Silver Sword    11     1                                           -
# 35       Tyrfing    16     1  Grants Def+4 in battle if unit's HP ≤ 50%.
#
#    SP Cost Default  Unlock    Hero  IndexCol
# 32      50       -       0  Seliph       359
# 33     100       -       0  Seliph       360
# 34     200       4       0  Seliph       361
# 35     400       5       5  Seliph       362
# Marth
#             Name Might Range  \
# 36    Iron Sword     6     1
# 37   Steel Sword     8     1
# 38  Silver Sword    11     1
# 39      Falchion    16     1
#
#                                                Effect SP Cost Default  Unlock  \
# 36                                                  -      50       -       0
# 37                                                  -     100       -       0
# 38                                                  -     200       4       0
# 39  Effective against dragons. At the start of eve...     400       5       5
#
#      Hero  IndexCol
# 36  Marth       272
# 37  Marth       273
# 38  Marth       274
# 39  Marth       275
# Ryoma
#             Name Might Range  \
# 40    Iron Sword     6     1
# 41   Steel Sword     8     1
# 42  Silver Sword    11     1
# 43      Raijinto    16     1
#
#                                                Effect SP Cost Default  Unlock  \
# 40                                                  -      50       -       0
# 41                                                  -     100       -       0
# 42                                                  -     200       -       0
# 43  Enables counterattack regardless of distance i...     400       5       0
#
#      Hero  IndexCol
# 40  Ryoma        32
# 41  Ryoma        33
# 42  Ryoma        34
# 43  Ryoma        35
# Lyn
#             Name Might Range  \
# 44    Iron Sword     6     1
# 45   Steel Sword     8     1
# 46  Silver Sword    11     1
# 47     Sol Katti    16     1
#
#                                                Effect SP Cost Default  Unlock  \
# 44                                                  -      50       -       0
# 45                                                  -     100       -       0
# 46                                                  -     200       -       0
# 47  If wielder initiates attack at HP ≤ 50%, any f...     400       5       0
#
#    Hero  IndexCol
# 44  Lyn       276
# 45  Lyn       277
# 46  Lyn       278
# 47  Lyn       279
# Lucina
#             Name Might Range  \
# 48    Iron Sword     6     1
# 49   Steel Sword     8     1
# 50  Silver Sword    11     1
# 51      Falchion    16     1
#
#                                                Effect SP Cost Default  Unlock  \
# 48                                                  -      50       -       0
# 49                                                  -     100       -       0
# 50                                                  -     200       -       0
# 51  Effective against dragons. At the start of eve...     400       5       0
#
#       Hero  IndexCol
# 48  Lucina       216
# 49  Lucina       217
# 50  Lucina       218
# 51  Lucina       219
# Roy
#              Name Might Range                                        Effect  \
# 52     Iron Sword     6     1                                             -
# 53    Steel Sword     8     1                                             -
# 54   Silver Sword    11     1                                             -
# 55  Binding Blade    16     1  Grants Def/Res+2 when this unit is attacked.
#
#    SP Cost Default  Unlock Hero  IndexCol
# 52      50       -       0  Roy       297
# 53     100       -       0  Roy       298
# 54     200       4       0  Roy       299
# 55     400       5       5  Roy       300
# Tiki
# Empty DataFrame
# Columns: [Name, Might, Range, Effect, SP Cost, Default, Unlock, Hero, IndexCol]
# Index: []
# Sanaki
#          Name Might Range                                             Effect  \
# 56       Fire     4     2                                                  -
# 57     Elfire     6     2                                                  -
# 58  Bolganone     9     2                                                  -
# 59  Cymbeline    14     2  Grants adjacent allies Atk+4 through their nex...
#
#    SP Cost Default  Unlock    Hero  IndexCol
# 56      50       -       0  Sanaki       379
# 57     100       -       0  Sanaki       380
# 58     200       -       0  Sanaki       381
# 59     400       5       0  Sanaki       382
# Tharja
#            Name Might Range  \
# 60         Flux     4     2
# 61         Ruin     6     2
# 62   Rauðrblade     9     2
# 63  Rauðrblade+    13     2
#
#                                                Effect SP Cost Default  Unlock  \
# 60                                                  -      50       -       0
# 61                                                  -     100       -       0
# 62  Slows Special trigger (cooldown count+1).Adds ...     200       4       0
# 63  Slows Special trigger (cooldown count+1).Adds ...     300       5       5
#
#       Hero  IndexCol
# 60  Tharja       407
# 61  Tharja       408
# 62  Tharja       409
# 63  Tharja       410
# Lilina
#           Name Might Range Effect SP Cost Default  Unlock    Hero  IndexCol
# 64        Fire     4     2      -      50       -       0  Lilina       411
# 65      Elfire     6     2      -     100       -       0  Lilina       412
# 66   Bolganone     9     2      -     200       4       0  Lilina       413
# 67  Bolganone+    13     2      -     300       5       5  Lilina       414
# Leo
#          Name Might Range                                             Effect  \
# 68       Flux     4     2                                                  -
# 69       Ruin     6     2                                                  -
# 70     Fenrir     9     2                                                  -
# 71  Brynhildr    14     2  If unit initiates attack, restricts foe's next...
#
#    SP Cost Default  Unlock Hero  IndexCol
# 68      50       -       0  Leo        40
# 69     100       -       0  Leo        41
# 70     200       -       0  Leo        42
# 71     400       5       0  Leo        43
# Azura
#                Name Might Range  \
# 72       Iron Lance     6     1
# 73      Steel Lance     8     1
# 74   Sapphire Lance     8     1
# 75  Sapphire Lance+    12     1
#
#                                                Effect SP Cost Default  Unlock  \
# 72                                                  -      50       -       0
# 73                                                  -     100       -       0
# 74  Gives Atk+20% if weapon-triangle advantage, At...     200       -       0
# 75  Gives Atk+20% if weapon-triangle advantage, At...     300       5       0
#
#      Hero  IndexCol
# 72  Azura       375
# 73  Azura       376
# 74  Azura       377
# 75  Azura       378
# Abel
#             Name Might Range                                       Effect  \
# 76    Iron Lance     6     1                                            -
# 77   Steel Lance     8     1                                            -
# 78   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 79  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#    SP Cost Default  Unlock  Hero  IndexCol
# 76      50       -       0  Abel        88
# 77     100       -       0  Abel        89
# 78     200       4       0  Abel        90
# 79     300       5       5  Abel        91
# Ephraim
#            Name Might Range  \
# 80   Iron Lance     6     1
# 81  Steel Lance     8     1
# 82  Heavy Spear     8     1
# 83     Siegmund    16     1
#
#                                                Effect SP Cost Default  Unlock  \
# 80                                                  -      50       -       0
# 81                                                  -     100       -       0
# 82                  Effective against armored units.      200       -       0
# 83  Grants adjacent allies Atk+3 through their nex...     400       5       0
#
#        Hero  IndexCol
# 80  Ephraim       353
# 81  Ephraim       354
# 82  Ephraim       355
# 83  Ephraim       356
# Effie
#              Name Might Range Effect SP Cost Default  Unlock   Hero  IndexCol
# 84     Iron Lance     6     1      -      50       -       0  Effie       289
# 85    Steel Lance     8     1      -     100       -       0  Effie       290
# 86   Silver Lance    11     1      -     200       4       0  Effie       291
# 87  Silver Lance+    15     1      -     300       5       5  Effie       292
# Catria
#              Name Might Range  \
# 88     Iron Lance     6     1
# 89    Steel Lance     8     1
# 90   Killer Lance     7     1
# 91  Killer Lance+    11     1
#
#                                              Effect SP Cost Default  Unlock  \
# 88                                                -      50       -       0
# 89                                                -     100       3       0
# 90  Accelerates Special trigger (cooldown count-1).     200       4       3
# 91  Accelerates Special trigger (cooldown count-1).     300       5       5
#
#       Hero  IndexCol
# 88  Catria        28
# 89  Catria        29
# 90  Catria        30
# 91  Catria        31
# Clair
#              Name Might Range Effect SP Cost Default  Unlock   Hero  IndexCol
# 92     Iron Lance     6     1      -      50       -       0  Clair       439
# 93    Steel Lance     8     1      -     100       -       0  Clair       440
# 94   Silver Lance    11     1      -     200       4       0  Clair       441
# 95  Silver Lance+    15     1      -     300       5       0  Clair       442
# Cordelia
#             Name Might Range                                       Effect  \
# 96    Iron Lance     6     1                                            -
# 97   Steel Lance     8     1                                            -
# 98   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 99  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#    SP Cost Default  Unlock      Hero  IndexCol
# 96      50       -       0  Cordelia       150
# 97     100       -       0  Cordelia       151
# 98     200       4       0  Cordelia       152
# 99     300       5       5  Cordelia       153
# Hinoka
#              Name Might Range                                       Effect  \
# 100    Iron Lance     6     1                                            -
# 101   Steel Lance     8     1                                            -
# 102   Brave Lance     5     1  Spd-5. Attack twice when initiating combat.
# 103  Brave Lance+     8     1  Spd-5. Attack twice when initiating combat.
#
#     SP Cost Default  Unlock    Hero  IndexCol
# 100      50       -       0  Hinoka       268
# 101     100       -       0  Hinoka       269
# 102     200       -       0  Hinoka       270
# 103     300       5       0  Hinoka       271
# Peri
#               Name Might Range  \
# 104     Iron Lance     6     1
# 105    Steel Lance     8     1
# 106   Killer Lance     7     1
# 107  Killer Lance+    11     1
#
#                                               Effect SP Cost Default  Unlock  \
# 104                                                -      50       -       0
# 105                                                -     100       -       0
# 106  Accelerates Special trigger (cooldown count-1).     200       4       0
# 107  Accelerates Special trigger (cooldown count-1).     300       5       5
#
#      Hero  IndexCol
# 104  Peri       284
# 105  Peri       285
# 106  Peri       286
# 107  Peri       287
# Lukas
#               Name Might Range  \
# 108     Iron Lance     6     1
# 109    Steel Lance     8     1
# 110   Killer Lance     7     1
# 111  Killer Lance+    11     1
#
#                                               Effect SP Cost Default  Unlock  \
# 108                                                -      50       -       0
# 109                                                -     100       -       0
# 110  Accelerates Special trigger (cooldown count-1).     200       4       0
# 111  Accelerates Special trigger (cooldown count-1).     300       5       0
#
#       Hero  IndexCol
# 108  Lukas       122
# 109  Lukas       123
# 110  Lukas       124
# 111  Lukas       125
# Ninian
#               Name Might Range  \
# 112    Fire Breath     6     1
# 113   Fire Breath+     8     1
# 114   Light Breath     9     1
# 115  Light Breath+    13     1
#
#                                                 Effect SP Cost Default  \
# 112                                                  -      50       -
# 113                                                  -     100       -
# 114  Grants adjacent allies Def/Res+4 through their...     200       -
# 115  Grants adjacent allies Def/Res+4 through their...     300       5
#
#      Unlock    Hero  IndexCol
# 112       0  Ninian       429
# 113       0  Ninian       430
# 114       0  Ninian       431
# 115       0  Ninian       432
# Nowi
#                   Name Might Range  \
# 116        Fire Breath     6     1
# 117       Fire Breath+     8     1
# 118   Lightning Breath     7     1
# 119  Lightning Breath+    11     1
#
#                                                 Effect SP Cost Default  \
# 116                                                  -      50       -
# 117                                                  -     100       -
# 118  Enables counterattack regardless of attacker's...     200       4
# 119  Enables counterattack regardless of attacker's...     300       5
#
#      Unlock  Hero  IndexCol
# 116       0  Nowi       345
# 117       0  Nowi       346
# 118       0  Nowi       347
# 119       5  Nowi       348
# Olwen
#              Name Might Range                                       Effect  \
# 120       Thunder     4     2                                            -
# 121     Elthunder     6     2                                            -
# 122        Thoron     9     2                                            -
# 123  Dire Thunder     9     2  Spd-5. Attack twice when initiating combat.
#
#     SP Cost Default  Unlock   Hero  IndexCol
# 120      50       -       0  Olwen       471
# 121     100       -       0  Olwen       472
# 122     200       -       0  Olwen       473
# 123     400       5       0  Olwen       474
# Reinhardt
#              Name Might Range                                       Effect  \
# 124       Thunder     4     2                                            -
# 125     Elthunder     6     2                                            -
# 126        Thoron     9     2                                            -
# 127  Dire Thunder     9     2  Spd-5. Attack twice when initiating combat.
#
#     SP Cost Default  Unlock       Hero  IndexCol
# 124      50       -       0  Reinhardt       419
# 125     100       -       0  Reinhardt       420
# 126     200       4       0  Reinhardt       421
# 127     400       5       5  Reinhardt       422
# Linde
#           Name Might Range                                             Effect  \
# 128    Thunder     4     2                                                  -
# 129  Elthunder     6     2                                                  -
# 130     Thoron     9     2                                                  -
# 131       Aura    14     2  Restores 5 HP to adjacent allies after any com...
#
#     SP Cost Default  Unlock   Hero  IndexCol
# 128      50       -       0  Linde       443
# 129     100       -       0  Linde       444
# 130     200       -       0  Linde       445
# 131     400       5       0  Linde       446
# Camilla
#            Name Might Range                                       Effect  \
# 132    Iron Axe     6     1                                            -
# 133   Steel Axe     8     1                                            -
# 134   Brave Axe     5     1  Spd-5. Attack twice when initiating combat.
# 135  Brave Axe+     8     1  Spd-5. Attack twice when initiating combat.
#
#     SP Cost Default  Unlock     Hero  IndexCol
# 132      50       -       0  Camilla       425
# 133     100       -       0  Camilla       426
# 134     200       4       0  Camilla       427
# 135     300       5       5  Camilla       428
# Sheena
#             Name Might Range                                           Effect  \
# 136     Iron Axe     6     1                                                -
# 137    Steel Axe     8     1                                                -
# 138   Killer Axe     7     1  Accelerates Special trigger (cooldown count-1).
# 139  Killer Axe+    11     1  Accelerates Special trigger (cooldown count-1).
#
#     SP Cost Default  Unlock    Hero  IndexCol
# 136      50       -       0  Sheena         5
# 137     100       -       0  Sheena         6
# 138     200       4       0  Sheena         7
# 139     300       5       5  Sheena         8
# Hector
#            Name Might Range  \
# 140    Iron Axe     6     1
# 141   Steel Axe     8     1
# 142  Silver Axe    11     1
# 143      Armads    16     1
#
#                                                 Effect SP Cost Default  \
# 140                                                  -      50       -
# 141                                                  -     100       -
# 142                                                  -     200       -
# 143  Unit makes a guaranteed follow-up attack when ...     400       5
#
#      Unlock    Hero  IndexCol
# 140       0  Hector       110
# 141       0  Hector       111
# 142       0  Hector       112
# 143       0  Hector       113
# Hawkeye
#             Name Might Range                                           Effect  \
# 144     Iron Axe     6     1                                                -
# 145    Steel Axe     8     1                                                -
# 146   Killer Axe     7     1  Accelerates Special trigger (cooldown count-1).
# 147  Killer Axe+    11     1  Accelerates Special trigger (cooldown count-1).
#
#     SP Cost Default  Unlock     Hero  IndexCol
# 144      50       -       0  Hawkeye       309
# 145     100       -       0  Hawkeye       310
# 146     200       4       3  Hawkeye       311
# 147     300       5       5  Hawkeye       312
# Minerva
#            Name Might Range                                           Effect  \
# 148    Iron Axe     6     1                                                -
# 149   Steel Axe     8     1                                                -
# 150  Silver Axe    11     1                                                -
# 151  Hauteclere    16     1  Accelerates Special trigger (cooldown count-1).
#
#     SP Cost Default  Unlock     Hero  IndexCol
# 148      50       -       0  Minerva       188
# 149     100       -       0  Minerva       189
# 150     200       -       0  Minerva       190
# 151     400       5       0  Minerva       191
# Raven
#            Name Might Range                                       Effect  \
# 152    Iron Axe     6     1                                            -
# 153   Steel Axe     8     1                                            -
# 154   Brave Axe     5     1  Spd-5. Attack twice when initiating combat.
# 155  Brave Axe+     8     1  Spd-5. Attack twice when initiating combat.
#
#     SP Cost Default  Unlock   Hero  IndexCol
# 152      50       -       0  Raven       234
# 153     100       -       0  Raven       235
# 154     200       4       0  Raven       236
# 155     300       5       5  Raven       237
# Fae
#               Name Might Range  \
# 156    Fire Breath     6     1
# 157   Fire Breath+     8     1
# 158   Light Breath     9     1
# 159  Light Breath+    13     1
#
#                                                 Effect SP Cost Default  \
# 156                                                  -      50       -
# 157                                                  -     100       -
# 158  Grants adjacent allies Def/Res+4 through their...     200       4
# 159  Grants adjacent allies Def/Res+4 through their...     300       5
#
#      Unlock Hero  IndexCol
# 156       0  Fae        44
# 157       0  Fae        45
# 158       0  Fae        46
# 159       5  Fae        47
# Merric
#            Name Might Range                            Effect SP Cost Default  \
# 160        Wind     4     2                                 -      50       -
# 161      Elwind     6     2                                 -     100       -
# 162  Rexcalibur     9     2                                 -     200       4
# 163   Excalibur    14     2  Effective against flying units.      400       5
#
#      Unlock    Hero  IndexCol
# 160       0  Merric       102
# 161       0  Merric       103
# 162       0  Merric       104
# 163       5  Merric       105
# Julia
#            Name Might Range  \
# 164        Wind     4     2
# 165      Elwind     6     2
# 166  Rexcalibur     9     2
# 167        Naga    14     2
#
#                                                 Effect SP Cost Default  \
# 164                                                  -      50       -
# 165                                                  -     100       -
# 166                                                  -     200       -
# 167  Effective against dragons. Grants Def/Res+2 wh...     400       5
#
#      Unlock   Hero  IndexCol
# 164       0  Julia       170
# 165       0  Julia       171
# 166       0  Julia       172
# 167       0  Julia       173
# Faye
#                Name Might Range  \
# 168        Iron Bow     4     2
# 169       Steel Bow     6     2
# 170   Firesweep Bow     7     2
# 171  Firesweep Bow+    11     2
#
#                                                 Effect SP Cost Default  \
# 168                   Effective against flying units.       50       -
# 169                   Effective against flying units.      100       -
# 170  Effective against flying units. Unit and enemi...     200       -
# 171  Effective against flying units. Unit and enemi...     300       5
#
#      Unlock  Hero  IndexCol
# 168       0  Faye       363
# 169       0  Faye       364
# 170       0  Faye       365
# 171       0  Faye       366
# Klein
#            Name Might Range  \
# 172    Iron Bow     4     2
# 173   Steel Bow     6     2
# 174   Brave Bow     4     2
# 175  Brave Bow+     7     2
#
#                                                 Effect SP Cost Default  \
# 172                   Effective against flying units.       50       -
# 173                   Effective against flying units.      100       -
# 174  Spd-5. Effective against flying units. Attacks...     200       4
# 175  Spd-5. Effective against flying units. Attacks...     300       5
#
#      Unlock   Hero  IndexCol
# 172       0  Klein       387
# 173       0  Klein       388
# 174       0  Klein       389
# 175       5  Klein       390
# Jeorge
#            Name Might Range  \
# 176    Iron Bow     4     2
# 177   Steel Bow     6     2
# 178  Silver Bow     9     2
# 179     Parthia    14     2
#
#                                                 Effect SP Cost Default  \
# 176                   Effective against flying units.       50       -
# 177                   Effective against flying units.      100       -
# 178                   Effective against flying units.      200       4
# 179  Effective against flying units. Grants Res+4 d...     400       5
#
#      Unlock    Hero  IndexCol
# 176       0  Jeorge       154
# 177       0  Jeorge       155
# 178       0  Jeorge       156
# 179       5  Jeorge       157
# Takumi
#            Name Might Range  \
# 180    Iron Bow     4     2
# 181   Steel Bow     6     2
# 182  Silver Bow     9     2
# 183  Fujin Yumi    14     2
#
#                                                 Effect SP Cost Default  \
# 180                   Effective against flying units.       50       -
# 181                   Effective against flying units.      100       -
# 182                   Effective against flying units.      200       -
# 183  Effective against flying units. Unit can pass ...     400       5
#
#      Unlock    Hero  IndexCol
# 180       0  Takumi       459
# 181       0  Takumi       460
# 182       0  Takumi       461
# 183       0  Takumi       462
# Rebecca
#             Name Might Range                            Effect SP Cost  \
# 184     Iron Bow     4     2  Effective against flying units.       50
# 185    Steel Bow     6     2  Effective against flying units.      100
# 186   Silver Bow     9     2  Effective against flying units.      200
# 187  Silver Bow+    13     2  Effective against flying units.      300
#
#     Default  Unlock     Hero  IndexCol
# 184       -       0  Rebecca       262
# 185       -       0  Rebecca       263
# 186       4       0  Rebecca       264
# 187       5       5  Rebecca       265
# Kagero
#                Name Might Range  \
# 188     Iron Dagger     3     2
# 189    Steel Dagger     5     2
# 190   Poison Dagger     2     2
# 191  Poison Dagger+     5     2
#
#                                                 Effect SP Cost Default  \
# 188  After combat, inflicts Def/Res-3 on foe throug...      50       -
# 189  After combat, inflicts Def/Res-3 on foe throug...     100       -
# 190  Effective against infantry units. Infantry foe...     200       4
# 191  Effective against infantry units. Infantry foe...     300       5
#
#      Unlock    Hero  IndexCol
# 188       0  Kagero       138
# 189       0  Kagero       139
# 190       0  Kagero       140
# 191       5  Kagero       141
# Jaffar
#                Name Might Range  \
# 192     Iron Dagger     3     2
# 193    Steel Dagger     5     2
# 194   Silver Dagger     7     2
# 195  Deathly Dagger    11     2
#
#                                                 Effect SP Cost Default  \
# 192  After combat, inflicts Def/Res-3 on foe throug...      50       -
# 193  After combat, inflicts Def/Res-3 on foe throug...     100       -
# 194  After combat, inflicts Def/Res-5 on foe throug...     200       -
# 195  After combat, inflicts Def/Res-7 on foe throug...     400       5
#
#      Unlock    Hero  IndexCol
# 192       0  Jaffar       383
# 193       0  Jaffar       384
# 194       0  Jaffar       385
# 195       0  Jaffar       386
# Jakob
#                Name Might Range  \
# 196     Iron Dagger     3     2
# 197    Steel Dagger     5     2
# 198   Silver Dagger     7     2
# 199  Silver Dagger+    10     2
#
#                                                 Effect SP Cost Default  \
# 196  After combat, inflicts Def/Res-3 on foe throug...      50       -
# 197  After combat, inflicts Def/Res-3 on foe throug...     100       -
# 198  After combat, inflicts Def/Res-5 on foe throug...     200       4
# 199  After combat, inflicts Def/Res-7 on foe throug...     300       5
#
#      Unlock   Hero  IndexCol
# 196       0  Jakob       166
# 197       0  Jakob       167
# 198       0  Jakob       168
# 199       5  Jakob       169
# Elise
#         Name Might Range                                             Effect  \
# 200  Assault    10     2                                                  -
# 201  Gravity     6     2  After any combat, prevents foe from moving mor...
#
#     SP Cost Default  Unlock   Hero  IndexCol
# 200      50       -       0  Elise       174
# 201     150       -       0  Elise       175
# Sakura
#         Name Might Range                                             Effect  \
# 202  Assault    10     2                                                  -
# 203     Fear     5     2  After combat, inflicts Atk-6 on targeted foe t...
#
#     SP Cost Default  Unlock    Hero  IndexCol
# 202      50       -       0  Sakura       266
# 203     150       -       4  Sakura       267
# Priscilla
#         Name Might Range                                             Effect  \
# 204  Assault    10     2                                                  -
# 205    Panic     7     2  After combat, bonuses on targeted foe become p...
#
#     SP Cost Default  Unlock       Hero  IndexCol
# 204      50       -       4  Priscilla       357
# 205     150       -       4  Priscilla       358
# Maria
#         Name Might Range                                             Effect  \
# 206  Assault    10     2                                                  -
# 207    Panic     7     2  After combat, bonuses on targeted foe become p...
#
#     SP Cost Default  Unlock   Hero  IndexCol
# 206      50       -       4  Maria       313
# 207     150       -       4  Maria       314
# Lachesis
#         Name Might Range                            Effect SP Cost Default  \
# 208  Assault    10     2                                 -      50       -
# 209   Absorb     4     2  Recovers HP=50% of damage dealt.     150       -
#
#      Unlock      Hero  IndexCol
# 208       0  Lachesis       323
# 209       4  Lachesis       324
# Lucius
#         Name Might Range                                            Effect  \
# 210  Assault    10     2                                                 -
# 211     Pain     3     2  Inflicts 10 damage on targeted foe after combat.
#
#     SP Cost Default  Unlock    Hero  IndexCol
# 210      50       -       4  Lucius       423
# 211     150       -       4  Lucius       424

# %%
print(wep_df[wep_df['Hero'] == 'Alm'])
# Out:
#              Name Might Range  \
# 467    Iron Sword     6     1
# 468   Steel Sword     8     1
# 469  Silver Sword    11     1
# 470      Falchion    16     1
#
#                                                 Effect SP Cost Default  \
# 467                                                  -      50       -
# 468                                                  -     100       -
# 469                                                  -     200       -
# 470  Effective against dragons. At the start of eve...     400       5
#
#      Unlock Hero  IndexCol
# 467       0  Alm       467
# 468       0  Alm       468
# 469       0  Alm       469
# 470       0  Alm       470
